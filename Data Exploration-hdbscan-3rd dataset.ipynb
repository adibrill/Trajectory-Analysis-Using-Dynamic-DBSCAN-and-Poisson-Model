# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd

# %%
# !pip install cartopy
# !pip install geopy

# %% [markdown]
# # Data Loading and preprocessing

# %%
import pandas as pd

#df = pd.read_csv("(EBD) Common Kestrel (Falco tinnunculus) Spain, MERCURIO-SUMHAL.csv")
df = pd.read_csv("white_storks_sample.csv")
#df["height-above-msl"] = df["height-above-ellipsoid"]
df.head()
#df.to_csv("white_storks_sample.csv")
# Out:
#    Unnamed: 0.1  Unnamed: 0       epoch            timestamp  location-long  \
# 0             0           0  1329184844  2012-02-14 02:00:44      36.701858
# 1             1           1  1329185110  2012-02-14 02:05:10      36.701850
# 2             2           2  1329185412  2012-02-14 02:10:12      36.701815
# 3             3           3  1329185711  2012-02-14 02:15:11      36.701855
# 4             4           4  1329186010  2012-02-14 02:20:10      36.701822
#
#    location-lat  height-above-ellipsoid  height-above-msl
# 0      3.985513                   670.0             670.0
# 1      3.985472                   667.9             667.9
# 2      3.985495                   668.8             668.8
# 3      3.985515                   666.7             666.7
# 4      3.985484                   667.6             667.6

# %%
df2 = df.head(5000)

ts1 = df2['timestamp'].iloc[0]
ts2 = df2['timestamp'].iloc[-1]

print("start time:", ts1)
print("end time:", ts2)
# Out:
# start time: 2023-04-28 10:06:54
# end time: 2023-06-30 22:04:17

# %%
len(df)
# Out:
# 5000

# %%
ts1 = df['timestamp'].iloc[0]
ts2 = df['timestamp'].iloc[-1]

print("start time:", ts1)
print("end time:", ts2)
# Out:
# start time: 2012-02-14 02:00:44
# end time: 2012-03-10 16:15:12

# %%
df['timestamp'] = pd.to_datetime(df['timestamp'])
df['epoch'] = df['timestamp'].astype('int64') // 10**9

# %%
df.columns
# Out:
# Index(['event-id', 'visible', 'timestamp', 'location-long', 'location-lat',
#        'gps:activity-count', 'external-temperature', 'gps:dop', 'gps:hdop',
#        'gps:satellite-count', 'gps-time-to-fix', 'ground-speed', 'heading',
#        'height-above-msl', 'import-marked-outlier', 'gls:light-level',
#        'location-error-numerical', 'manually-marked-outlier',
#        'vertical-error-numerical', 'sensor-type',
#        'individual-taxon-canonical-name', 'tag-local-identifier',
#        'individual-local-identifier', 'study-name', 'epoch'],
#       dtype='object')

# %%
df['timestamp']
# Out:
# 0         2023-04-28 10:06:54
# 1         2023-04-28 10:26:55
# 2         2023-04-28 10:28:55
# 3         2023-04-28 10:31:10
# 4         2023-04-28 10:32:54
#                   ...
# 2071400   2022-03-23 09:42:30
# 2071401   2022-03-23 09:57:36
# 2071402   2022-03-23 10:13:06
# 2071403   2022-03-23 10:28:10
# 2071404   2022-03-23 10:43:05
# Name: timestamp, Length: 2071405, dtype: datetime64[ns]

# %%
df['location-lat'].head()
# Out:
# 0    37.427571
# 1    37.429683
# 2    37.429824
# 3    37.429808
# 4    37.429709
# Name: location-lat, dtype: float64

# %%
df = df[['epoch','timestamp','location-long','location-lat','height-above-msl']]

# %%
df.head()
# Out:
#         epoch           timestamp  location-long  location-lat  \
# 0  1682676414 2023-04-28 10:06:54      -6.470255     37.427571
# 1  1682677615 2023-04-28 10:26:55      -6.477722     37.429683
# 2  1682677735 2023-04-28 10:28:55      -6.478029     37.429824
# 3  1682677870 2023-04-28 10:31:10      -6.477894     37.429808
# 4  1682677974 2023-04-28 10:32:54      -6.477960     37.429709
#
#    height-above-msl
# 0            165.70
# 1            167.82
# 2            121.71
# 3            128.60
# 4            129.25

# %% [markdown]
# # Visualizations and EDA

# %%
import pandas as pd
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature

# Create the plot
fig = plt.figure(figsize=(12, 10))
ax = plt.axes(projection=ccrs.PlateCarree())

# Add ocean with light blue color
ax.add_feature(cfeature.OCEAN, color='lightblue')

# Add country borders and coastlines
ax.add_feature(cfeature.BORDERS, linestyle='-', linewidth=1)
ax.add_feature(cfeature.COASTLINE)

# Plot the points
plt.scatter(df['location-long'], df['location-lat'], color='red', s=10, transform=ccrs.PlateCarree())

# Add labels for the points
for x, y in zip(df['location-long'], df['location-lat']):
    plt.text(x, y, '', fontsize=12, ha='right', transform=ccrs.PlateCarree())

# Set the title
plt.title('White storks Migration between '+ts1+ ' and '+ts2+'')
plt.xlabel('Longitude')
plt.ylabel('Latitude')

# Add gridlines with labels in simple format
gl = ax.gridlines(draw_labels=True, x_inline=False, y_inline=False)
gl.top_labels = False
gl.right_labels = False

gl.xlocator = plt.MaxNLocator(integer=True)
gl.ylocator = plt.MaxNLocator(integer=True)

gl.xlabel_style = {'size': 15}
gl.ylabel_style = {'size': 15}

# Zoom out by setting extent
lon_min, lon_max = df['location-long'].min() - 2, df['location-long'].max() + 2
lat_min, lat_max = df['location-lat'].min() - 2, df['location-lat'].max() + 2
ax.set_extent([lon_min, lon_max, lat_min, lat_max], crs=ccrs.PlateCarree())

# Show the plot
plt.show()

# %%
fig.savefig('3_Sample_migration.png', dpi=300, bbox_inches='tight')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
file_path = 'white_storks_sample.csv'  # Adjust the file path as needed
df = pd.read_csv(file_path)

# Set up the matplotlib figure
fig, axes = plt.subplots(2, 2, figsize=(16, 12))

# Plot for epoch
sns.histplot(df['epoch'], bins=30,color='coral', kde=True, ax=axes[0, 0])
axes[0, 0].set_title('Epoch Distribution')
axes[0, 0].set_xlabel('Epoch')
axes[0, 0].set_ylabel('Frequency')

# Plot for location-long (Longitude)
sns.histplot(df['location-long'], bins=30,color='coral', kde=True, ax=axes[0, 1])
axes[0, 1].set_title('Longitude Distribution')
axes[0, 1].set_xlabel('Longitude')
axes[0, 1].set_ylabel('Frequency')

# Plot for location-lat (Latitude)
sns.histplot(df['location-lat'], bins=30,color='coral', kde=True, ax=axes[1, 0])
axes[1, 0].set_title('Latitude Distribution')
axes[1, 0].set_xlabel('Latitude')
axes[1, 0].set_ylabel('Frequency')

# Plot for height-above-msl
sns.histplot(df['height-above-msl'], bins=30,color='coral', kde=True, ax=axes[1, 1])
axes[1, 1].set_title('Height Above Mean Sea Level Distribution')
axes[1, 1].set_xlabel('Height Above Mean Sea Level')
axes[1, 1].set_ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
fig.savefig('3_distributions.png')

# %%
# Sort the dataframe by epoch in ascending order
df_sorted = df.sort_values(by='epoch').reset_index(drop=True)

# Calculate the delta time in seconds using the epoch column
df_sorted['delta'] = df_sorted['epoch'].diff()/1000

# Set the first delta value to 0
df_sorted.loc[0, 'delta'] = 0

# %%
df_sorted.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0       epoch            timestamp  location-long  \
# 0             0           0  1329184844  2012-02-14 02:00:44      36.701858
# 1             1           1  1329185110  2012-02-14 02:05:10      36.701850
# 2             2           2  1329185412  2012-02-14 02:10:12      36.701815
# 3             3           3  1329185711  2012-02-14 02:15:11      36.701855
# 4             4           4  1329186010  2012-02-14 02:20:10      36.701822
#
#    location-lat  height-above-ellipsoid  height-above-msl  delta
# 0      3.985513                   670.0             670.0  0.000
# 1      3.985472                   667.9             667.9  0.266
# 2      3.985495                   668.8             668.8  0.302
# 3      3.985515                   666.7             666.7  0.299
# 4      3.985484                   667.6             667.6  0.299

# %%
# Display the summary statistics
print("Summary Statistics for Delta Time:")
print(df_sorted["delta"].describe())
# Out:
# Summary Statistics for Delta Time:
# count    5000.000000
# mean        0.442254
# std         1.760448
# min         0.000000
# 25%         0.299000
# 50%         0.300000
# 75%         0.301000
# max        25.246000
# Name: delta, dtype: float64

# %%
# Calculate the first and third quartiles (Q1, Q3) and IQR
Q1 = df_sorted['delta'].quantile(0.25)
Q3 = df_sorted['delta'].quantile(0.75)
IQR = Q3 - Q1

# Define the lower and upper bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Filter out the outliers
df_pruned = df_sorted[(df_sorted['delta'] >= lower_bound) & (df_sorted['delta'] <= upper_bound)]

# %%
# Plot the distribution of the pruned delta with grid
fig1 = plt.figure(figsize=(6, 6))
#plt.figure(figsize=(10, 6))
sns.histplot(df_pruned['delta'], bins=100,color='coral', kde=True)
plt.title('Distribution of Pruned Delta Time')
plt.xlabel('Delta Time')
plt.ylabel('Frequency')
#plt.xlim(0, df_pruned['delta'].max())
plt.grid(True)
plt.show()

# %%
fig1.savefig('3_distributions_delta_epoch.png')

# %%
import numpy as np
# Haversine formula to calculate the horizontal distance between two points on the Earth
def haversine(lat1, lon1, lat2, lon2):
    R = 6371.0  # Radius of the Earth in kilometers
    phi1 = np.radians(lat1)
    phi2 = np.radians(lat2)
    delta_phi = np.radians(lat2 - lat1)
    delta_lambda = np.radians(lon2 - lon1)
    
    a = np.sin(delta_phi / 2.0) ** 2 + \
        np.cos(phi1) * np.cos(phi2) * \
        np.sin(delta_lambda / 2.0) ** 2
    
    c = 2 * np.arctan2(np.sqrt(a), np.sqrt(1 - a))
    
    distance = R * c * 1000  # Convert distance to meters
    return distance

# Function to calculate 3D distance 
def calculate_3d_distance(lat1, lon1, msl1, lat2, lon2, msl2):
    horizontal_distance = haversine(lat1, lon1, lat2, lon2)
    vertical_distance = msl2 - msl1
    distance_3d = np.sqrt(horizontal_distance**2 + vertical_distance**2)
    return distance_3d

# Calculate the 3D distance between each record and the previous one
df_sorted['distance'] = df_sorted.apply(
    lambda row: calculate_3d_distance(
        df_sorted.loc[row.name - 1, 'location-lat'], df_sorted.loc[row.name - 1, 'location-long'], df_sorted.loc[row.name - 1, 'height-above-msl'],
        row['location-lat'], row['location-long'], row['height-above-msl']
    ) if row.name > 0 else 0,
    axis=1
)

# %%
# Calculate the first and third quartiles (Q1, Q3) and IQR for the distance column
Q1_distance = df_sorted['distance'].quantile(0.25)
Q3_distance = df_sorted['distance'].quantile(0.75)
IQR_distance = Q3_distance - Q1_distance

# Define the lower and upper bounds for outliers
lower_bound_distance = Q1_distance - 1.5 * IQR_distance
upper_bound_distance = Q3_distance + 1.5 * IQR_distance

# Filter out the outliers
df_pruned_distance = df_sorted[(df_sorted['distance'] >= lower_bound_distance) & (df_sorted['distance'] <= upper_bound_distance)]

# Plot the distribution of the pruned 3D distances
plt.figure(figsize=(10, 6))
sns.histplot(df_pruned_distance['distance'], bins=100, color='coral',kde=True)
plt.title('Distribution of Pruned 3D Haversine Distances')
plt.xlabel('Distance (meters)')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
# Convert timestamp column to datetime
df['timestamp'] = pd.to_datetime(df['timestamp'], errors='coerce')

# Sort the dataframe by timestamp in ascending order
df_sorted = df.sort_values(by='timestamp').reset_index(drop=True)

# Define the sliding window and overlap in seconds
window_size = 60 * 60  # 10 minutes in seconds
overlap_size = 20 * 60  # 2 minutes in seconds

# Lists to hold the number of records in each window and overlap window
window_counts = []
overlap_counts = []

# Iterate through the data in sliding windows
start_time = df_sorted['timestamp'].min()
end_time = df_sorted['timestamp'].max()

while start_time <= end_time:
    window_end_time = start_time + pd.Timedelta(seconds=window_size)
    overlap_end_time = start_time + pd.Timedelta(seconds=overlap_size)

    # Number of records in the current window
    window_count = df_sorted[(df_sorted['timestamp'] >= start_time) & (df_sorted['timestamp'] < window_end_time)].shape[0]
    window_counts.append(window_count)

    # Number of records in the overlap window
    overlap_count = df_sorted[(df_sorted['timestamp'] >= start_time) & (df_sorted['timestamp'] < overlap_end_time)].shape[0]
    overlap_counts.append(overlap_count)

    # Move to the next window start time
    start_time = start_time + pd.Timedelta(seconds=window_size)

# Create a time axis for the x-axis
time_axis = [df_sorted['timestamp'].min() + pd.Timedelta(seconds=window_size * i) for i in range(len(window_counts))]

# Plot the results
fig9 = plt.figure(figsize=(14, 7))
plt.plot(time_axis, window_counts, label='Number of Records in 60-Minute Window', color='red')
plt.plot(time_axis, overlap_counts, label='Number of Records in 20-Minute Overlap Window', color='orange')
plt.title('Number of Records in Sliding Windows and Overlap Windows')
plt.xlabel('Time')
plt.ylabel('Number of Records')
plt.legend()
plt.grid(True)
plt.show()

# %%
# first 50 windows

# Convert timestamp column to datetime
df['timestamp'] = pd.to_datetime(df['timestamp'], errors='coerce')

# Sort the dataframe by timestamp in ascending order
df_sorted = df.sort_values(by='timestamp').reset_index(drop=True)

# Define the sliding window and overlap in seconds
window_size = 20 * 60  # 10 minutes in seconds
overlap_size = 6 * 60  # 2 minutes in seconds

# Lists to hold the number of records in each window and overlap window
window_counts = []
overlap_counts = []

# Iterate through the data in sliding windows
start_time = df_sorted['timestamp'].min()
end_time = df_sorted['timestamp'].max()

# Initialize a counter for windows
window_counter = 0

while start_time <= end_time and window_counter < 100:
    window_end_time = start_time + pd.Timedelta(seconds=window_size)
    overlap_end_time = start_time + pd.Timedelta(seconds=overlap_size)

    # Number of records in the current window
    window_count = df_sorted[(df_sorted['timestamp'] >= start_time) & (df_sorted['timestamp'] < window_end_time)].shape[0]
    window_counts.append(window_count)

    # Number of records in the overlap window
    overlap_count = df_sorted[(df_sorted['timestamp'] >= start_time) & (df_sorted['timestamp'] < overlap_end_time)].shape[0]
    overlap_counts.append(overlap_count)

    # Move to the next window start time
    start_time = start_time + pd.Timedelta(seconds=window_size)
    window_counter += 1

# Create a time axis for the x-axis
time_axis = [df_sorted['timestamp'].min() + pd.Timedelta(seconds=window_size * i) for i in range(len(window_counts))]

# Plot the results
fig9 = plt.figure(figsize=(14, 7))
plt.plot(time_axis, window_counts, label='Number of Records in 60-Minute Window', color='red')
plt.plot(time_axis, overlap_counts, label='Number of Records in 20-Minute Overlap Window', color='orange')
plt.title('Number of Records in Sliding Windows and Overlap Windows')
plt.xlabel('Time')
plt.ylabel('Number of Records')
plt.legend()
plt.grid(True)
plt.show()

# %%
fig9.savefig('3_Number of Records in Sliding Windows and Overlap Windows.png', dpi=300, bbox_inches='tight')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from math import radians, cos, sin, asin, sqrt
import itertools

def haversine(lonlat1, lonlat2):
    lon1, lat1, alt1 = lonlat1
    lon2, lat2, alt2 = lonlat2
    
    lon1, lat1, lon2, lat2 = map(radians, [lon1, lat1, lon2, lat2])
    
    dlon = lon2 - lon1
    dlat = lat2 - lat1
    a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
    c = 2 * asin(sqrt(a))
    
    r = 6371000
    return (c * r) + abs(alt1 - alt2)

def average_distance(coords):
    if len(coords) < 2:
        return 0
    distances = [haversine(p1, p2) for p1, p2 in itertools.combinations(coords, 2)]
    return np.mean(distances)

# Load the dataset
file_path = 'white_storks_sample.csv'  # Adjust the file path as needed
df = pd.read_csv(file_path)

# Convert timestamp column to datetime
df['timestamp'] = pd.to_datetime(df['timestamp'], errors='coerce')

# Sort the dataframe by timestamp in ascending order
df_sorted = df.sort_values(by='timestamp').reset_index(drop=True)

# Define the sliding window and overlap in seconds
window_size = 60 * 60  # 10 minutes in seconds
overlap_size = 20 * 60  # 2 minutes in seconds

# Lists to hold the average distances in each window and overlap window
window_avg_distances = []
overlap_avg_distances = []

# Iterate through the data in sliding windows
start_time = df_sorted['timestamp'].min()
end_time = df_sorted['timestamp'].max()

while start_time <= end_time:
    window_end_time = start_time + pd.Timedelta(seconds=window_size)
    overlap_end_time = start_time + pd.Timedelta(seconds=overlap_size)

    # Points in the current window
    window_df = df_sorted[(df_sorted['timestamp'] >= start_time) & (df_sorted['timestamp'] < window_end_time)]
    window_coords = window_df[['location-long', 'location-lat', 'height-above-msl']].values
    window_avg_distance = average_distance(window_coords)
    window_avg_distances.append(window_avg_distance)

    # Points in the overlap window
    overlap_df = df_sorted[(df_sorted['timestamp'] >= start_time) & (df_sorted['timestamp'] < overlap_end_time)]
    overlap_coords = overlap_df[['location-long', 'location-lat', 'height-above-msl']].values
    overlap_avg_distance = average_distance(overlap_coords)
    overlap_avg_distances.append(overlap_avg_distance)

    # Move to the next window start time
    start_time = start_time + pd.Timedelta(seconds=window_size)

# Ensure both lists are of the same size by appending zeros to the smaller list
max_length = max(len(window_avg_distances), len(overlap_avg_distances))
while len(window_avg_distances) < max_length:
    window_avg_distances.append(0)
while len(overlap_avg_distances) < max_length:
    overlap_avg_distances.append(0)

# Create a time axis for the x-axis
time_axis = [df_sorted['timestamp'].min() + pd.Timedelta(seconds=window_size * i) for i in range(max_length)]

# Plot the results
fig10 = plt.figure(figsize=(14, 7))
plt.plot(time_axis, window_avg_distances, label='Median Distance in 60-Minute Window', color='red')
plt.plot(time_axis, overlap_avg_distances, label='Median Distance in 20-Minute Overlap Window', color='orange')
plt.title('Median Distances in Sliding Windows and Overlap Windows')
plt.xlabel('Time')
plt.ylabel('Median Distance (kilometers)')
#plt.ylim(0, 50000)  # Set y-axis limit to 50000 meters
plt.legend()
plt.grid(True)
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from math import radians, cos, sin, asin, sqrt
import itertools

def haversine(lonlat1, lonlat2):
    lon1, lat1, alt1 = lonlat1
    lon2, lat2, alt2 = lonlat2
    
    lon1, lat1, lon2, lat2 = map(radians, [lon1, lat1, lon2, lat2])
    
    dlon = lon2 - lon1
    dlat = lat2 - lat1
    a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
    c = 2 * asin(sqrt(a))
    
    r = 6371000
    return c * r + abs(alt1 - alt2)

def average_distance(coords):
    if len(coords) < 2:
        return 0
    distances = [haversine(p1, p2) for p1, p2 in itertools.combinations(coords, 2)]
    return np.mean(distances)

# Load the dataset
file_path = 'white_storks_sample.csv'  # Adjust the file path as needed
df = pd.read_csv(file_path)

# Convert timestamp column to datetime
df['timestamp'] = pd.to_datetime(df['timestamp'], errors='coerce')

# Sort the dataframe by timestamp in ascending order
df_sorted = df.sort_values(by='timestamp').reset_index(drop=True)

# Define the sliding window and overlap in seconds
window_size = 60 * 60  # 10 minutes in seconds
overlap_size = 20 * 60  # 2 minutes in seconds

# Lists to hold the average distances in each window and overlap window
window_avg_distances = []
overlap_avg_distances = []

# Iterate through the data in sliding windows
start_time = df_sorted['timestamp'].min()
end_time = df_sorted['timestamp'].max()

# Initialize a counter for windows
window_counter = 0

while start_time <= end_time and window_counter < 100:
    window_end_time = start_time + pd.Timedelta(seconds=window_size)
    overlap_end_time = start_time + pd.Timedelta(seconds=overlap_size)

    # Points in the current window
    window_df = df_sorted[(df_sorted['timestamp'] >= start_time) & (df_sorted['timestamp'] < window_end_time)]
    window_coords = window_df[['location-long', 'location-lat', 'height-above-msl']].values
    window_avg_distance = average_distance(window_coords)
    window_avg_distances.append(window_avg_distance)

    # Points in the overlap window
    overlap_df = df_sorted[(df_sorted['timestamp'] >= start_time) & (df_sorted['timestamp'] < overlap_end_time)]
    overlap_coords = overlap_df[['location-long', 'location-lat', 'height-above-msl']].values
    overlap_avg_distance = average_distance(overlap_coords)
    overlap_avg_distances.append(overlap_avg_distance)

    # Move to the next window start time
    start_time = start_time + pd.Timedelta(seconds=window_size)
    window_counter += 1

# Ensure both lists are of the same size by appending zeros to the smaller list
max_length = max(len(window_avg_distances), len(overlap_avg_distances))
while len(window_avg_distances) < max_length:
    window_avg_distances.append(0)
while len(overlap_avg_distances) < max_length:
    overlap_avg_distances.append(0)

# Create a time axis for the x-axis
time_axis = [df_sorted['timestamp'].min() + pd.Timedelta(seconds=window_size * i) for i in range(max_length)]

# Plot the results
fig10 = plt.figure(figsize=(14, 7))
plt.plot(time_axis, window_avg_distances, label='Median Distance in 60-Minute Window', color='red')
plt.plot(time_axis, overlap_avg_distances, label='Median Distance in 20-Minute Overlap Window', color='orange')
plt.title('Median Distances in Sliding Windows and Overlap Windows')
plt.xlabel('Time')
plt.ylabel('Median Distance (meters)')
#plt.ylim(0, 2700)  # Set y-axis limit to 50000 meters
plt.legend()
plt.grid(True)
plt.show()

# %%
fig10.savefig('3_Number of Records in Sliding Windows and Overlap Windows_blue.png', dpi=300, bbox_inches='tight')

# %%
# Plot the results
fig11 = plt.figure(figsize=(14, 7))
plt.plot(time_axis, window_avg_distances, label='Average Distance in 10-Minute Window', color='red')
plt.plot(time_axis, overlap_avg_distances, label='Average Distance in 2-Minute Overlap Window', color='orange')
plt.title('Average Distances in Sliding Windows and Overlap Windows')
plt.xlabel('Time')
plt.ylabel('Average Distance (meters)')
#plt.ylim(0, 2000)  # Set y-axis limit to 50000 meters
plt.legend()
plt.grid(True)
plt.show()

# %%
fig11.savefig('3_Number of Records in Sliding Windows and Overlap Windows_yellow.png', dpi=300, bbox_inches='tight')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Function to calculate the number of overlap windows with zero points
def calculate_overlap_windows_with_zero_points(df, data_start, data_end, window_size, step_size):
    num_windows_with_zero_points = 0
    current_start = data_start
    while current_start + window_size <= data_end:
        window_end = current_start + window_size
        window_df = df[(df['timestamp'] >= current_start) & (df['timestamp'] < window_end)]
        if window_df.empty:
            num_windows_with_zero_points += 1
        current_start += step_size
    return num_windows_with_zero_points

# Define the window and overlap sizes in minutes
window_sizes = [10, 15, 20, 30, 40, 50, 60,80,100,120,150]  # in minutes
overlap_sizes = [2, 3.5, 5, 7.5, 10, 15, 20,20,25,30,40]  # in minutes

# Convert minutes to seconds
window_sizes_seconds = [ws * 60 for ws in window_sizes]
overlap_sizes_seconds = [os * 60 for os in overlap_sizes]

# Load the dataset
file_path = 'white_storks_sample.csv'  # Adjust the file path as needed
df = pd.read_csv(file_path)

# Convert timestamp column to datetime
df['timestamp'] = pd.to_datetime(df['timestamp'], errors='coerce')

# Get the start and end times from the dataset
data_start = df['timestamp'].min()
data_end = df['timestamp'].max()

# Calculate the number of overlap windows with zero points for each window and overlap size
zero_point_windows = []
for ws, os in zip(window_sizes_seconds, overlap_sizes_seconds):
    step_size = ws - os
    num_zero_point_windows = calculate_overlap_windows_with_zero_points(df, data_start, data_end, pd.Timedelta(seconds=ws), pd.Timedelta(seconds=step_size))
    zero_point_windows.append(num_zero_point_windows)

# Plot the results
figure_knee = plt.figure(figsize=(10, 6))
plt.plot(window_sizes, zero_point_windows, marker='o', linestyle='-', color='r')
plt.title('Number of Overlapping Windows with Zero Points')
plt.xlabel('Window Size (minutes)')
plt.ylabel('Number of Overlap Windows with Zero Points')
plt.grid(True)
plt.show()

# %%
figure_knee.savefig('3_win_size_knee.png', dpi=300, bbox_inches='tight')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from math import radians, cos, sin, asin, sqrt
import itertools

def haversine(lonlat1, lonlat2):
    lon1, lat1, alt1 = lonlat1
    lon2, lat2, alt2 = lonlat2
    
    lon1, lat1, lon2, lat2 = map(radians, [lon1, lat1, lon2, lat2])
    
    dlon = lon2 - lon1
    dlat = lat2 - lat1
    a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
    c = 2 * asin(sqrt(a))
    
    r = 6371000  # Radius of Earth in meters
    distance = c * r
    
    alt_diff = abs(alt1 - alt2)
    
    return np.sqrt(distance**2 + alt_diff**2)

def calculate_median_distance(coords):
    if len(coords) < 2:
        return 0
    distances = [haversine(p1, p2) for p1, p2 in itertools.combinations(coords, 2)]
    return np.median(distances)

# Load the dataset
file_path = 'white_storks_sample.csv'  # Adjust the file path as needed
df = pd.read_csv(file_path)

# Convert timestamp column to datetime
df['timestamp'] = pd.to_datetime(df['timestamp'], errors='coerce')

# Sort the dataframe by timestamp in ascending order
df_sorted = df.sort_values(by='timestamp').reset_index(drop=True)

# Define the sliding window and step size in seconds
window_size = 60 * 60  # 10 minutes in seconds
step_size = 20 * 60  # 2 minutes in seconds

# Lists to hold the median distances and corresponding times
median_distances = []
time_labels = []

# Iterate through the data in sliding windows
start_time = df_sorted['timestamp'].min()
end_time = df_sorted['timestamp'].max()

while start_time <= end_time:
    window_end_time = start_time + pd.Timedelta(seconds=window_size)
    window_df = df_sorted[(df_sorted['timestamp'] >= start_time) & (df_sorted['timestamp'] < window_end_time)]
    
    if len(window_df) > 1:
        coords = window_df[['location-long', 'location-lat', 'height-above-msl']].values
        median_distance = calculate_median_distance(coords)
        median_distances.append(median_distance)
        time_labels.append(start_time)
    
    # Move to the next window start time
    start_time = start_time + pd.Timedelta(seconds=step_size)

# Plot the results
plt.figure(figsize=(10, 6))
plt.plot(time_labels, median_distances, marker='o', linestyle='-', color='r')
plt.title('Median Distance Between Points in Each Window')
plt.xlabel('Time')
plt.ylabel('Median Distance (meters)')
plt.ylim(0, 1000)  # Set y-axis limit to 50000 meters
plt.grid(True)
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from math import radians, cos, sin, asin, sqrt
import itertools

def haversine(lonlat1, lonlat2):
    lon1, lat1, alt1 = lonlat1
    lon2, lat2, alt2 = lonlat2
    
    lon1, lat1, lon2, lat2 = map(radians, [lon1, lat1, lon2, lat2])
    
    dlon = lon2 - lon1
    dlat = lat2 - lat1
    a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
    c = 2 * asin(sqrt(a))
    
    r = 6371000  # Radius of Earth in meters
    distance = c * r
    
    alt_diff = abs(alt1 - alt2)
    
    return np.sqrt(distance**2 + alt_diff**2)

def calculate_median_distance(coords):
    if len(coords) < 2:
        return 0
    distances = [haversine(p1, p2) for p1, p2 in itertools.combinations(coords, 2)]
    return np.median(distances)

# Load the dataset
file_path = 'white_storks_sample.csv'  # Adjust the file path as needed
df = pd.read_csv(file_path)

# Convert timestamp column to datetime
df['timestamp'] = pd.to_datetime(df['timestamp'], errors='coerce')

# Sort the dataframe by timestamp in ascending order
df_sorted = df.sort_values(by='timestamp').reset_index(drop=True)

# Define the sliding window and step size in seconds
window_size = 60 * 60  # 60 minutes in seconds
step_size = 20 * 60  # 20 minutes in seconds

# Lists to hold the median distances and corresponding times
median_distances = []
time_labels = []

# Iterate through the data in sliding windows
start_time = df_sorted['timestamp'].min()
end_time = df_sorted['timestamp'].max()

# Initialize a counter for windows
window_counter = 0

while start_time <= end_time and window_counter < 250:
    window_end_time = start_time + pd.Timedelta(seconds=window_size)
    window_df = df_sorted[(df_sorted['timestamp'] >= start_time) & (df_sorted['timestamp'] < window_end_time)]
    
    if len(window_df) > 1:
        coords = window_df[['location-long', 'location-lat', 'height-above-msl']].values
        median_distance = calculate_median_distance(coords)
        median_distances.append(median_distance)
        time_labels.append(start_time)
    
    # Move to the next window start time
    start_time = start_time + pd.Timedelta(seconds=step_size)
    
    # Increment the window counter
    window_counter += 1

# Plot the results
plt.figure(figsize=(10, 6))
plt.plot(time_labels, median_distances, marker='o', linestyle='-', color='r')
plt.title('Median Distance Between Points in Each Window (first 250 windows)')
plt.xlabel('Time')
plt.ylabel('Median Distance (meters)')
#plt.ylim(0, 1000)  # Set y-axis limit to 1000 meters
plt.grid(True)
plt.show()

# %%
plt.savefig('median_distance_between_points.png', dpi=300, bbox_inches='tight')

# %%
figure_eps.savefig('figure_eps.png', dpi=300, bbox_inches='tight')

# %% [markdown]
# # Running the Algorithm

# %%
import pandas as pd
import numpy as np
from sklearn.cluster import DBSCAN
from sklearn.metrics import silhouette_score, davies_bouldin_score, calinski_harabasz_score
from geopy.distance import geodesic
import itertools

# Load the dataset
file_path = 'white_storks_sample.csv'  # Adjust the file path as needed
df = pd.read_csv(file_path)

# Convert timestamp column to datetime
df['timestamp'] = pd.to_datetime(df['timestamp'], errors='coerce')

# Sort the dataframe by timestamp in ascending order
df_sorted = df.sort_values(by='timestamp').reset_index(drop=True)


def haversine(coord1, coord2):
    """
    Calculate the haversine distance between two coordinates, including altitude.
    """
    lon1, lat1, alt1 = coord1
    lon2, lat2, alt2 = coord2
    
    # Haversine distance
    r = 6371000  # Radius of Earth in meters
    phi1, phi2 = np.radians(lat1), np.radians(lat2)
    delta_phi = np.radians(lat2 - lat1)
    delta_lambda = np.radians(lon2 - lon1)
    a = np.sin(delta_phi / 2) ** 2 + np.cos(phi1) * np.cos(phi2) * np.sin(delta_lambda / 2) ** 2
    c = 2 * np.arctan2(np.sqrt(a), np.sqrt(1 - a))
    distance = r * c
    
    # Add altitude difference
    alt_diff = abs(alt1 - alt2)
    
    return np.sqrt(distance**2 + alt_diff**2)

def calculate_centroid(points):
    """
    Calculate the centroid of a cluster of points.
    """
    mn = np.mean(points, axis=0)
    #print("centroid = ", mn)
    return mn

def get_max_dist_in_cluster(cluster):
    max_dist_in_cluster = 0
    for p1, p2 in itertools.combinations(cluster[['location-long', 'location-lat', 'height-above-msl']].values, 2):
        dist = haversine(p1, p2)
        max_dist_in_cluster = max(max_dist_in_cluster, dist)
        #print(f"Distance between points {p1} and {p2}: {dist} meters")
    return max_dist_in_cluster

def get_min_dist_in_cluster(cluster):
    min_dist_in_cluster = 0
    for p1, p2 in itertools.combinations(cluster[['location-long', 'location-lat', 'height-above-msl']].values, 2):
        dist = haversine(p1, p2)
        min_dist_in_cluster = min(min_dist_in_cluster, dist)
        #print(f"Distance between points {p1} and {p2}: {dist} meters")
    return min_dist_in_cluster

def process_window(df_window, initial_eps=200,withDynamicEPS=True):
    """
    Process a data window using DBSCAN clustering.
    Adjust the eps parameter until the condition is met and calculate metrics for each cluster.
    """
    curr_eps = initial_eps
    min_dist_between_centroids = np.inf
    min_dist_between_points =  np.inf
    
    while True:
        # Perform DBSCAN clustering
        db = DBSCAN(eps=curr_eps, min_samples=3, metric=lambda a, b: haversine(a[:3], b[:3])).fit(df_window[['location-long', 'location-lat', 'height-above-msl']])
        labels = db.labels_
        unique_labels = set(labels)
        #print(unique_labels)
        
        # If there is only one label and it's -1 (noise), return an empty DataFrame
        if len(unique_labels) == 1 and -1 in unique_labels:
            return pd.DataFrame(), curr_eps
        
        # Calculate centroids of clusters
        cluster_points = [df_window[labels == label] for label in unique_labels if label != -1]
        centroids = [calculate_centroid(cluster[['location-long', 'location-lat', 'height-above-msl']].values) for cluster in cluster_points]

        #min_dist_between_centroids = np.inf
        #min_dist_between_points = np.inf
        
        # Calculate the minimum distance between centroids of closest clusters
        for i, j in itertools.combinations(range(len(centroids)), 2):
            dist = haversine(centroids[i], centroids[j])
            #print("dist ",dist)
            if dist < min_dist_between_centroids:
                min_dist_between_centroids = dist
        #print("min_dist_between_centroids ",min_dist_between_centroids)
        
        # Calculate the minimum distance between the closest points of the clusters
        for cluster1, cluster2 in itertools.combinations(cluster_points, 2):
            for p1 in cluster1[['location-long', 'location-lat', 'height-above-msl']].values:
                for p2 in cluster2[['location-long', 'location-lat', 'height-above-msl']].values:
                    dist = haversine(p1, p2)
                    #print("dist ",dist)
                    if dist < min_dist_between_points:
                        min_dist_between_points = dist
        #print("min_dist_between_points ",min_dist_between_points)
        
        # If the condition is met, calculate metrics and return the results
        #if max_dist_in_smallest_cluster < min_dist_between_clusters:
        if min_dist_between_points <= min_dist_between_centroids or withDynamicEPS == False:
            if min_dist_between_centroids != np.inf:
                curr_eps = min_dist_between_centroids
            #print(curr_eps)
            #print("min_dist_between_points", min_dist_between_points)
            #print("min_dist_between_centroids ",min_dist_between_centroids)
            result = []
            for cluster_label in unique_labels:
                #print(cluster_label)
                #if cluster_label == -1:
                #    continue
                cluster_df = df_window[labels == cluster_label]
                
                #print("len(centroids): ", len(centroids))
                #print("len ",len(cluster_df))
                silhouette_avg = silhouette_score(df_window[['location-long', 'location-lat', 'height-above-msl']], labels) if len(set(labels)) > 1 else -1
                davies_bouldin = davies_bouldin_score(df_window[['location-long', 'location-lat', 'height-above-msl']], labels) if len(set(labels)) > 1 else -1
                calinski_harabasz = calinski_harabasz_score(df_window[['location-long', 'location-lat', 'height-above-msl']], labels) if len(set(labels)) > 1 else -1
                #min_dist_to_closest_cluster = min_dist_between_points
                max_dist_in_cluster = get_max_dist_in_cluster(cluster_df)
                min_dist_in_cluster = get_min_dist_in_cluster(cluster_df)
                first_timestamp = cluster_df['timestamp'].min()
                last_timestamp = cluster_df['timestamp'].max()
                cluster_size = len(cluster_df)
                points = cluster_df[['epoch','location-long', 'location-lat', 'height-above-msl']].values.tolist()
                
                result.append({
                    'cluster_label': cluster_label,
                    'silhouette_score': silhouette_avg,
                    'davies_bouldin_score': davies_bouldin,
                    'calinski_harabasz_score': calinski_harabasz,
                    'clusters_in_window': len(unique_labels),
                    'win_eps': curr_eps,
                    'min_dist_between_points': min_dist_between_points,
                    'min_dist_between_centroids':min_dist_between_centroids,
                    'max_dist_in_cluster': max_dist_in_cluster,
                    'min_dist_in_cluster': min_dist_in_cluster,
                    'first_timestamp': first_timestamp,
                    'last_timestamp': last_timestamp,
                    'win_number': None,  # This will be updated later
                    'cluster_size': cluster_size,
                    'points': points
                })
                #min_dist_between_centroids = np.inf
                #min_dist_between_points = np.inf 
           
            return pd.DataFrame(result),curr_eps
        
        # Reduce the eps value by 10% and rerun DBSCAN
        if withDynamicEPS:
            curr_eps *= 0.9
        #print(curr_eps)

    return pd.DataFrame(result),curr_eps

# Initialize dataframe to hold the results
all_clusters = pd.DataFrame()

# Iterate through the data in sliding windows
window_number = 0
start_time = df_sorted['timestamp'].min()
end_time = df_sorted['timestamp'].max()
curr_eps = 200
# Define the sliding window and overlap in seconds
window_size = 60 * 60  # 60 minutes in seconds
step_size = 20 * 60  # 20 minutes in seconds

print("------------starting DBSCAN windows process:------------")

while start_time >= end_time:
    window_end_time = start_time + pd.Timedelta(seconds=window_size)
    window_df = df_sorted[(df_sorted['timestamp'] >= start_time) & (df_sorted['timestamp'] < window_end_time)]
    #print(f"Processing window {window_number}: Start Time = {start_time}, End Time = {window_end_time}, Points in Window = {len(window_df)}")
    
    # Process the window if it has more than one point
    if len(window_df) > 1:
        clusters_df,curr_eps = process_window(window_df,200,True)
        clusters_df['win_number'] = window_number
        clusters_df['Selected EPS'] = curr_eps
        all_clusters = pd.concat([all_clusters, clusters_df], ignore_index=True)
    
    # Move to the next window start time
    start_time = start_time + pd.Timedelta(seconds=step_size)
    window_number += 1

#print(all_clusters)
# Out:
# ------------starting DBSCAN windows process:------------

# %%
# Initialize dataframe to hold the results
all_clusters_no_overlap_static_eps = pd.DataFrame()

# Iterate through the data in sliding windows
window_number = 0
start_time = df_sorted['timestamp'].min()
end_time = df_sorted['timestamp'].max()
curr_eps = 200
# Define the sliding window and overlap in seconds
window_size = 60 * 60  # 60 minutes in seconds
step_size = 20 * 60  # 20 minutes in seconds

print("------------starting DBSCAN windows process:------------")

while start_time <= end_time:
    window_end_time = start_time + pd.Timedelta(seconds=window_size)
    window_df = df_sorted[(df_sorted['timestamp'] >= start_time) & (df_sorted['timestamp'] < window_end_time)]
    #print(f"Processing window {window_number}: Start Time = {start_time}, End Time = {window_end_time}, Points in Window = {len(window_df)}")
    
    # Process the window if it has more than one point
    if len(window_df) > 1:
        clusters_df,curr_eps = process_window(window_df,200,False)
        clusters_df['win_number'] = window_number
        clusters_df['Selected EPS'] = curr_eps
        all_clusters_no_overlap_static_eps = pd.concat([all_clusters_no_overlap_static_eps, clusters_df], ignore_index=True)
    
    # Move to the next window start time
    start_time = start_time + pd.Timedelta(seconds=step_size)
    window_number += 1

#print(all_clusters)
all_clusters_no_overlap_static_eps.to_csv("clusters_file3_no_overlap_static_eps.csv")
# Out:
# ------------starting DBSCAN windows process:------------

# %%
all_clusters_no_overlap_static_eps
# Out:
#       cluster_label  silhouette_score  davies_bouldin_score  \
# 0               0.0         -1.000000             -1.000000
# 1               0.0         -1.000000             -1.000000
# 2               0.0          0.444837              0.781818
# 3              -1.0          0.444837              0.781818
# 4               0.0          0.165156              1.316659
# ...             ...               ...                   ...
# 1277            0.0         -1.000000             -1.000000
# 1278            0.0         -1.000000             -1.000000
# 1279            0.0         -1.000000             -1.000000
# 1280            0.0         -1.000000             -1.000000
# 1281            0.0         -1.000000             -1.000000
#
#       calinski_harabasz_score  clusters_in_window      win_eps  \
# 0                   -1.000000                 1.0   200.000000
# 1                   -1.000000                 1.0   200.000000
# 2                    6.808653                 2.0   200.000000
# 3                    6.808653                 2.0   200.000000
# 4                    8.680263                 3.0  2967.335778
# ...                       ...                 ...          ...
# 1277                -1.000000                 1.0   200.000000
# 1278                -1.000000                 1.0   200.000000
# 1279                -1.000000                 1.0   200.000000
# 1280                -1.000000                 1.0   200.000000
# 1281                -1.000000                 1.0   200.000000
#
#       min_dist_between_points  min_dist_between_centroids  \
# 0                         inf                         inf
# 1                         inf                         inf
# 2                         inf                         inf
# 3                         inf                         inf
# 4                 2840.789495                 2967.335778
# ...                       ...                         ...
# 1277                      inf                         inf
# 1278                      inf                         inf
# 1279                      inf                         inf
# 1280                      inf                         inf
# 1281                      inf                         inf
#
#       max_dist_in_cluster  min_dist_in_cluster     first_timestamp  \
# 0               12.101281                  0.0 2012-02-14 02:00:44
# 1               12.101281                  0.0 2012-02-14 02:25:12
# 2               28.183760                  0.0 2012-02-14 02:45:10
# 3              849.443062                  0.0 2012-02-14 03:35:11
# 4               27.369578                  0.0 2012-02-14 03:05:12
# ...                   ...                  ...                 ...
# 1277            42.536324                  0.0 2012-03-10 14:45:17
# 1278            49.236047                  0.0 2012-03-10 15:05:13
# 1279            49.236047                  0.0 2012-03-10 15:25:13
# 1280            22.902119                  0.0 2012-03-10 15:45:13
# 1281             5.116988                  0.0 2012-03-10 16:00:46
#
#           last_timestamp  win_number  cluster_size  \
# 0    2012-02-14 03:00:11           0          13.0
# 1    2012-02-14 03:20:10           1          12.0
# 2    2012-02-14 03:30:12           2          10.0
# 3    2012-02-14 03:40:12           2           2.0
# 4    2012-02-14 03:30:12           3           6.0
# ...                  ...         ...           ...
# 1277 2012-03-10 15:40:14        1838          12.0
# 1278 2012-03-10 15:55:13        1839          11.0
# 1279 2012-03-10 16:15:12        1840          11.0
# 1280 2012-03-10 16:15:12        1841           7.0
# 1281 2012-03-10 16:15:12        1842           4.0
#
#                                                  points  Selected EPS
# 0     [[1329184844.0, 36.701858, 3.985513, 670.0], [...    200.000000
# 1     [[1329186312.0, 36.70184, 3.985496, 670.1], [1...    200.000000
# 2     [[1329187510.0, 36.701839, 3.985476, 667.6], [...    200.000000
# 3     [[1329190511.0, 36.703101, 3.970574, 657.0], [...    200.000000
# 4     [[1329188712.0, 36.701836, 3.985473, 667.9], [...   2967.335778
# ...                                                 ...           ...
# 1277  [[1331390717.0, 31.181274, 21.659701, 193.2], ...    200.000000
# 1278  [[1331391913.0, 31.181295, 21.659588, 179.9], ...    200.000000
# 1279  [[1331393113.0, 31.181216, 21.659453, 214.6], ...    200.000000
# 1280  [[1331394313.0, 31.181232, 21.659608, 171.5], ...    200.000000
# 1281  [[1331395246.0, 31.181263, 21.659601, 189.7], ...    200.000000
#
# [1282 rows x 16 columns]

# %%
# Initialize dataframe to hold the results
all_clusters_with_overlap_static_eps = pd.DataFrame()

# Iterate through the data in sliding windows
window_number = 0
start_time = df_sorted['timestamp'].min()
end_time = df_sorted['timestamp'].max()
curr_eps = 200
# Define the sliding window and overlap in seconds
window_size = 60 * 60  # 60 minutes in seconds
step_size = 20 * 60  # 20 minutes in seconds

print("------------starting DBSCAN windows process:------------")

while start_time <= end_time:
    window_end_time = start_time + pd.Timedelta(seconds=window_size)
    window_df = df_sorted[(df_sorted['timestamp'] >= start_time) & (df_sorted['timestamp'] < window_end_time)]
    #print(f"Processing window {window_number}: Start Time = {start_time}, End Time = {window_end_time}, Points in Window = {len(window_df)}")
    
    # Process the window if it has more than one point
    if len(window_df) > 1:
        clusters_df,curr_eps = process_window(window_df,200,False)
        clusters_df['win_number'] = window_number
        clusters_df['Selected EPS'] = curr_eps
        all_clusters_with_overlap_static_eps = pd.concat([all_clusters_with_overlap_static_eps, clusters_df], ignore_index=True)
    
    # Move to the next window start time
    start_time = start_time + pd.Timedelta(seconds=step_size)
    window_number += 1

#print(all_clusters)
all_clusters_with_overlap_static_eps.to_csv("clusters_file3_with_overlap_static_eps.csv")
# Out:
# ------------starting DBSCAN windows process:------------

# %%
all_clusters_with_overlap_static_eps
# Out:
#       cluster_label  silhouette_score  davies_bouldin_score  \
# 0               0.0         -1.000000             -1.000000
# 1               0.0         -1.000000             -1.000000
# 2               0.0          0.444837              0.781818
# 3              -1.0          0.444837              0.781818
# 4               0.0          0.165156              1.316659
# ...             ...               ...                   ...
# 1277            0.0         -1.000000             -1.000000
# 1278            0.0         -1.000000             -1.000000
# 1279            0.0         -1.000000             -1.000000
# 1280            0.0         -1.000000             -1.000000
# 1281            0.0         -1.000000             -1.000000
#
#       calinski_harabasz_score  clusters_in_window      win_eps  \
# 0                   -1.000000                 1.0   200.000000
# 1                   -1.000000                 1.0   200.000000
# 2                    6.808653                 2.0   200.000000
# 3                    6.808653                 2.0   200.000000
# 4                    8.680263                 3.0  2967.335778
# ...                       ...                 ...          ...
# 1277                -1.000000                 1.0   200.000000
# 1278                -1.000000                 1.0   200.000000
# 1279                -1.000000                 1.0   200.000000
# 1280                -1.000000                 1.0   200.000000
# 1281                -1.000000                 1.0   200.000000
#
#       min_dist_between_points  min_dist_between_centroids  \
# 0                         inf                         inf
# 1                         inf                         inf
# 2                         inf                         inf
# 3                         inf                         inf
# 4                 2840.789495                 2967.335778
# ...                       ...                         ...
# 1277                      inf                         inf
# 1278                      inf                         inf
# 1279                      inf                         inf
# 1280                      inf                         inf
# 1281                      inf                         inf
#
#       max_dist_in_cluster  min_dist_in_cluster     first_timestamp  \
# 0               12.101281                  0.0 2012-02-14 02:00:44
# 1               12.101281                  0.0 2012-02-14 02:25:12
# 2               28.183760                  0.0 2012-02-14 02:45:10
# 3              849.443062                  0.0 2012-02-14 03:35:11
# 4               27.369578                  0.0 2012-02-14 03:05:12
# ...                   ...                  ...                 ...
# 1277            42.536324                  0.0 2012-03-10 14:45:17
# 1278            49.236047                  0.0 2012-03-10 15:05:13
# 1279            49.236047                  0.0 2012-03-10 15:25:13
# 1280            22.902119                  0.0 2012-03-10 15:45:13
# 1281             5.116988                  0.0 2012-03-10 16:00:46
#
#           last_timestamp  win_number  cluster_size  \
# 0    2012-02-14 03:00:11           0          13.0
# 1    2012-02-14 03:20:10           1          12.0
# 2    2012-02-14 03:30:12           2          10.0
# 3    2012-02-14 03:40:12           2           2.0
# 4    2012-02-14 03:30:12           3           6.0
# ...                  ...         ...           ...
# 1277 2012-03-10 15:40:14        1838          12.0
# 1278 2012-03-10 15:55:13        1839          11.0
# 1279 2012-03-10 16:15:12        1840          11.0
# 1280 2012-03-10 16:15:12        1841           7.0
# 1281 2012-03-10 16:15:12        1842           4.0
#
#                                                  points  Selected EPS
# 0     [[1329184844.0, 36.701858, 3.985513, 670.0], [...    200.000000
# 1     [[1329186312.0, 36.70184, 3.985496, 670.1], [1...    200.000000
# 2     [[1329187510.0, 36.701839, 3.985476, 667.6], [...    200.000000
# 3     [[1329190511.0, 36.703101, 3.970574, 657.0], [...    200.000000
# 4     [[1329188712.0, 36.701836, 3.985473, 667.9], [...   2967.335778
# ...                                                 ...           ...
# 1277  [[1331390717.0, 31.181274, 21.659701, 193.2], ...    200.000000
# 1278  [[1331391913.0, 31.181295, 21.659588, 179.9], ...    200.000000
# 1279  [[1331393113.0, 31.181216, 21.659453, 214.6], ...    200.000000
# 1280  [[1331394313.0, 31.181232, 21.659608, 171.5], ...    200.000000
# 1281  [[1331395246.0, 31.181263, 21.659601, 189.7], ...    200.000000
#
# [1282 rows x 16 columns]

# %%
all_clusters["points"]
# Out:
# 0       [[1329184844.0, 36.701858, 3.985513, 670.0], [...
# 1       [[1329186312.0, 36.70184, 3.985496, 670.1], [1...
# 2       [[1329187510.0, 36.701839, 3.985476, 667.6], [...
# 3       [[1329188712.0, 36.701836, 3.985473, 667.9], [...
# 4       [[1329191110.0, 36.705714, 3.960221, 640.3], [...
#                               ...
# 1022    [[1331390717.0, 31.181274, 21.659701, 193.2], ...
# 1023    [[1331391913.0, 31.181295, 21.659588, 179.9], ...
# 1024    [[1331393113.0, 31.181216, 21.659453, 214.6], ...
# 1025    [[1331394313.0, 31.181232, 21.659608, 171.5], ...
# 1026    [[1331395246.0, 31.181263, 21.659601, 189.7], ...
# Name: points, Length: 1027, dtype: object

# %%
all_clusters["min_dist_between_points"].unique()
#all_clusters[["min_dist_between_points","win_eps"]]
# Out:
# array([          inf, 2840.78949513,  847.57638358,  478.61484179,
#         478.07357433,  364.81726586,  478.23993617, 1169.23167146,
#        1143.61323698,  412.77808328,  326.67364706,  843.74837934,
#         281.40693456,  376.78950529, 1001.26631988, 4384.58295845,
#        4388.93226816, 2596.70610721,  686.97918395,  206.79811879,
#        1158.09112762, 1025.82818427,  791.12377501,  486.33532126,
#         349.4421651 , 1658.37649951,  992.65265032,  379.28971781,
#         428.56877308,  303.47188616,  263.356612  ,  602.85774976,
#        1152.18396617, 1150.07757955,  361.24615026, 6052.68598498,
#        8126.15107037, 7021.45064125,  341.30559329, 2562.70795941,
#        2966.8036856 , 3221.8121768 ,  697.6363037 ,  318.01485436,
#         379.59902735,  273.62787559,  414.53808532,  432.01177441,
#         795.17261821,  318.30388776,  287.76758083,  253.96453221,
#        1704.90527085,  252.28501964, 1927.85817228, 2030.47418896,
#         675.65038096,  233.21985756,  265.68512842,  851.38144405,
#         850.03177479,  243.42447719,  481.7291462 ,  454.82880427,
#         724.78303455, 1185.94987497, 1564.71037322,  209.25586506,
#         216.66131239,  729.59463248,  714.42899571,  236.1808648 ,
#         915.56867788,  713.57124624,  605.09927518,  601.11558353])

# %%
all_clusters.columns
# Out:
# Index(['cluster_label', 'silhouette_score', 'davies_bouldin_score',
#        'calinski_harabasz_score', 'win_eps', 'min_dist_between_points',
#        'min_dist_between_centroids', 'max_dist_in_cluster', 'first_timestamp',
#        'last_timestamp', 'win_number', 'cluster_size', 'points',
#        'Selected EPS'],
#       dtype='object')

# %%
all_clusters.to_csv("clusters_file3.csv")

# %% [markdown]
# # Analyzing the results - visualisations of metrics and windows
#
# extracting kinematic features and visualisation

# %%
import pandas as pd
all_clusters = pd.read_csv("clusters_file3.csv")

# %%
all_clusters
# Out:
#       Unnamed: 0  cluster_label  silhouette_score  davies_bouldin_score  \
# 0              0            0.0         -1.000000             -1.000000
# 1              1            0.0         -1.000000             -1.000000
# 2              2            0.0          0.444837              0.781818
# 3              3            0.0          0.165156              1.316659
# 4              4            1.0          0.165156              1.316659
# ...          ...            ...               ...                   ...
# 1022        1022            0.0         -1.000000             -1.000000
# 1023        1023            0.0         -1.000000             -1.000000
# 1024        1024            0.0         -1.000000             -1.000000
# 1025        1025            0.0         -1.000000             -1.000000
# 1026        1026            0.0         -1.000000             -1.000000
#
#       calinski_harabasz_score  clusters_in_window      win_eps  \
# 0                   -1.000000                 1.0   200.000000
# 1                   -1.000000                 1.0   200.000000
# 2                    6.808653                 2.0   200.000000
# 3                    8.680263                 3.0  2967.335778
# 4                    8.680263                 3.0  2967.335778
# ...                       ...                 ...          ...
# 1022                -1.000000                 1.0   200.000000
# 1023                -1.000000                 1.0   200.000000
# 1024                -1.000000                 1.0   200.000000
# 1025                -1.000000                 1.0   200.000000
# 1026                -1.000000                 1.0   200.000000
#
#       min_dist_between_points  min_dist_between_centroids  \
# 0                         inf                         inf
# 1                         inf                         inf
# 2                         inf                         inf
# 3                 2840.789495                 2967.335778
# 4                 2840.789495                 2967.335778
# ...                       ...                         ...
# 1022                      inf                         inf
# 1023                      inf                         inf
# 1024                      inf                         inf
# 1025                      inf                         inf
# 1026                      inf                         inf
#
#       max_dist_in_cluster      first_timestamp       last_timestamp  \
# 0               12.101281  2012-02-14 02:00:44  2012-02-14 03:00:11
# 1               12.101281  2012-02-14 02:25:12  2012-02-14 03:20:10
# 2               28.183760  2012-02-14 02:45:10  2012-02-14 03:30:12
# 3               27.369578  2012-02-14 03:05:12  2012-02-14 03:30:12
# 4              237.112234  2012-02-14 03:45:10  2012-02-14 04:00:10
# ...                   ...                  ...                  ...
# 1022            42.536324  2012-03-10 14:45:17  2012-03-10 15:40:14
# 1023            49.236047  2012-03-10 15:05:13  2012-03-10 15:55:13
# 1024            49.236047  2012-03-10 15:25:13  2012-03-10 16:15:12
# 1025            22.902119  2012-03-10 15:45:13  2012-03-10 16:15:12
# 1026             5.116988  2012-03-10 16:00:46  2012-03-10 16:15:12
#
#       win_number  cluster_size  \
# 0              0          13.0
# 1              1          12.0
# 2              2          10.0
# 3              3           6.0
# 4              3           4.0
# ...          ...           ...
# 1022        1838          12.0
# 1023        1839          11.0
# 1024        1840          11.0
# 1025        1841           7.0
# 1026        1842           4.0
#
#                                                  points  Selected EPS
# 0     [[1329184844.0, 36.701858, 3.985513, 670.0], [...    200.000000
# 1     [[1329186312.0, 36.70184, 3.985496, 670.1], [1...    200.000000
# 2     [[1329187510.0, 36.701839, 3.985476, 667.6], [...    200.000000
# 3     [[1329188712.0, 36.701836, 3.985473, 667.9], [...   2967.335778
# 4     [[1329191110.0, 36.705714, 3.960221, 640.3], [...   2967.335778
# ...                                                 ...           ...
# 1022  [[1331390717.0, 31.181274, 21.659701, 193.2], ...    200.000000
# 1023  [[1331391913.0, 31.181295, 21.659588, 179.9], ...    200.000000
# 1024  [[1331393113.0, 31.181216, 21.659453, 214.6], ...    200.000000
# 1025  [[1331394313.0, 31.181232, 21.659608, 171.5], ...    200.000000
# 1026  [[1331395246.0, 31.181263, 21.659601, 189.7], ...    200.000000
#
# [1027 rows x 16 columns]

# %%
import matplotlib.pyplot as plt
#all_clusters = pd.read_csv("clusters_file3.csv")
# Calculate the median EPS distance for each window
median_eps_by_window = all_clusters.groupby('win_number')['win_eps'].median()

#median_eps_by_window = median_eps_by_window[median_eps_by_window != 200]

# Plot the median EPS distance as a function of window number
plt.figure(figsize=(10, 6))
plt.plot(median_eps_by_window.index, median_eps_by_window.values, marker='o', linestyle='-', color='red')
plt.title('Median EPS Distance vs. Window Number')
plt.xlabel('Window Number')
plt.ylabel('Median EPS Distance')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
#all_clusters = pd.read_csv("clusters_file3.csv")

# Calculate the median EPS distance for each window
median_eps_by_window = all_clusters.groupby('win_number')['win_eps'].median()

median_eps_by_window = median_eps_by_window[median_eps_by_window != 200]

# Limit to the first 3000 windows
median_eps_by_window = median_eps_by_window[median_eps_by_window.index >= 50]

# Plot the median EPS distance as a function of window number
plt.figure(figsize=(10, 6))
plt.plot(median_eps_by_window.index, median_eps_by_window.values, marker='o', linestyle='-', color='red')
plt.title('Median EPS Distance vs. Window Number (Up to Window 50)')
plt.xlabel('Window Number')
plt.ylabel('Median EPS Distance')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Calculate the number of clusters for each window
clusters_per_window = all_clusters.groupby('win_number')['cluster_label'].nunique()

# Plot the number of clusters as a function of window number
plt.figure(figsize=(10, 6))
plt.plot(clusters_per_window.index, clusters_per_window.values, marker='o', linestyle='-', color='r')
plt.title('Number of Clusters vs. Window Number')
plt.xlabel('Window Number')
plt.ylabel('Number of Clusters')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Calculate the median distance between points for each window
median_distance_per_window = all_clusters.groupby('win_number')['max_dist_in_cluster'].median()

# Calculate the number of points in each window
points_per_window = all_clusters.groupby('win_number')['cluster_size'].sum()

points_per_window = points_per_window.head(100)
median_distance_per_window = median_distance_per_window.head(100)

# Create a figure and axis with dual y-axes
fig, ax1 = plt.subplots(figsize=(12, 8))

# Plot the median distance between points on the first y-axis
ax1.set_xlabel('Window Number')
ax1.set_ylabel('Median Distance Between Points (meters)', color='b')
ax1.plot(median_distance_per_window.index, median_distance_per_window.values, marker='o', linestyle='-', color='b')
ax1.tick_params(axis='y', labelcolor='b')

# Create a second y-axis to plot the number of points
ax2 = ax1.twinx()
ax2.set_ylabel('Number of Points in Window', color='r')
ax2.plot(points_per_window.index, points_per_window.values, marker='o', linestyle='-', color='r')
ax2.tick_params(axis='y', labelcolor='r')

# Set the title and display the plot
plt.title('Median Distance Between Points and Number of Points vs. Window Number')
fig.tight_layout()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Calculate the median distance between points for each window
median_distance_per_window = all_clusters.groupby('win_number')['max_dist_in_cluster'].median()

# Calculate the number of points in each window
points_per_window = all_clusters.groupby('win_number')['cluster_size'].sum()

# Restrict to the first 100 windows for plotting
points_per_window = points_per_window.head(100)
median_distance_per_window = median_distance_per_window.head(100)

# Combine the two series into a DataFrame for easy plotting
correlation_df = pd.DataFrame({
    'Median Distance': median_distance_per_window,
    'Points per Window': points_per_window
})

# Drop any rows with missing values
correlation_df = correlation_df.dropna()

# Create the correlation plot
plt.figure(figsize=(12, 8))
sns.scatterplot(x='Median Distance', y='Points per Window', data=correlation_df)

# Calculate and display the correlation coefficient
correlation_coefficient = correlation_df['Median Distance'].corr(correlation_df['Points per Window'])
plt.title(f'Correlation between Median Distance and Points per Window (r = {correlation_coefficient:.2f})')
plt.xlabel('Median Distance Between Points (meters)')
plt.ylabel('Number of Points in Window')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Calculate the median distance between points for each window
median_distance_per_window = all_clusters.groupby('win_number')['max_dist_in_cluster'].median()

# Calculate the number of points in each window
points_per_window = all_clusters.groupby('win_number')['cluster_size'].sum()

# Limit the data to the first 250 windows
median_distance_per_window = median_distance_per_window[median_distance_per_window.index <= 300]
points_per_window = points_per_window[points_per_window.index <= 300]

# Create a figure and axis with dual y-axes
fig, ax1 = plt.subplots(figsize=(12, 8))

# Plot the median distance between points on the first y-axis
ax1.set_xlabel('Window Number')
ax1.set_ylabel('Median Distance Between Points (meters)', color='b')
ax1.plot(median_distance_per_window.index, median_distance_per_window.values, marker='o', linestyle='-', color='b')
ax1.tick_params(axis='y', labelcolor='b')

# Create a second y-axis to plot the number of points
ax2 = ax1.twinx()
ax2.set_ylabel('Number of Points in Window', color='r')
ax2.plot(points_per_window.index, points_per_window.values, marker='o', linestyle='-', color='r')
ax2.tick_params(axis='y', labelcolor='r')

# Set the title and display the plot
plt.title('Median Distance Between Points and Number of Points vs. Window Number (First 300 Windows)')
fig.tight_layout()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Group the data by window number and calculate the mean for each metric
silhouette_scores = all_clusters.groupby('win_number')['silhouette_score'].mean()
davies_bouldin_scores = all_clusters.groupby('win_number')['davies_bouldin_score'].mean()
calinski_harabasz_scores = all_clusters.groupby('win_number')['calinski_harabasz_score'].mean()

# Calculate the third quartile for the red and green axes
davies_bouldin_third_quartile = np.percentile(davies_bouldin_scores, 75)
calinski_harabasz_third_quartile = np.percentile(calinski_harabasz_scores, 75)

# Create the plot
fig, ax1 = plt.subplots(figsize=(14, 8))

# Plot Silhouette Score on the first y-axis
ax1.plot(silhouette_scores.index, silhouette_scores.values, marker='o', linestyle='-', color='b', label='Silhouette Score')
ax1.set_xlabel('Window Number')
ax1.set_ylabel('Silhouette Score', color='b')
ax1.tick_params(axis='y', labelcolor='b')

# Create a second y-axis for Davies-Bouldin Index
ax2 = ax1.twinx()
ax2.plot(davies_bouldin_scores.index, davies_bouldin_scores.values, marker='s', linestyle='-', color='r', label='Davies-Bouldin Index')
ax2.set_ylabel('Davies-Bouldin Index', color='r')
ax2.tick_params(axis='y', labelcolor='r')
ax2.set_ylim(0, davies_bouldin_third_quartile)  # Limit the red axis

# Create a third y-axis for Calinski-Harabasz Score
ax3 = ax1.twinx()
ax3.spines['right'].set_position(('outward', 60))  # Move the third y-axis to the right
ax3.plot(calinski_harabasz_scores.index, calinski_harabasz_scores.values, marker='^', linestyle='-', color='g', label='Calinski-Harabasz Score')
ax3.set_ylabel('Calinski-Harabasz Score', color='g')
ax3.tick_params(axis='y', labelcolor='g')
ax3.set_ylim(0, calinski_harabasz_third_quartile)  # Limit the green axis

# Adding title
plt.title('Clustering Evaluation Metrics as a Function of Window Number')

# Show the plot
fig.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

def normalize(data):
    return 2 * (data - np.min(data)) / (np.max(data) - np.min(data)) - 1

# Group the data by window number and calculate the mean for each metric
silhouette_scores = all_clusters.groupby('win_number')['silhouette_score'].mean()
davies_bouldin_scores = all_clusters.groupby('win_number')['davies_bouldin_score'].mean()
calinski_harabasz_scores = all_clusters.groupby('win_number')['calinski_harabasz_score'].mean()

# Normalize the values between -1 and 1
silhouette_scores_normalized = normalize(silhouette_scores)
davies_bouldin_scores_normalized = normalize(davies_bouldin_scores)
calinski_harabasz_scores_normalized = normalize(calinski_harabasz_scores)

# Filter the first 250 windows
silhouette_scores_normalized = silhouette_scores_normalized.head(50)
davies_bouldin_scores_normalized = davies_bouldin_scores_normalized.head(50)
calinski_harabasz_scores_normalized = calinski_harabasz_scores_normalized.head(50)

# Calculate the third quartile for the red and green axes (on normalized data)
davies_bouldin_third_quartile = np.percentile(davies_bouldin_scores_normalized, 75)
calinski_harabasz_third_quartile = np.percentile(calinski_harabasz_scores_normalized, 75)

# Create the plot
fig, ax1 = plt.subplots(figsize=(14, 8))

# Plot Silhouette Score on the first y-axis
ax1.plot(silhouette_scores_normalized.index, silhouette_scores_normalized.values, marker='o', linestyle='-', color='b', label='Silhouette Score')
ax1.set_xlabel('Window Number')
ax1.set_ylabel('Silhouette Score (Normalized)', color='b')
ax1.tick_params(axis='y', labelcolor='b')

# Create a second y-axis for Davies-Bouldin Index
ax2 = ax1.twinx()
ax2.plot(davies_bouldin_scores_normalized.index, davies_bouldin_scores_normalized.values, marker='s', linestyle='-', color='r', label='Davies-Bouldin Index')
ax2.set_ylabel('Davies-Bouldin Index (Normalized)', color='r')
ax2.tick_params(axis='y', labelcolor='r')
#ax2.set_ylim(-1, davies_bouldin_third_quartile)  # Limit the red axis

# Create a third y-axis for Calinski-Harabasz Score
ax3 = ax1.twinx()
ax3.spines['right'].set_position(('outward', 60))  # Move the third y-axis to the right
ax3.plot(calinski_harabasz_scores_normalized.index, calinski_harabasz_scores_normalized.values, marker='^', linestyle='-', color='g', label='Calinski-Harabasz Score')
ax3.set_ylabel('Calinski-Harabasz Score (Normalized)', color='g')
ax3.tick_params(axis='y', labelcolor='g')
#ax3.set_ylim(-1, calinski_harabasz_third_quartile)  # Limit the green axis

# Adding title
plt.title('Clustering Evaluation Metrics (Normalized) as a Function of Window Number (First 250 Windows)')

# Show the plot
fig.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
file_path = 'clusters_file3.csv'  # Adjust the file path as needed
df = pd.read_csv(file_path)

# Extract the relevant columns for plotting
min_dist_between_points = df['min_dist_between_points']
min_dist_between_centroids = df['min_dist_between_centroids'] if 'min_dist_between_centroids' in df.columns else None
max_dist_in_cluster = df['max_dist_in_cluster']
selected_eps = df['win_eps']


# Create the plot
plt.figure(figsize=(14, 8))

# Plot each metric
plt.plot(min_dist_between_points, marker='o', linestyle='-', color='b', label='Min Dist Between Points')
if min_dist_between_centroids is not None:
    plt.plot(min_dist_between_centroids, marker='x', linestyle='-', color='r', label='Min Dist Between Centroids')
plt.plot(max_dist_in_cluster, marker='^', linestyle='-', color='g', label='Max Dist in Cluster')
plt.plot(selected_eps, marker='s', linestyle='-', color='orange', label='Selected EPS')

# Adding labels and title
plt.xlabel('Cluster Index')
plt.ylabel('Distance / EPS Value')
plt.title('Distances and Selected EPS Across Clusters')
plt.legend()
plt.grid(True)
plt.ylim(-20, 1500)
plt.tight_layout()

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
file_path = 'clusters_file3.csv'  # Adjust the file path as needed
df = pd.read_csv(file_path)

# Update 'selected_eps' values
#df['win_eps'] = df['win_eps'].apply(lambda x: np.random.randint(30, 130) if x == 500 else x)

# Extract the relevant columns for plotting
min_dist_between_points = df['min_dist_between_points']
min_dist_between_centroids = df['min_dist_between_centroids'] if 'min_dist_between_centroids' in df.columns else None
max_dist_in_cluster = df['max_dist_in_cluster']
selected_eps = df['win_eps']

# Create the plot
plt.figure(figsize=(14, 8))

# Plot each metric
plt.plot(min_dist_between_points, marker='o', linestyle='-', color='b', label='Min Dist Between Points')
#if min_dist_between_centroids is not None:
plt.plot(min_dist_between_centroids, marker='x', linestyle='-', color='r', label='Min Dist Between Centroids')
#plt.plot(max_dist_in_cluster, marker='^', linestyle='-', color='g', label='Max Dist in Cluster')
#plt.plot(selected_eps, marker='s', linestyle='-', color='orange', label='Selected EPS')

# Adding labels and title
plt.xlabel('Cluster Index')
plt.ylabel('Distance / EPS Value')
plt.title('Distances and Selected EPS Across Clusters')
plt.legend()
plt.ylim(-1, 1750)
plt.grid(True)
plt.tight_layout()

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
file_path = 'clusters_file3.csv'  # Adjust the file path as needed
df = pd.read_csv(file_path)

# Extract the relevant columns for plotting
min_dist_between_points = df['min_dist_between_points']
min_dist_between_centroids = df['min_dist_between_centroids'] if 'min_dist_between_centroids' in df.columns else None
max_dist_in_cluster = df['max_dist_in_cluster']
selected_eps = df['win_eps']

# Create the plot
plt.figure(figsize=(14, 8))

# Plot each metric
#plt.plot(min_dist_between_points, marker='o', linestyle='-', color='b', label='Min Dist Between Points')
#if min_dist_between_centroids is not None:
#plt.plot(min_dist_between_centroids, marker='x', linestyle='-', color='r', label='Min Dist Between Centroids')
plt.plot(max_dist_in_cluster, marker='^', linestyle='-', color='g', label='Max Dist in Cluster')
plt.plot(selected_eps, marker='s', linestyle='-', color='orange', label='Selected EPS')

# Adding labels and title
plt.xlabel('Cluster Index')
plt.ylabel('Distance / EPS Value')
plt.title('Distances and Selected EPS Across Clusters')
plt.legend()
plt.ylim(-1, 750)
plt.grid(True)
plt.tight_layout()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Calculate the median distance between points for each window
median_distance_per_window = all_clusters.groupby('win_number')['max_dist_in_cluster'].median()

# Calculate the number of points in each window
points_per_window = all_clusters.groupby('win_number')['cluster_size'].sum()

# Restrict to the first 100 windows for plotting
points_per_window = points_per_window.head(100)
median_distance_per_window = median_distance_per_window.head(100)

# Combine the two series into a DataFrame for easy plotting
correlation_df = pd.DataFrame({
    'Median Distance': median_distance_per_window,
    'Points per Window': points_per_window
})

# Drop any rows with missing values
correlation_df = correlation_df.dropna()

# Create the correlation plot
plt.figure(figsize=(12, 8))
sns.scatterplot(x='Median Distance', y='Points per Window', data=correlation_df)

# Calculate and display the correlation coefficient
correlation_coefficient = correlation_df['Median Distance'].corr(correlation_df['Points per Window'])
plt.title(f'Correlation between Median Distance and Points per Window (r = {correlation_coefficient:.2f})')
plt.xlabel('Median Distance Between Points (meters)')
plt.ylabel('Number of Points in Window')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
file_path = 'clusters_file3.csv'  # Adjust the file path as needed
df = pd.read_csv(file_path)

# Calculate the number of points in each cluster
df['num_points_in_cluster'] = df['points'].apply(lambda x: len(eval(x)))

# Group by 'win_number' to calculate the average number of points in a cluster and the total number of points in a window
avg_points_per_cluster = df.groupby('win_number')['num_points_in_cluster'].mean()
total_points_in_window = df.groupby('win_number')['num_points_in_cluster'].sum()

# Create the plot
plt.figure(figsize=(14, 8))

# Plot the average number of points per cluster
plt.plot(avg_points_per_cluster.index, avg_points_per_cluster.values, marker='o', linestyle='-', color='b', label='Average Points per Cluster')

# Plot the total number of points in each window
plt.plot(total_points_in_window.index, total_points_in_window.values, marker='s', linestyle='-', color='r', label='Total Points in Window')

# Adding labels and title
plt.xlabel('Window Number')
plt.ylabel('Number of Points')
plt.title('Average Number of Points per Cluster and Total Points per Window')
plt.legend()
plt.grid(True)
plt.tight_layout()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Combine all metrics into one DataFrame for easier plotting
combined_scores = pd.DataFrame({
    'Silhouette Score': all_clusters['silhouette_score']*-1,
    'Davies-Bouldin Index': all_clusters['davies_bouldin_score'],
    'Calinski-Harabasz Score': all_clusters['calinski_harabasz_score']
})

# Create the box plot
plt.figure(figsize=(14, 8))

# Plot the boxplot for all metrics
combined_scores.boxplot()

# Adding labels and title
plt.ylabel('Score')
plt.title('Box Plot of Clustering Evaluation Metrics Across All Windows')
plt.ylim(-2, 25)  # Set the y-axis limit to 1000
plt.grid(True)
plt.tight_layout()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Combine all metrics into one DataFrame for easier plotting
combined_scores = pd.DataFrame({
    'Silhouette Score': all_clusters['silhouette_score']*-1,
    'Davies-Bouldin Index': all_clusters['davies_bouldin_score'],
    'Calinski-Harabasz Score': all_clusters['calinski_harabasz_score']
})

# Create the box plot with seaborn for better aesthetics
plt.figure(figsize=(14, 8))

# Plot the boxplot for all metrics, removing outliers and coloring each box
sns.boxplot(data=combined_scores, palette="Set2", showfliers=False)

# Adding labels and title
plt.ylabel('Score')
plt.title('Box Plot of Clustering Evaluation Metrics Across All Windows (Outliers Removed)')
plt.ylim(-2, 15)  # Set the y-axis limit to 1000
plt.grid(True)
plt.tight_layout()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Normalize all values between 0 and 1
normalized_scores = pd.DataFrame()
for column in ['silhouette_score', 'davies_bouldin_score', 'calinski_harabasz_score']:
    normalized_scores[column] = all_clusters[column] #(all_clusters[column] - all_clusters[column].min()) / (all_clusters[column].max() - all_clusters[column].min())

# Create subplots to place the boxplots in one line
fig, axes = plt.subplots(1, 3, figsize=(18, 6))

# Plot the Silhouette Score
sns.boxplot(data=normalized_scores['silhouette_score']*-1, ax=axes[0], color="skyblue", showfliers=False)
axes[0].set_title('Silhouette Score (Normalized)')
axes[0].set_ylabel('Normalized Score')

# Plot the Davies-Bouldin Index
sns.boxplot(data=normalized_scores['davies_bouldin_score'], ax=axes[1], color="lightgreen", showfliers=False)
axes[1].set_title('Davies-Bouldin Index (Normalized)')
axes[1].set_ylabel('Normalized Score')

# Plot the Calinski-Harabasz Score
sns.boxplot(data=normalized_scores['calinski_harabasz_score'], ax=axes[2], color="lightcoral", showfliers=False)
axes[2].set_title('Calinski-Harabasz Score (Normalized)')
axes[2].set_ylabel('Normalized Score')

# Add a main title and adjust layout
plt.suptitle('Normalized Box Plots of Clustering Evaluation Metrics Across All Windows (Outliers Removed)', y=1.02)
plt.tight_layout()

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Ensure that all_clusters dataframe exists and contains 'win_number' and 'cluster_label'

# Initialize a list to store the count of clusters with sibling clusters for each window
sibling_clusters_per_window = []

# Loop through each window number
for win_number in sorted(all_clusters['win_number'].unique()):
    # Get clusters in the current window
    current_window_clusters = all_clusters[all_clusters['win_number'] == win_number]
    
    # If it's the first window, no previous window exists, so append 0 and continue
    if win_number == 0:
        sibling_clusters_per_window.append(0)
        continue
    
    # Get clusters in the previous window
    previous_window_clusters = all_clusters[all_clusters['win_number'] == win_number - 1]
    
    # Count clusters with siblings in the previous window
    sibling_count = 0
    for _, cluster in current_window_clusters.iterrows():
        points = set(tuple(x) for x in cluster['points'])
        for _, prev_cluster in previous_window_clusters.iterrows():
            prev_points = set(tuple(x) for x in prev_cluster['points'])
            if len(points.intersection(prev_points)) > 0:
                sibling_count += 1
                break  # Move to the next cluster once a sibling is found
    
    sibling_clusters_per_window.append(sibling_count)

# Plotting the results
plt.figure(figsize=(10, 6))
plt.plot(range(len(sibling_clusters_per_window)), sibling_clusters_per_window, marker='o', linestyle='-', color='red')
plt.title('Number of Clusters with Sibling Clusters from the Previous Window')
plt.xlabel('Window Number')
plt.ylabel('Number of Clusters with Sibling Clusters')
plt.grid(True)
plt.show()

# %%
import pandas as pd

# Ensure that all_clusters dataframe exists and contains 'win_number' and 'cluster_label'

# Initialize variables to store the total number of clusters and the count of clusters with siblings
total_clusters = 0
total_sibling_clusters = 0

# Loop through each window number
for win_number in sorted(all_clusters['win_number'].unique()):
    # Get clusters in the current window
    current_window_clusters = all_clusters[all_clusters['win_number'] == win_number]
    
    # If it's the first window, no previous window exists, so skip to the next iteration
    if win_number == 0:
        continue
    
    # Get clusters in the previous window
    previous_window_clusters = all_clusters[all_clusters['win_number'] == win_number - 1]
    
    # Count clusters with siblings in the previous window
    for _, cluster in current_window_clusters.iterrows():
        points = set(tuple(x) for x in cluster['points'])
        for _, prev_cluster in previous_window_clusters.iterrows():
            prev_points = set(tuple(x) for x in prev_cluster['points'])
            if len(points.intersection(prev_points)) > 0:
                total_sibling_clusters += 1
                break  # Move to the next cluster once a sibling is found
    
    total_clusters += len(current_window_clusters)

# Calculate the overall percentage of clusters with siblings
percentage_siblings = (total_sibling_clusters / total_clusters) * 100

# Print the result
print(f"Overall Percentage of Clusters with Sibling Clusters: {percentage_siblings:.2f}%")
# Out:
# Overall Percentage of Clusters with Sibling Clusters: 93.76%

# %%
import pandas as pd

# Ensure that all_clusters dataframe exists and contains 'cluster_label'

# Initialize variables to store the total number of clusters and the count of noise clusters
total_clusters = 0
total_noise_clusters = 0

# Loop through each window number
for win_number in sorted(all_clusters['win_number'].unique()):
    # Get clusters in the current window
    current_window_clusters = all_clusters[all_clusters['win_number'] == win_number]
    
    # Count the number of noise clusters (label -1) in the current window
    noise_clusters = current_window_clusters[current_window_clusters['cluster_label'] == -1]
    
    # Add the count of noise clusters to the total
    total_noise_clusters += len(noise_clusters)
    
    # Add the total number of clusters in the current window to the overall total
    total_clusters += len(current_window_clusters)

# Print the total number of noise clusters
print(f"Total Number of Noise Clusters: {total_noise_clusters/total_clusters}")
# Out:
# Total Number of Noise Clusters: 0.0

# %% [markdown]
# # Validating the clusterization model (per species)
#
# check how many clusters in the dataframe match the kinematic features of the known species?

# %%
df["points"]
# Out:
# 0      [[1329187510.0, 36.701839, 3.985476, 667.6], [...
# 1      [[1329188712.0, 36.701836, 3.985473, 667.9], [...
# 2      [[1329190812.0, 36.704966, 3.963166, 642.2], [...
# 3      [[1329211508.0, 36.705836, 3.947558, 662.5], [...
# 4      [[1329212712.0, 36.706384, 3.94668, 653.8], [1...
#                              ...
# 239    [[1331359246.0, 31.232397, 20.30416, 341.2], [...
# 240    [[1331360709.0, 31.23242, 20.304162, 341.0], [...
# 241    [[1331361910.0, 31.232416, 20.304152, 341.0], ...
# 242    [[1331386210.0, 31.181622, 21.659063, 180.9], ...
# 243    [[1331386210.0, 31.181622, 21.659063, 180.9], ...
# Name: points, Length: 244, dtype: object

# %%
import ast

# Function to count the number of points in the "points" list
def count_points(points_str):
    try:
        points_list = ast.literal_eval(points_str)  # Convert string representation of list to an actual list
        return len(points_list)
    except:
        return 0

# Apply the function to create a new column with the count of points
df['num_points'] = df['points'].apply(count_points)

# Filter and display the rows where the number of points is less than 4
filtered_df = df[df['num_points'] < 4]
print(filtered_df[['points']])
# Out:
#                                                 points
# 23   [[1329212712.0, 36.706384, 3.94668, 653.8], [1...
# 28   [[1329228052.0, 37.175702, 4.00127, 677.3], [1...
# 68   [[1329301808.0, 36.783137, 3.721869, 606.0], [...
# 72   [[1329304921.0, 36.78289, 3.721382, 598.9], [1...
# 75   [[1329316213.0, 37.176372, 4.012509, 681.1], [...
# ..                                                 ...
# 798  [[1331046611.0, 32.716951, 15.837311, 404.2], ...
# 854  [[1331185518.0, 32.577839, 17.598057, 372.2], ...
# 860  [[1331223912.0, 31.959739, 18.810809, 311.5], ...
# 883  [[1331273712.0, 31.964064, 18.818296, 302.9], ...
# 915  [[1331361910.0, 31.232416, 20.304152, 341.0], ...
#
# [77 rows x 1 columns]

# %%
import pandas as pd
import numpy as np
from scipy.stats import kendalltau
from math import atan2, radians, degrees, sqrt, sin, cos

# Load the dataset
file_path = 'clusters_file3.csv'  # Adjust the file path as needed
df = pd.read_csv(file_path)

# Function to convert epoch time in milliseconds to datetime
def convert_epoch_to_datetime(epoch_ms):
    return pd.to_datetime(epoch_ms*1000, unit='ms')

# Function to calculate haversine distance
def haversine(point1, point2):
    lon1, lat1, alt1 = point1
    lon2, lat2, alt2 = point2
    lon1, lat1, lon2, lat2 = map(radians, [lon1, lat1, lon2, lat2])
    dlon = lon2 - lon1
    dlat = lat2 - lat1
    a = sin(dlat / 2) ** 2 + cos(lat1) * cos(lat2) * sin(dlon / 2) ** 2
    c = 2 * atan2(sqrt(a), sqrt(1 - a))
    r = 6371000  # Radius of earth in meters
    distance = r * c
    
    # Include altitude difference
    alt_diff = abs(alt2 - alt1)
    total_distance = sqrt(distance ** 2 + alt_diff ** 2)
    return total_distance

# Function to calculate bearing
def calculate_bearing(point1, point2):
    lon1, lat1, alt1 = point1
    lon2, lat2, alt2 = point2
    lon1, lat1, lon2, lat2 = map(radians, [lon1, lat1, lon2, lat2])
    dlon = lon2 - lon1
    x = sin(dlon) * cos(lat2)
    y = cos(lat1) * sin(lat2) - sin(lat1) * cos(lat2) * cos(dlon)
    initial_bearing = atan2(x, y)
    initial_bearing = degrees(initial_bearing)
    compass_bearing = (initial_bearing + 360) % 360
    return compass_bearing

# Function to calculate angle to horizon
def calculate_angle_to_horizon(alt1, alt2, horizontal_distance):
    vertical_distance = alt2 - alt1
    return degrees(atan2(vertical_distance, horizontal_distance))

# Function to calculate kinematic features
def calculate_kinematic_features(cluster_points):
    timestamps = [p[0] for p in cluster_points]
    lons = [p[1] for p in cluster_points]
    lats = [p[2] for p in cluster_points]
    alts = [p[3] for p in cluster_points]
    
    # Normalize timestamps to start from t=0
    t0 = timestamps[0]
    normalized_timestamps = [(t - t0) / 1000 for t in timestamps]  # Convert to seconds

    # Ensure there are enough points to calculate kinematic features
    if len(normalized_timestamps) < 2:
        return None  # Not enough points to calculate features
    
    # Calculate differences between consecutive points
    time_diffs = np.diff(normalized_timestamps).astype(np.float64)  # in seconds
    time_diffs[time_diffs == 0] = np.nan  # Avoid division by zero by setting to NaN
    
    if len(time_diffs) == 0:
        return None
    
    distances = [haversine(cluster_points[i][1:], cluster_points[i+1][1:]) for i in range(len(cluster_points)-1)]
    distances = np.array(distances)
    
    if len(distances) == 0:
        return None
    
    speeds = distances / time_diffs  # Speed = distance / time
    speeds = np.where(np.isfinite(speeds), speeds, np.nan)  # Replace inf with NaN
    
    # Velocity calculation (as vector)
    velocities = [(speeds[i], calculate_bearing(cluster_points[i][1:], cluster_points[i+1][1:])) for i in range(len(speeds))]
    
    accelerations = np.diff(speeds) / time_diffs[:-1]  # Acceleration = change in speed / time
    accelerations = np.where(np.isfinite(accelerations), accelerations, np.nan)
    
    jerks = np.diff(accelerations) / time_diffs[:-2]  # Jerk = change in acceleration / time
    jerks = np.where(np.isfinite(jerks), jerks, np.nan)
    
    # Bearing calculations
    bearings = [calculate_bearing(cluster_points[i][1:], cluster_points[i+1][1:]) for i in range(len(cluster_points)-1)]
    bearing_changes = np.diff(bearings)
    
    # Angle to horizon
    angles_to_horizon = [calculate_angle_to_horizon(alts[i], alts[i+1], distances[i]) for i in range(len(alts)-1)]
    
    # Calculate the average height
    avg_height = np.mean(alts)
    
    # Turn rate, trajectory curvature, angular velocity, etc.
    turn_rate = np.nanmean(np.abs(bearing_changes) / time_diffs[:-1])
    curvature = np.nanmean(bearing_changes / distances[:-1])
    angular_velocity = np.nanmean(bearing_changes / time_diffs[:-1])
    angular_acceleration = np.nanmean(np.diff(bearing_changes) / time_diffs[:-2])
    
    # Displacement calculations
    displacement = haversine(cluster_points[0][1:], cluster_points[-1][1:])
    distance_traveled = np.sum(distances)
    
    # Vertical acceleration
    vertical_acceleration = np.diff(alts) / time_diffs
    vertical_acceleration = np.where(np.isfinite(vertical_acceleration), vertical_acceleration, np.nan)
    
    # Up/Down direction using Kendall Tau
    tau, _ = kendalltau(alts, np.arange(len(alts)))
    
    return {
        'avg_height': avg_height,
        'turn_rate': turn_rate,
        'bearing': np.nanmean(bearings),
        'trajectory_curvature': curvature,
        'angular_acceleration': angular_acceleration,
        'angular_velocity': angular_velocity,
        'distance_traveled': distance_traveled,
        'displacement': displacement,
        'jerk': np.nanmean(jerks),
        'vertical_acceleration': np.nanmean(vertical_acceleration),
        'up_down_direction': tau,
        'angle_to_horizon': np.nanmean(angles_to_horizon),
        'average_speed': np.nanmean(speeds),
        'average_velocity_magnitude': np.nanmean([v[0] for v in velocities]),
        'average_velocity_direction': np.nanmean([v[1] for v in velocities])
    }

# Keep only clusters with at least 30 points
df['points'] = df['points'].apply(eval)  # Convert the 'points' column from string to list
df_filtered = df[df['points'].apply(len) >= 3].reset_index(drop=True)

# Reindex the filtered DataFrame and use the new index as cluster labels
df_filtered['new_cluster_label'] = df_filtered.index

# Process clusters
clusters_with_features = []

for new_cluster_label, cluster in df_filtered.groupby('new_cluster_label'):
    #print("Processing cluster:", new_cluster_label)
    cluster_points = cluster.iloc[0]['points']  # Get the points for this cluster
    features = calculate_kinematic_features(cluster_points)
    if features:  # Only append if features were successfully calculated
        features['new_cluster_label'] = new_cluster_label
        clusters_with_features.append(features)

# Convert to DataFrame
clusters_with_features_df = pd.DataFrame(clusters_with_features)

# Merge the features back with the original dataframe (optional)
df = df_filtered.merge(clusters_with_features_df, on='new_cluster_label', how='left')

# Save or inspect the updated DataFrame
df.to_csv('clusters3_with_kinematic_features.csv', index=False)
# Out:
# Processing cluster: 0
# Processing cluster: 1
# Processing cluster: 2
# Processing cluster: 3
# Processing cluster: 4
# Processing cluster: 5
# Processing cluster: 6
# Processing cluster: 7
# Processing cluster: 8
# Processing cluster: 9
# Processing cluster: 10
# Processing cluster: 11
# Processing cluster: 12
# Processing cluster: 13
# Processing cluster: 14
# Processing cluster: 15
# Processing cluster: 16
# Processing cluster: 17
# Processing cluster: 18
# Processing cluster: 19
# Processing cluster: 20
# Processing cluster: 21
# Processing cluster: 22
# Processing cluster: 23
# Processing cluster: 24
# Processing cluster: 25
# Processing cluster: 26
# Processing cluster: 27
# Processing cluster: 28
# Processing cluster: 29
# Processing cluster: 30
# Processing cluster: 31
# Processing cluster: 32
# Processing cluster: 33
# Processing cluster: 34
# Processing cluster: 35
# Processing cluster: 36
# Processing cluster: 37
# Processing cluster: 38
# Processing cluster: 39
# Processing cluster: 40
# Processing cluster: 41
# Processing cluster: 42
# Processing cluster: 43
# Processing cluster: 44
# Processing cluster: 45
# Processing cluster: 46
# Processing cluster: 47
# Processing cluster: 48
# Processing cluster: 49
# Processing cluster: 50
# Processing cluster: 51
# Processing cluster: 52
# Processing cluster: 53
# Processing cluster: 54
# Processing cluster: 55
# Processing cluster: 56
# Processing cluster: 57
# Processing cluster: 58
# Processing cluster: 59
# Processing cluster: 60
# Processing cluster: 61
# Processing cluster: 62
# Processing cluster: 63
# Processing cluster: 64
# Processing cluster: 65
# Processing cluster: 66
# Processing cluster: 67
# Processing cluster: 68
# Processing cluster: 69
# Processing cluster: 70
# Processing cluster: 71
# Processing cluster: 72
# Processing cluster: 73
# Processing cluster: 74
# Processing cluster: 75
# Processing cluster: 76
# Processing cluster: 77
# Processing cluster: 78
# Processing cluster: 79
# Processing cluster: 80
# Processing cluster: 81
# Processing cluster: 82
# Processing cluster: 83
# Processing cluster: 84
# Processing cluster: 85
# Processing cluster: 86
# Processing cluster: 87
# Processing cluster: 88
# Processing cluster: 89
# Processing cluster: 90
# Processing cluster: 91
# Processing cluster: 92
# Processing cluster: 93
# Processing cluster: 94
# Processing cluster: 95
# Processing cluster: 96
# Processing cluster: 97
# Processing cluster: 98
# Processing cluster: 99
# Processing cluster: 100
# Processing cluster: 101
# Processing cluster: 102
# Processing cluster: 103
# Processing cluster: 104
# Processing cluster: 105
# Processing cluster: 106
# C:\Users\adibr\AppData\Local\Temp\ipykernel_11524\1902878558.py:103: RuntimeWarning: Mean of empty slice
#   angular_acceleration = np.nanmean(np.diff(bearing_changes) / time_diffs[:-2])
# C:\Users\adibr\AppData\Local\Temp\ipykernel_11524\1902878558.py:125: RuntimeWarning: Mean of empty slice
#   'jerk': np.nanmean(jerks),
# Processing cluster: 107
# Processing cluster: 108
# Processing cluster: 109
# Processing cluster: 110
# Processing cluster: 111
# Processing cluster: 112
# Processing cluster: 113
# Processing cluster: 114
# Processing cluster: 115
# Processing cluster: 116
# Processing cluster: 117
# Processing cluster: 118
# Processing cluster: 119
# Processing cluster: 120
# Processing cluster: 121
# Processing cluster: 122
# Processing cluster: 123
# Processing cluster: 124
# Processing cluster: 125
# Processing cluster: 126
# Processing cluster: 127
# Processing cluster: 128
# Processing cluster: 129
# Processing cluster: 130
# Processing cluster: 131
# Processing cluster: 132
# Processing cluster: 133
# Processing cluster: 134
# Processing cluster: 135
# Processing cluster: 136
# Processing cluster: 137
# Processing cluster: 138
# Processing cluster: 139
# Processing cluster: 140
# Processing cluster: 141
# Processing cluster: 142
# Processing cluster: 143
# Processing cluster: 144
# Processing cluster: 145
# Processing cluster: 146
# Processing cluster: 147
# Processing cluster: 148
# Processing cluster: 149
# Processing cluster: 150
# Processing cluster: 151
# Processing cluster: 152
# Processing cluster: 153
# Processing cluster: 154
# Processing cluster: 155
# Processing cluster: 156
# Processing cluster: 157
# Processing cluster: 158
# Processing cluster: 159
# Processing cluster: 160
# Processing cluster: 161
# Processing cluster: 162
# Processing cluster: 163
# Processing cluster: 164
# Processing cluster: 165
# Processing cluster: 166
# Processing cluster: 167
# Processing cluster: 168
# Processing cluster: 169
# Processing cluster: 170
# Processing cluster: 171
# Processing cluster: 172
# Processing cluster: 173
# Processing cluster: 174
# Processing cluster: 175
# Processing cluster: 176
# Processing cluster: 177
# Processing cluster: 178
# Processing cluster: 179
# Processing cluster: 180
# Processing cluster: 181
# Processing cluster: 182
# Processing cluster: 183
# Processing cluster: 184
# Processing cluster: 185
# Processing cluster: 186
# Processing cluster: 187
# Processing cluster: 188
# Processing cluster: 189
# Processing cluster: 190
# Processing cluster: 191
# Processing cluster: 192
# Processing cluster: 193
# Processing cluster: 194
# Processing cluster: 195
# Processing cluster: 196
# Processing cluster: 197
# Processing cluster: 198
# Processing cluster: 199
# Processing cluster: 200
# Processing cluster: 201
# Processing cluster: 202
# Processing cluster: 203
# Processing cluster: 204
# Processing cluster: 205
# Processing cluster: 206
# Processing cluster: 207
# Processing cluster: 208
# Processing cluster: 209
# Processing cluster: 210
# Processing cluster: 211
# Processing cluster: 212
# Processing cluster: 213
# Processing cluster: 214
# Processing cluster: 215
# Processing cluster: 216
# Processing cluster: 217
# Processing cluster: 218
# Processing cluster: 219
# Processing cluster: 220
# Processing cluster: 221
# Processing cluster: 222
# Processing cluster: 223
# Processing cluster: 224
# Processing cluster: 225
# Processing cluster: 226
# Processing cluster: 227
# Processing cluster: 228
# Processing cluster: 229
# Processing cluster: 230
# Processing cluster: 231
# Processing cluster: 232
# Processing cluster: 233
# Processing cluster: 234
# Processing cluster: 235
# Processing cluster: 236
# Processing cluster: 237
# Processing cluster: 238
# Processing cluster: 239
# Processing cluster: 240
# Processing cluster: 241
# Processing cluster: 242
# Processing cluster: 243
# Processing cluster: 244
# Processing cluster: 245
# Processing cluster: 246
# Processing cluster: 247
# Processing cluster: 248
# Processing cluster: 249
# Processing cluster: 250
# Processing cluster: 251
# Processing cluster: 252
# Processing cluster: 253
# Processing cluster: 254
# Processing cluster: 255
# Processing cluster: 256
# Processing cluster: 257
# Processing cluster: 258
# Processing cluster: 259
# Processing cluster: 260
# Processing cluster: 261
# Processing cluster: 262
# Processing cluster: 263
# Processing cluster: 264
# Processing cluster: 265
# Processing cluster: 266
# Processing cluster: 267
# Processing cluster: 268
# Processing cluster: 269
# Processing cluster: 270
# Processing cluster: 271
# Processing cluster: 272
# Processing cluster: 273
# Processing cluster: 274
# Processing cluster: 275
# Processing cluster: 276
# Processing cluster: 277
# Processing cluster: 278
# Processing cluster: 279
# Processing cluster: 280
# Processing cluster: 281
# Processing cluster: 282
# Processing cluster: 283
# Processing cluster: 284
# Processing cluster: 285
# Processing cluster: 286
# Processing cluster: 287
# Processing cluster: 288
# Processing cluster: 289
# Processing cluster: 290
# Processing cluster: 291
# Processing cluster: 292
# Processing cluster: 293
# Processing cluster: 294
# Processing cluster: 295
# Processing cluster: 296
# Processing cluster: 297
# Processing cluster: 298
# Processing cluster: 299
# Processing cluster: 300
# Processing cluster: 301
# Processing cluster: 302
# Processing cluster: 303
# Processing cluster: 304
# Processing cluster: 305
# Processing cluster: 306
# Processing cluster: 307
# Processing cluster: 308
# Processing cluster: 309
# Processing cluster: 310
# Processing cluster: 311
# Processing cluster: 312
# Processing cluster: 313
# Processing cluster: 314
# Processing cluster: 315
# Processing cluster: 316
# Processing cluster: 317
# Processing cluster: 318
# Processing cluster: 319
# Processing cluster: 320
# Processing cluster: 321
# Processing cluster: 322
# Processing cluster: 323
# Processing cluster: 324
# Processing cluster: 325
# Processing cluster: 326
# Processing cluster: 327
# Processing cluster: 328
# Processing cluster: 329
# Processing cluster: 330
# Processing cluster: 331
# Processing cluster: 332
# Processing cluster: 333
# Processing cluster: 334
# Processing cluster: 335
# Processing cluster: 336
# Processing cluster: 337
# Processing cluster: 338
# Processing cluster: 339
# Processing cluster: 340
# Processing cluster: 341
# Processing cluster: 342
# Processing cluster: 343
# Processing cluster: 344
# Processing cluster: 345
# Processing cluster: 346
# Processing cluster: 347
# Processing cluster: 348
# Processing cluster: 349
# Processing cluster: 350
# Processing cluster: 351
# Processing cluster: 352
# Processing cluster: 353
# Processing cluster: 354
# Processing cluster: 355
# Processing cluster: 356
# Processing cluster: 357
# Processing cluster: 358
# Processing cluster: 359
# Processing cluster: 360
# Processing cluster: 361
# Processing cluster: 362
# Processing cluster: 363
# Processing cluster: 364
# Processing cluster: 365
# Processing cluster: 366
# Processing cluster: 367
# Processing cluster: 368
# Processing cluster: 369
# Processing cluster: 370
# Processing cluster: 371
# Processing cluster: 372
# Processing cluster: 373
# Processing cluster: 374
# Processing cluster: 375
# Processing cluster: 376
# Processing cluster: 377
# Processing cluster: 378
# Processing cluster: 379
# Processing cluster: 380
# Processing cluster: 381
# Processing cluster: 382
# Processing cluster: 383
# Processing cluster: 384
# Processing cluster: 385
# Processing cluster: 386
# Processing cluster: 387
# Processing cluster: 388
# Processing cluster: 389
# Processing cluster: 390
# Processing cluster: 391
# Processing cluster: 392
# Processing cluster: 393
# Processing cluster: 394
# Processing cluster: 395
# Processing cluster: 396
# Processing cluster: 397
# Processing cluster: 398
# Processing cluster: 399
# Processing cluster: 400
# Processing cluster: 401
# Processing cluster: 402
# Processing cluster: 403
# Processing cluster: 404
# Processing cluster: 405
# Processing cluster: 406
# Processing cluster: 407
# Processing cluster: 408
# Processing cluster: 409
# Processing cluster: 410
# Processing cluster: 411
# Processing cluster: 412
# Processing cluster: 413
# Processing cluster: 414
# Processing cluster: 415
# Processing cluster: 416
# Processing cluster: 417
# Processing cluster: 418
# Processing cluster: 419
# Processing cluster: 420
# Processing cluster: 421
# Processing cluster: 422
# Processing cluster: 423
# Processing cluster: 424
# Processing cluster: 425
# Processing cluster: 426
# Processing cluster: 427
# Processing cluster: 428
# Processing cluster: 429
# Processing cluster: 430
# Processing cluster: 431
# Processing cluster: 432
# Processing cluster: 433
# Processing cluster: 434
# Processing cluster: 435
# Processing cluster: 436
# Processing cluster: 437
# Processing cluster: 438
# Processing cluster: 439
# Processing cluster: 440
# Processing cluster: 441
# Processing cluster: 442
# Processing cluster: 443
# Processing cluster: 444
# Processing cluster: 445
# Processing cluster: 446
# Processing cluster: 447
# Processing cluster: 448
# Processing cluster: 449
# Processing cluster: 450
# Processing cluster: 451
# Processing cluster: 452
# Processing cluster: 453
# Processing cluster: 454
# Processing cluster: 455
# Processing cluster: 456
# Processing cluster: 457
# Processing cluster: 458
# Processing cluster: 459
# Processing cluster: 460
# Processing cluster: 461
# Processing cluster: 462
# Processing cluster: 463
# Processing cluster: 464
# Processing cluster: 465
# Processing cluster: 466
# Processing cluster: 467
# Processing cluster: 468
# Processing cluster: 469
# Processing cluster: 470
# Processing cluster: 471
# Processing cluster: 472
# Processing cluster: 473
# Processing cluster: 474
# Processing cluster: 475
# Processing cluster: 476
# Processing cluster: 477
# Processing cluster: 478
# Processing cluster: 479
# Processing cluster: 480
# Processing cluster: 481
# Processing cluster: 482
# Processing cluster: 483
# Processing cluster: 484
# Processing cluster: 485
# Processing cluster: 486
# Processing cluster: 487
# Processing cluster: 488
# Processing cluster: 489
# Processing cluster: 490
# Processing cluster: 491
# Processing cluster: 492
# Processing cluster: 493
# Processing cluster: 494
# Processing cluster: 495
# Processing cluster: 496
# Processing cluster: 497
# Processing cluster: 498
# Processing cluster: 499
# Processing cluster: 500
# Processing cluster: 501
# Processing cluster: 502
# Processing cluster: 503
# Processing cluster: 504
# Processing cluster: 505
# Processing cluster: 506
# Processing cluster: 507
# Processing cluster: 508
# Processing cluster: 509
# Processing cluster: 510
# Processing cluster: 511
# Processing cluster: 512
# Processing cluster: 513
# Processing cluster: 514
# Processing cluster: 515
# Processing cluster: 516
# Processing cluster: 517
# Processing cluster: 518
# Processing cluster: 519
# Processing cluster: 520
# Processing cluster: 521
# Processing cluster: 522
# Processing cluster: 523
# Processing cluster: 524
# Processing cluster: 525
# Processing cluster: 526
# Processing cluster: 527
# Processing cluster: 528
# Processing cluster: 529
# Processing cluster: 530
# Processing cluster: 531
# Processing cluster: 532
# Processing cluster: 533
# Processing cluster: 534
# Processing cluster: 535
# Processing cluster: 536
# Processing cluster: 537
# Processing cluster: 538
# Processing cluster: 539
# Processing cluster: 540
# Processing cluster: 541
# Processing cluster: 542
# Processing cluster: 543
# Processing cluster: 544
# Processing cluster: 545
# Processing cluster: 546
# Processing cluster: 547
# Processing cluster: 548
# Processing cluster: 549
# Processing cluster: 550
# Processing cluster: 551
# Processing cluster: 552
# Processing cluster: 553
# Processing cluster: 554
# Processing cluster: 555
# Processing cluster: 556
# Processing cluster: 557
# Processing cluster: 558
# Processing cluster: 559
# Processing cluster: 560
# Processing cluster: 561
# Processing cluster: 562
# Processing cluster: 563
# Processing cluster: 564
# Processing cluster: 565
# Processing cluster: 566
# Processing cluster: 567
# Processing cluster: 568
# Processing cluster: 569
# Processing cluster: 570
# Processing cluster: 571
# Processing cluster: 572
# Processing cluster: 573
# Processing cluster: 574
# Processing cluster: 575
# Processing cluster: 576
# Processing cluster: 577
# Processing cluster: 578
# Processing cluster: 579
# Processing cluster: 580
# Processing cluster: 581
# Processing cluster: 582
# Processing cluster: 583
# Processing cluster: 584
# Processing cluster: 585
# Processing cluster: 586
# Processing cluster: 587
# Processing cluster: 588
# Processing cluster: 589
# Processing cluster: 590
# Processing cluster: 591
# Processing cluster: 592
# Processing cluster: 593
# Processing cluster: 594
# Processing cluster: 595
# Processing cluster: 596
# Processing cluster: 597
# Processing cluster: 598
# Processing cluster: 599
# Processing cluster: 600
# Processing cluster: 601
# Processing cluster: 602
# Processing cluster: 603
# Processing cluster: 604
# Processing cluster: 605
# Processing cluster: 606
# Processing cluster: 607
# Processing cluster: 608
# Processing cluster: 609
# Processing cluster: 610
# Processing cluster: 611
# Processing cluster: 612
# Processing cluster: 613
# Processing cluster: 614
# Processing cluster: 615
# Processing cluster: 616
# Processing cluster: 617
# Processing cluster: 618
# Processing cluster: 619
# Processing cluster: 620
# Processing cluster: 621
# Processing cluster: 622
# Processing cluster: 623
# Processing cluster: 624
# Processing cluster: 625
# Processing cluster: 626
# Processing cluster: 627
# Processing cluster: 628
# Processing cluster: 629
# Processing cluster: 630
# Processing cluster: 631
# Processing cluster: 632
# Processing cluster: 633
# Processing cluster: 634
# Processing cluster: 635
# Processing cluster: 636
# Processing cluster: 637
# Processing cluster: 638
# Processing cluster: 639
# Processing cluster: 640
# Processing cluster: 641
# Processing cluster: 642
# Processing cluster: 643
# Processing cluster: 644
# Processing cluster: 645
# Processing cluster: 646
# Processing cluster: 647
# Processing cluster: 648
# Processing cluster: 649
# Processing cluster: 650
# Processing cluster: 651
# Processing cluster: 652
# Processing cluster: 653
# Processing cluster: 654
# Processing cluster: 655
# Processing cluster: 656
# Processing cluster: 657
# Processing cluster: 658
# Processing cluster: 659
# Processing cluster: 660
# Processing cluster: 661
# Processing cluster: 662
# Processing cluster: 663
# Processing cluster: 664
# Processing cluster: 665
# Processing cluster: 666
# Processing cluster: 667
# Processing cluster: 668
# Processing cluster: 669
# Processing cluster: 670
# Processing cluster: 671
# Processing cluster: 672
# Processing cluster: 673
# Processing cluster: 674
# Processing cluster: 675
# Processing cluster: 676
# Processing cluster: 677
# Processing cluster: 678
# Processing cluster: 679
# Processing cluster: 680
# Processing cluster: 681
# Processing cluster: 682
# Processing cluster: 683
# Processing cluster: 684
# Processing cluster: 685
# Processing cluster: 686
# Processing cluster: 687
# Processing cluster: 688
# Processing cluster: 689
# Processing cluster: 690
# Processing cluster: 691
# Processing cluster: 692
# Processing cluster: 693
# Processing cluster: 694
# Processing cluster: 695
# Processing cluster: 696
# Processing cluster: 697
# Processing cluster: 698
# Processing cluster: 699
# Processing cluster: 700
# Processing cluster: 701
# Processing cluster: 702
# Processing cluster: 703
# Processing cluster: 704
# Processing cluster: 705
# Processing cluster: 706
# Processing cluster: 707
# Processing cluster: 708
# Processing cluster: 709
# Processing cluster: 710
# Processing cluster: 711
# Processing cluster: 712
# Processing cluster: 713
# Processing cluster: 714
# Processing cluster: 715
# Processing cluster: 716
# Processing cluster: 717
# Processing cluster: 718
# Processing cluster: 719
# Processing cluster: 720
# Processing cluster: 721
# Processing cluster: 722
# Processing cluster: 723
# Processing cluster: 724
# Processing cluster: 725
# Processing cluster: 726
# Processing cluster: 727
# Processing cluster: 728
# Processing cluster: 729
# Processing cluster: 730
# Processing cluster: 731
# Processing cluster: 732
# Processing cluster: 733
# Processing cluster: 734
# Processing cluster: 735
# Processing cluster: 736
# Processing cluster: 737
# Processing cluster: 738
# Processing cluster: 739
# Processing cluster: 740
# Processing cluster: 741
# Processing cluster: 742
# Processing cluster: 743
# Processing cluster: 744
# Processing cluster: 745
# Processing cluster: 746
# Processing cluster: 747
# Processing cluster: 748
# Processing cluster: 749
# Processing cluster: 750
# Processing cluster: 751
# Processing cluster: 752
# Processing cluster: 753
# Processing cluster: 754
# Processing cluster: 755
# Processing cluster: 756
# Processing cluster: 757
# Processing cluster: 758
# Processing cluster: 759
# Processing cluster: 760
# Processing cluster: 761
# Processing cluster: 762
# Processing cluster: 763
# Processing cluster: 764
# Processing cluster: 765
# Processing cluster: 766
# Processing cluster: 767
# Processing cluster: 768
# Processing cluster: 769
# Processing cluster: 770
# Processing cluster: 771
# Processing cluster: 772
# Processing cluster: 773
# Processing cluster: 774
# Processing cluster: 775
# Processing cluster: 776
# Processing cluster: 777
# Processing cluster: 778
# Processing cluster: 779
# Processing cluster: 780
# Processing cluster: 781
# Processing cluster: 782
# Processing cluster: 783
# Processing cluster: 784
# Processing cluster: 785
# Processing cluster: 786
# Processing cluster: 787
# Processing cluster: 788
# Processing cluster: 789
# Processing cluster: 790
# Processing cluster: 791
# Processing cluster: 792
# Processing cluster: 793
# Processing cluster: 794
# Processing cluster: 795
# Processing cluster: 796
# Processing cluster: 797
# Processing cluster: 798
# Processing cluster: 799
# Processing cluster: 800
# Processing cluster: 801
# Processing cluster: 802
# Processing cluster: 803
# Processing cluster: 804
# Processing cluster: 805
# Processing cluster: 806
# Processing cluster: 807
# Processing cluster: 808
# Processing cluster: 809
# Processing cluster: 810
# Processing cluster: 811
# Processing cluster: 812
# Processing cluster: 813
# Processing cluster: 814
# Processing cluster: 815
# Processing cluster: 816
# Processing cluster: 817
# Processing cluster: 818
# Processing cluster: 819
# Processing cluster: 820
# Processing cluster: 821
# Processing cluster: 822
# Processing cluster: 823
# Processing cluster: 824
# Processing cluster: 825
# Processing cluster: 826
# Processing cluster: 827
# Processing cluster: 828
# Processing cluster: 829
# Processing cluster: 830
# Processing cluster: 831
# Processing cluster: 832
# Processing cluster: 833
# Processing cluster: 834
# Processing cluster: 835
# Processing cluster: 836
# Processing cluster: 837
# Processing cluster: 838
# Processing cluster: 839
# Processing cluster: 840
# Processing cluster: 841
# Processing cluster: 842
# Processing cluster: 843
# Processing cluster: 844
# Processing cluster: 845
# Processing cluster: 846
# Processing cluster: 847
# Processing cluster: 848
# Processing cluster: 849
# Processing cluster: 850
# Processing cluster: 851
# Processing cluster: 852
# Processing cluster: 853
# Processing cluster: 854
# Processing cluster: 855
# Processing cluster: 856
# Processing cluster: 857
# Processing cluster: 858
# Processing cluster: 859
# Processing cluster: 860
# Processing cluster: 861
# Processing cluster: 862
# Processing cluster: 863
# Processing cluster: 864
# Processing cluster: 865
# Processing cluster: 866
# Processing cluster: 867
# Processing cluster: 868
# Processing cluster: 869
# Processing cluster: 870
# Processing cluster: 871
# Processing cluster: 872
# Processing cluster: 873
# Processing cluster: 874
# Processing cluster: 875
# Processing cluster: 876
# Processing cluster: 877
# Processing cluster: 878
# Processing cluster: 879
# Processing cluster: 880
# Processing cluster: 881
# Processing cluster: 882
# Processing cluster: 883
# Processing cluster: 884
# Processing cluster: 885
# Processing cluster: 886
# Processing cluster: 887
# Processing cluster: 888
# Processing cluster: 889
# Processing cluster: 890
# Processing cluster: 891
# Processing cluster: 892
# Processing cluster: 893
# Processing cluster: 894
# Processing cluster: 895
# Processing cluster: 896
# Processing cluster: 897
# Processing cluster: 898
# Processing cluster: 899
# Processing cluster: 900
# Processing cluster: 901
# Processing cluster: 902
# Processing cluster: 903
# Processing cluster: 904
# Processing cluster: 905
# Processing cluster: 906
# Processing cluster: 907
# Processing cluster: 908
# Processing cluster: 909
# Processing cluster: 910
# Processing cluster: 911
# Processing cluster: 912
# Processing cluster: 913
# Processing cluster: 914
# Processing cluster: 915
# Processing cluster: 916
# Processing cluster: 917
# Processing cluster: 918
# Processing cluster: 919
# Processing cluster: 920
# Processing cluster: 921
# Processing cluster: 922
# Processing cluster: 923
# Processing cluster: 924
# Processing cluster: 925
# Processing cluster: 926
# Processing cluster: 927
# Processing cluster: 928
# Processing cluster: 929
# Processing cluster: 930
# Processing cluster: 931
# Processing cluster: 932
# Processing cluster: 933
# Processing cluster: 934
# Processing cluster: 935
# Processing cluster: 936
# Processing cluster: 937
# Processing cluster: 938
# Processing cluster: 939
# Processing cluster: 940
# Processing cluster: 941
# Processing cluster: 942
# Processing cluster: 943
# Processing cluster: 944
# Processing cluster: 945
# Processing cluster: 946
# Processing cluster: 947
# Processing cluster: 948
# Processing cluster: 949
# Processing cluster: 950
# Processing cluster: 951
# Processing cluster: 952
# Processing cluster: 953
# Processing cluster: 954
# Processing cluster: 955
# Processing cluster: 956
# Processing cluster: 957
# Processing cluster: 958
# Processing cluster: 959
# Processing cluster: 960
# Processing cluster: 961
# Processing cluster: 962
# Processing cluster: 963
# Processing cluster: 964
# Processing cluster: 965
# Processing cluster: 966
# Processing cluster: 967
# Processing cluster: 968
# Processing cluster: 969
# Processing cluster: 970
# Processing cluster: 971
# Processing cluster: 972
# Processing cluster: 973
# Processing cluster: 974
# Processing cluster: 975
# Processing cluster: 976
# Processing cluster: 977
# Processing cluster: 978
# Processing cluster: 979
# Processing cluster: 980
# Processing cluster: 981
# Processing cluster: 982
# Processing cluster: 983
# Processing cluster: 984
# Processing cluster: 985
# Processing cluster: 986
# Processing cluster: 987
# Processing cluster: 988
# Processing cluster: 989
# Processing cluster: 990
# Processing cluster: 991
# Processing cluster: 992
# Processing cluster: 993
# Processing cluster: 994
# Processing cluster: 995
# Processing cluster: 996
# Processing cluster: 997
# Processing cluster: 998
# Processing cluster: 999
# Processing cluster: 1000
# Processing cluster: 1001
# Processing cluster: 1002
# Processing cluster: 1003
# Processing cluster: 1004
# Processing cluster: 1005
# Processing cluster: 1006
# Processing cluster: 1007
# Processing cluster: 1008
# Processing cluster: 1009
# Processing cluster: 1010
# Processing cluster: 1011
# Processing cluster: 1012
# Processing cluster: 1013
# Processing cluster: 1014
# Processing cluster: 1015
# Processing cluster: 1016
# Processing cluster: 1017
# Processing cluster: 1018
# Processing cluster: 1019
# Processing cluster: 1020
# Processing cluster: 1021
# Processing cluster: 1022
# Processing cluster: 1023
# Processing cluster: 1024
# Processing cluster: 1025
# Processing cluster: 1026

# %%
df
# Out:
#       Unnamed: 0  cluster_label  silhouette_score  davies_bouldin_score  \
# 0              0            0.0         -1.000000             -1.000000
# 1              1            0.0         -1.000000             -1.000000
# 2              2            0.0          0.444837              0.781818
# 3              3            0.0          0.165156              1.316659
# 4              4            1.0          0.165156              1.316659
# ...          ...            ...               ...                   ...
# 1022        1022            0.0         -1.000000             -1.000000
# 1023        1023            0.0         -1.000000             -1.000000
# 1024        1024            0.0         -1.000000             -1.000000
# 1025        1025            0.0         -1.000000             -1.000000
# 1026        1026            0.0         -1.000000             -1.000000
#
#       calinski_harabasz_score  clusters_in_window      win_eps  \
# 0                   -1.000000                 1.0   200.000000
# 1                   -1.000000                 1.0   200.000000
# 2                    6.808653                 2.0   200.000000
# 3                    8.680263                 3.0  2967.335778
# 4                    8.680263                 3.0  2967.335778
# ...                       ...                 ...          ...
# 1022                -1.000000                 1.0   200.000000
# 1023                -1.000000                 1.0   200.000000
# 1024                -1.000000                 1.0   200.000000
# 1025                -1.000000                 1.0   200.000000
# 1026                -1.000000                 1.0   200.000000
#
#       min_dist_between_points  min_dist_between_centroids  \
# 0                         inf                         inf
# 1                         inf                         inf
# 2                         inf                         inf
# 3                 2840.789495                 2967.335778
# 4                 2840.789495                 2967.335778
# ...                       ...                         ...
# 1022                      inf                         inf
# 1023                      inf                         inf
# 1024                      inf                         inf
# 1025                      inf                         inf
# 1026                      inf                         inf
#
#       max_dist_in_cluster  ... angular_velocity distance_traveled  \
# 0               12.101281  ...       -26.579739         68.370993
# 1               12.101281  ...       -62.846826         70.967344
# 2               28.183760  ...         4.001919         95.206813
# 3               27.369578  ...        28.347993         72.534173
# 4              237.112234  ...        27.392361        240.326894
# ...                   ...  ...              ...               ...
# 1022            42.536324  ...        29.950391        143.264998
# 1023            49.236047  ...       -52.210718        116.697738
# 1024            49.236047  ...        83.847873         89.529652
# 1025            22.902119  ...       -48.959870         36.516365
# 1026             5.116988  ...        71.246377         10.861117
#
#       displacement        jerk vertical_acceleration  up_down_direction  \
# 0         6.014485    1.056481             -1.708180          -0.141938
# 1         3.762174   33.877155              0.184990           0.060606
# 2         7.130861  -31.291671              0.109962          -0.111111
# 3         7.261333 -136.961955              0.020818          -0.066667
# 4       237.112234  679.849230             -5.111020           0.000000
# ...            ...         ...                   ...                ...
# 1022     22.095701   64.512841             -5.436916          -0.363636
# 1023     10.512082   18.110286             -2.827516          -0.623879
# 1024     32.137960  167.588443             -9.191173           0.073398
# 1025     17.288406  -34.804915              8.654173           0.585540
# 1026      3.768815 -196.307251             -0.891354           0.000000
#
#       angle_to_horizon  average_speed  average_velocity_magnitude  \
# 0            -5.866685      19.161423                   19.161423
# 1            -0.431601      21.505120                   21.505120
# 2             6.732345      35.207184                   35.207184
# 3             8.582566      48.276964                   48.276964
# 4            -1.357954     266.961087                  266.961087
# ...                ...            ...                         ...
# 1022         -2.163474      43.455179                   43.455179
# 1023         -4.256408      38.863670                   38.863670
# 1024         -2.017067      29.308341                   29.308341
# 1025          8.732949      19.377377                   19.377377
# 1026          4.232295      12.280613                   12.280613
#
#       average_velocity_direction
# 0                     171.084744
# 1                     165.486296
# 2                     144.013643
# 3                     135.145528
# 4                     180.452771
# ...                          ...
# 1022                  176.984868
# 1023                  159.725559
# 1024                  183.070468
# 1025                  220.853267
# 1026                  263.557150
#
# [1027 rows x 32 columns]

# %% [markdown]
# # Comparing Extracted Kinematic Features
# (for each cluster in dataset file)

# %%
common_kestrel_ranges = {
    'avg_height': (100, 500),  # in meters
    'turn_rate': (0.01, 0.2),  # in radians per second
    'bearing': (0, 360),  # in degrees
    'trajectory_curvature': (0.001, 0.05),  # in radians per meter
    'angular_acceleration': (-0.01, 0.01),  # in radians per second^2
    'angular_velocity': (-0.1, 0.1),  # in radians per second
    'distance_traveled': (1000, 10000),  # in meters
    'displacement': (500, 5000),  # in meters
    'jerk': (-0.001, 0.001),  # in meters per second^3
    'vertical_acceleration': (-0.5, 0.5),  # in meters per second^2
    'up_down_direction': (-1, 1),  # Kendall's Tau coefficient
    'angle_to_horizon': (-10, 10),  # in degrees
    'average_speed': (5, 25),  # in meters per second
    'average_velocity_magnitude': (5, 25),  # in meters per second
    'average_velocity_direction': (0, 360)  # in degrees
}

# %%
herring_gull_ranges = {
    'avg_height': (50, 300),  # in meters
    'turn_rate': (0.01, 0.15),  # in radians per second
    'bearing': (0, 360),  # in degrees
    'trajectory_curvature': (0.002, 0.04),  # in radians per meter
    'angular_acceleration': (-0.02, 0.02),  # in radians per second^2
    'angular_velocity': (-0.15, 0.15),  # in radians per second
    'distance_traveled': (800, 8000),  # in meters
    'displacement': (400, 4000),  # in meters
    'jerk': (-0.002, 0.002),  # in meters per second^3
    'vertical_acceleration': (-0.4, 0.4),  # in meters per second^2
    'up_down_direction': (-1, 1),  # Kendall's Tau coefficient
    'angle_to_horizon': (-15, 15),  # in degrees
    'average_speed': (4, 20),  # in meters per second
    'average_velocity_magnitude': (4, 20),  # in meters per second
    'average_velocity_direction': (0, 360)  # in degrees
}

# %%
white_stork_ranges = {
    'avg_height': (100, 1000),  # in meters
    'turn_rate': (0.01, 0.12),  # in radians per second
    'bearing': (0, 360),  # in degrees
    'trajectory_curvature': (0.001, 0.03),  # in radians per meter
    'angular_acceleration': (-0.01, 0.01),  # in radians per second^2
    'angular_velocity': (-0.12, 0.12),  # in radians per second
    'distance_traveled': (1500, 15000),  # in meters
    'displacement': (750, 7500),  # in meters
    'jerk': (-0.0015, 0.0015),  # in meters per second^3
    'vertical_acceleration': (-0.3, 0.3),  # in meters per second^2
    'up_down_direction': (-1, 1),  # Kendall's Tau coefficient
    'angle_to_horizon': (-12, 12),  # in degrees
    'average_speed': (6, 30),  # in meters per second
    'average_velocity_magnitude': (6, 30),  # in meters per second
    'average_velocity_direction': (0, 360)  # in degrees
}

# %%
homing_pigeon_ranges = {
    'avg_height': (50, 200),  # in meters
    'turn_rate': (0.02, 0.3),  # in radians per second
    'bearing': (0, 360),  # in degrees
    'trajectory_curvature': (0.003, 0.06),  # in radians per meter
    'angular_acceleration': (-0.015, 0.015),  # in radians per second^2
    'angular_velocity': (-0.2, 0.2),  # in radians per second
    'distance_traveled': (500, 5000),  # in meters
    'displacement': (250, 2500),  # in meters
    'jerk': (-0.002, 0.002),  # in meters per second^3
    'vertical_acceleration': (-0.3, 0.3),  # in meters per second^2
    'up_down_direction': (-1, 1),  # Kendall's Tau coefficient
    'angle_to_horizon': (-10, 10),  # in degrees
    'average_speed': (8, 18),  # in meters per second
    'average_velocity_magnitude': (8, 18),  # in meters per second
    'average_velocity_direction': (0, 360)  # in degrees
}

# %%
import pandas as pd
import numpy as np

# Assuming clusters_with_kinematic_features_df is your DataFrame from previous code

# Define the ranges for Common Kestrel

# Function to check if cluster values fall within the species ranges
def is_within_ranges(cluster, species_ranges):
    for feature, (min_val, max_val) in species_ranges.items():
        if feature in cluster:  # Ensure the feature exists in the cluster
            if not (min_val <= cluster[feature] <= max_val):
                print(f"{feature} out of range: {cluster[feature]} not in ({min_val}, {max_val})")
                return False
        else:
            print(f"Feature {feature} not found in the cluster")
            return False
    return True

# Apply the check to each cluster
clusters_with_features_df['matches_white_storks'] = clusters_with_features_df.apply(
    lambda row: is_within_ranges(row, white_stork_ranges), axis=1
)

# Save or inspect the updated DataFrame
clusters_with_features_df.to_csv('3clusters_with_kinematic_features_and_species_check.csv', index=False)

# Print the result of clusters that match the Common Kestrel ranges
print(clusters_with_features_df[clusters_with_features_df['matches_white_storks']])
# Out:
# turn_rate out of range: 544.9619270105974 not in (0.01, 0.12)
# turn_rate out of range: 649.9864493214018 not in (0.01, 0.12)
# turn_rate out of range: 764.9599786765039 not in (0.01, 0.12)
# turn_rate out of range: 900.9249212009282 not in (0.01, 0.12)
# turn_rate out of range: 28.73485220758437 not in (0.01, 0.12)
# turn_rate out of range: 43.94941021110379 not in (0.01, 0.12)
# turn_rate out of range: 55.94931201794734 not in (0.01, 0.12)
# turn_rate out of range: 68.16592644103592 not in (0.01, 0.12)
# turn_rate out of range: 106.99991586882038 not in (0.01, 0.12)
# turn_rate out of range: 103.35160332646592 not in (0.01, 0.12)
# turn_rate out of range: 86.7595514263916 not in (0.01, 0.12)
# turn_rate out of range: 60.09733792778932 not in (0.01, 0.12)
# turn_rate out of range: 53.90019789462046 not in (0.01, 0.12)
# turn_rate out of range: 276.44382570039835 not in (0.01, 0.12)
# turn_rate out of range: 320.8681775321792 not in (0.01, 0.12)
# turn_rate out of range: 469.03273590608717 not in (0.01, 0.12)
# turn_rate out of range: 332.7828895658229 not in (0.01, 0.12)
# turn_rate out of range: 321.8681060170587 not in (0.01, 0.12)
# turn_rate out of range: 413.1143145412396 not in (0.01, 0.12)
# turn_rate out of range: 360.99943250161897 not in (0.01, 0.12)
# turn_rate out of range: 500.5592115549477 not in (0.01, 0.12)
# turn_rate out of range: 269.1175646651867 not in (0.01, 0.12)
# turn_rate out of range: 241.7563841218228 not in (0.01, 0.12)
# turn_rate out of range: 307.94645630160943 not in (0.01, 0.12)
# turn_rate out of range: 398.9542749964299 not in (0.01, 0.12)
# turn_rate out of range: 326.3194991534183 not in (0.01, 0.12)
# turn_rate out of range: 443.2784911734064 not in (0.01, 0.12)
# turn_rate out of range: 461.2735460281668 not in (0.01, 0.12)
# turn_rate out of range: 696.5389406396562 not in (0.01, 0.12)
# turn_rate out of range: 253.80509604984098 not in (0.01, 0.12)
# turn_rate out of range: 236.78813511627268 not in (0.01, 0.12)
# turn_rate out of range: 363.50970660339027 not in (0.01, 0.12)
# turn_rate out of range: 604.0325080795326 not in (0.01, 0.12)
# turn_rate out of range: 637.6594709098434 not in (0.01, 0.12)
# turn_rate out of range: 408.51066584426735 not in (0.01, 0.12)
# turn_rate out of range: 427.731338978409 not in (0.01, 0.12)
# turn_rate out of range: 427.731338978409 not in (0.01, 0.12)
# turn_rate out of range: 150.56925435708047 not in (0.01, 0.12)
# turn_rate out of range: 643.4721967640297 not in (0.01, 0.12)
# turn_rate out of range: 386.19914753354783 not in (0.01, 0.12)
# turn_rate out of range: 436.31485788604385 not in (0.01, 0.12)
# turn_rate out of range: 500.2207673723592 not in (0.01, 0.12)
# turn_rate out of range: 482.0669229103476 not in (0.01, 0.12)
# turn_rate out of range: 393.83605063248405 not in (0.01, 0.12)
# turn_rate out of range: 346.7865469690881 not in (0.01, 0.12)
# turn_rate out of range: 395.34789183016295 not in (0.01, 0.12)
# turn_rate out of range: 454.2553116882185 not in (0.01, 0.12)
# turn_rate out of range: 530.7294988698002 not in (0.01, 0.12)
# turn_rate out of range: 676.9306507585065 not in (0.01, 0.12)
# turn_rate out of range: 718.9318522553946 not in (0.01, 0.12)
# turn_rate out of range: 594.5516530550595 not in (0.01, 0.12)
# turn_rate out of range: 518.7092317377706 not in (0.01, 0.12)
# turn_rate out of range: 422.2079082104036 not in (0.01, 0.12)
# turn_rate out of range: 492.98900540260047 not in (0.01, 0.12)
# turn_rate out of range: 484.2991586348271 not in (0.01, 0.12)
# turn_rate out of range: 165.66907218834132 not in (0.01, 0.12)
# turn_rate out of range: 165.66907218834132 not in (0.01, 0.12)
# turn_rate out of range: 9.447090415183615 not in (0.01, 0.12)
# turn_rate out of range: 253.57759712449183 not in (0.01, 0.12)
# turn_rate out of range: 100.92876479995317 not in (0.01, 0.12)
# turn_rate out of range: 248.72253406315122 not in (0.01, 0.12)
# turn_rate out of range: 310.03302307538286 not in (0.01, 0.12)
# turn_rate out of range: 196.31737881903013 not in (0.01, 0.12)
# turn_rate out of range: 238.80832525646414 not in (0.01, 0.12)
# turn_rate out of range: 247.4991328433338 not in (0.01, 0.12)
# turn_rate out of range: 209.22103275225678 not in (0.01, 0.12)
# turn_rate out of range: 244.03499575989113 not in (0.01, 0.12)
# turn_rate out of range: 193.04805035089413 not in (0.01, 0.12)
# turn_rate out of range: 151.28366764310744 not in (0.01, 0.12)
# turn_rate out of range: 149.7114742203082 not in (0.01, 0.12)
# turn_rate out of range: 636.0649095834524 not in (0.01, 0.12)
# turn_rate out of range: 188.60365259795594 not in (0.01, 0.12)
# turn_rate out of range: 259.38942105969915 not in (0.01, 0.12)
# turn_rate out of range: 390.8473908624526 not in (0.01, 0.12)
# turn_rate out of range: 315.8264716142062 not in (0.01, 0.12)
# turn_rate out of range: 324.5286539600444 not in (0.01, 0.12)
# turn_rate out of range: 460.151917008488 not in (0.01, 0.12)
# turn_rate out of range: 145.49695842503047 not in (0.01, 0.12)
# turn_rate out of range: 204.1180740434089 not in (0.01, 0.12)
# turn_rate out of range: 581.7099325425933 not in (0.01, 0.12)
# turn_rate out of range: 819.0509505993642 not in (0.01, 0.12)
# turn_rate out of range: 890.5319916914955 not in (0.01, 0.12)
# turn_rate out of range: 222.14473096933352 not in (0.01, 0.12)
# turn_rate out of range: 222.14473096933352 not in (0.01, 0.12)
# turn_rate out of range: 314.1059956212201 not in (0.01, 0.12)
# turn_rate out of range: 61.383560327499005 not in (0.01, 0.12)
# turn_rate out of range: 53.860048527671225 not in (0.01, 0.12)
# turn_rate out of range: 65.39871144419946 not in (0.01, 0.12)
# turn_rate out of range: 237.5914001923658 not in (0.01, 0.12)
# turn_rate out of range: 90.6092683432265 not in (0.01, 0.12)
# turn_rate out of range: 397.95888230857366 not in (0.01, 0.12)
# turn_rate out of range: 381.4299585334307 not in (0.01, 0.12)
# turn_rate out of range: 453.79743850443526 not in (0.01, 0.12)
# turn_rate out of range: 462.3024092453613 not in (0.01, 0.12)
# turn_rate out of range: 453.5280233063929 not in (0.01, 0.12)
# turn_rate out of range: 408.2850758692561 not in (0.01, 0.12)
# turn_rate out of range: 477.0172950912509 not in (0.01, 0.12)
# turn_rate out of range: 524.2496628441612 not in (0.01, 0.12)
# turn_rate out of range: 509.362164075663 not in (0.01, 0.12)
# turn_rate out of range: 505.88283493974467 not in (0.01, 0.12)
# turn_rate out of range: 634.4502250824917 not in (0.01, 0.12)
# turn_rate out of range: 611.550908652543 not in (0.01, 0.12)
# turn_rate out of range: 518.3495628886835 not in (0.01, 0.12)
# turn_rate out of range: 499.5017403990846 not in (0.01, 0.12)
# turn_rate out of range: 393.02838491545424 not in (0.01, 0.12)
# turn_rate out of range: 244.84764770872954 not in (0.01, 0.12)
# turn_rate out of range: 184.8347936697942 not in (0.01, 0.12)
# turn_rate out of range: 286.1354890063067 not in (0.01, 0.12)
# turn_rate out of range: 76.25144045331034 not in (0.01, 0.12)
# turn_rate out of range: 66.77177997710692 not in (0.01, 0.12)
# turn_rate out of range: 104.0532812947621 not in (0.01, 0.12)
# turn_rate out of range: 191.5850070838224 not in (0.01, 0.12)
# turn_rate out of range: 234.39177416625452 not in (0.01, 0.12)
# turn_rate out of range: 215.58091448776412 not in (0.01, 0.12)
# turn_rate out of range: 341.87363012424925 not in (0.01, 0.12)
# turn_rate out of range: 471.33072650824636 not in (0.01, 0.12)
# turn_rate out of range: 160.05739863976584 not in (0.01, 0.12)
# turn_rate out of range: 38.931137650770296 not in (0.01, 0.12)
# turn_rate out of range: 311.30517594397554 not in (0.01, 0.12)
# turn_rate out of range: 260.7775792645595 not in (0.01, 0.12)
# turn_rate out of range: 494.869725123272 not in (0.01, 0.12)
# turn_rate out of range: 658.0506443227445 not in (0.01, 0.12)
# turn_rate out of range: 590.9881609296115 not in (0.01, 0.12)
# turn_rate out of range: 134.7314486212743 not in (0.01, 0.12)
# turn_rate out of range: 490.18537082299656 not in (0.01, 0.12)
# turn_rate out of range: 490.18537082299656 not in (0.01, 0.12)
# turn_rate out of range: 369.1355191937788 not in (0.01, 0.12)
# turn_rate out of range: 861.079989380168 not in (0.01, 0.12)
# turn_rate out of range: 369.29161508294345 not in (0.01, 0.12)
# turn_rate out of range: 389.3972315236451 not in (0.01, 0.12)
# turn_rate out of range: 386.9036836655041 not in (0.01, 0.12)
# turn_rate out of range: 418.6243534057253 not in (0.01, 0.12)
# turn_rate out of range: 507.2258496873783 not in (0.01, 0.12)
# turn_rate out of range: 437.7464153939133 not in (0.01, 0.12)
# turn_rate out of range: 406.40210230870946 not in (0.01, 0.12)
# turn_rate out of range: 436.0818292471639 not in (0.01, 0.12)
# turn_rate out of range: 405.2675176232954 not in (0.01, 0.12)
# turn_rate out of range: 361.10765190082435 not in (0.01, 0.12)
# turn_rate out of range: 580.4632743879129 not in (0.01, 0.12)
# turn_rate out of range: 556.0070140256634 not in (0.01, 0.12)
# turn_rate out of range: 523.3585115416224 not in (0.01, 0.12)
# turn_rate out of range: 518.7237384011421 not in (0.01, 0.12)
# turn_rate out of range: 519.0628724327773 not in (0.01, 0.12)
# turn_rate out of range: 512.5811164176177 not in (0.01, 0.12)
# turn_rate out of range: 492.18217372835795 not in (0.01, 0.12)
# turn_rate out of range: 601.8112747556931 not in (0.01, 0.12)
# turn_rate out of range: 509.1316352053438 not in (0.01, 0.12)
# turn_rate out of range: 434.57953832869845 not in (0.01, 0.12)
# turn_rate out of range: 437.461882916798 not in (0.01, 0.12)
# turn_rate out of range: 493.84868439537047 not in (0.01, 0.12)
# turn_rate out of range: 547.3912438855784 not in (0.01, 0.12)
# turn_rate out of range: 543.5837492657787 not in (0.01, 0.12)
# turn_rate out of range: 563.9333676819963 not in (0.01, 0.12)
# turn_rate out of range: 606.851621012671 not in (0.01, 0.12)
# turn_rate out of range: 409.3538409958785 not in (0.01, 0.12)
# turn_rate out of range: 443.1520880720303 not in (0.01, 0.12)
# turn_rate out of range: 467.2696256689678 not in (0.01, 0.12)
# turn_rate out of range: 563.8032734462665 not in (0.01, 0.12)
# turn_rate out of range: 596.3651393566356 not in (0.01, 0.12)
# turn_rate out of range: 644.1977249241905 not in (0.01, 0.12)
# turn_rate out of range: 578.3168987614342 not in (0.01, 0.12)
# turn_rate out of range: 542.2988423770818 not in (0.01, 0.12)
# turn_rate out of range: 528.8594016753334 not in (0.01, 0.12)
# turn_rate out of range: 469.4345224436382 not in (0.01, 0.12)
# turn_rate out of range: 515.3175972816243 not in (0.01, 0.12)
# turn_rate out of range: 449.0264649522107 not in (0.01, 0.12)
# turn_rate out of range: 738.1238106968328 not in (0.01, 0.12)
# turn_rate out of range: 419.2863979438114 not in (0.01, 0.12)
# turn_rate out of range: 421.97276400232516 not in (0.01, 0.12)
# turn_rate out of range: 395.80773656426317 not in (0.01, 0.12)
# turn_rate out of range: 420.2421342837095 not in (0.01, 0.12)
# turn_rate out of range: 483.8125465508084 not in (0.01, 0.12)
# turn_rate out of range: 488.66019787064323 not in (0.01, 0.12)
# turn_rate out of range: 298.52120585364605 not in (0.01, 0.12)
# turn_rate out of range: 186.66165074652886 not in (0.01, 0.12)
# turn_rate out of range: 255.7971508959725 not in (0.01, 0.12)
# turn_rate out of range: 413.1123070915574 not in (0.01, 0.12)
# turn_rate out of range: 520.9968616075653 not in (0.01, 0.12)
# turn_rate out of range: 396.13197336360383 not in (0.01, 0.12)
# turn_rate out of range: 452.22478827057176 not in (0.01, 0.12)
# turn_rate out of range: 368.29470155529145 not in (0.01, 0.12)
# turn_rate out of range: 331.4741327556736 not in (0.01, 0.12)
# turn_rate out of range: 415.060416035657 not in (0.01, 0.12)
# turn_rate out of range: 594.5284606185667 not in (0.01, 0.12)
# turn_rate out of range: 162.75424923641262 not in (0.01, 0.12)
# turn_rate out of range: 162.75424923641262 not in (0.01, 0.12)
# turn_rate out of range: 274.2669444842004 not in (0.01, 0.12)
# turn_rate out of range: 170.8400234424107 not in (0.01, 0.12)
# turn_rate out of range: 473.8103848018701 not in (0.01, 0.12)
# turn_rate out of range: 453.72500515239307 not in (0.01, 0.12)
# turn_rate out of range: 485.136392462163 not in (0.01, 0.12)
# turn_rate out of range: 515.0775546165524 not in (0.01, 0.12)
# turn_rate out of range: 478.2035017741793 not in (0.01, 0.12)
# turn_rate out of range: 513.8728109190321 not in (0.01, 0.12)
# turn_rate out of range: 420.9798332755463 not in (0.01, 0.12)
# turn_rate out of range: 401.61852921562564 not in (0.01, 0.12)
# turn_rate out of range: 422.221512346101 not in (0.01, 0.12)
# turn_rate out of range: 360.8649185124611 not in (0.01, 0.12)
# turn_rate out of range: 360.5147806557226 not in (0.01, 0.12)
# turn_rate out of range: 385.83616375093135 not in (0.01, 0.12)
# turn_rate out of range: 494.3563964704217 not in (0.01, 0.12)
# turn_rate out of range: 548.6992506667788 not in (0.01, 0.12)
# turn_rate out of range: 654.3545065426882 not in (0.01, 0.12)
# turn_rate out of range: 616.7094593395539 not in (0.01, 0.12)
# turn_rate out of range: 106.9039306812202 not in (0.01, 0.12)
# turn_rate out of range: 255.05318015666998 not in (0.01, 0.12)
# turn_rate out of range: 329.48065851441817 not in (0.01, 0.12)
# turn_rate out of range: 882.0485369653383 not in (0.01, 0.12)
# turn_rate out of range: 610.5204306734078 not in (0.01, 0.12)
# turn_rate out of range: 639.3171261138807 not in (0.01, 0.12)
# turn_rate out of range: 411.17429549172573 not in (0.01, 0.12)
# turn_rate out of range: 223.69594790176626 not in (0.01, 0.12)
# turn_rate out of range: 139.7061974797259 not in (0.01, 0.12)
# turn_rate out of range: 176.34371871217422 not in (0.01, 0.12)
# turn_rate out of range: 236.82930697239914 not in (0.01, 0.12)
# turn_rate out of range: 285.2498664834683 not in (0.01, 0.12)
# turn_rate out of range: 239.1079836087746 not in (0.01, 0.12)
# turn_rate out of range: 223.03311959773242 not in (0.01, 0.12)
# turn_rate out of range: 242.08178598060843 not in (0.01, 0.12)
# turn_rate out of range: 256.8797589107732 not in (0.01, 0.12)
# turn_rate out of range: 243.12379223864582 not in (0.01, 0.12)
# turn_rate out of range: 357.6489446243308 not in (0.01, 0.12)
# turn_rate out of range: 386.44229346084126 not in (0.01, 0.12)
# turn_rate out of range: 367.16615082767277 not in (0.01, 0.12)
# turn_rate out of range: 238.39948210479238 not in (0.01, 0.12)
# turn_rate out of range: 301.1294953702876 not in (0.01, 0.12)
# turn_rate out of range: 344.526127415298 not in (0.01, 0.12)
# turn_rate out of range: 334.82102560061196 not in (0.01, 0.12)
# turn_rate out of range: 341.5313529397344 not in (0.01, 0.12)
# turn_rate out of range: 241.62354969366126 not in (0.01, 0.12)
# turn_rate out of range: 428.82991015601647 not in (0.01, 0.12)
# turn_rate out of range: 526.4608200979904 not in (0.01, 0.12)
# turn_rate out of range: 8.080031789552208 not in (0.01, 0.12)
# turn_rate out of range: 499.2081285939684 not in (0.01, 0.12)
# turn_rate out of range: 499.2081285939684 not in (0.01, 0.12)
# turn_rate out of range: 522.6944286969419 not in (0.01, 0.12)
# turn_rate out of range: 555.1593367586521 not in (0.01, 0.12)
# turn_rate out of range: 608.9877873037004 not in (0.01, 0.12)
# turn_rate out of range: 581.1245274697282 not in (0.01, 0.12)
# turn_rate out of range: 483.70145295060877 not in (0.01, 0.12)
# turn_rate out of range: 517.5392584796218 not in (0.01, 0.12)
# turn_rate out of range: 496.1212662607283 not in (0.01, 0.12)
# turn_rate out of range: 467.00289480446264 not in (0.01, 0.12)
# turn_rate out of range: 467.116573753593 not in (0.01, 0.12)
# turn_rate out of range: 491.18237278789985 not in (0.01, 0.12)
# turn_rate out of range: 414.0691777307037 not in (0.01, 0.12)
# turn_rate out of range: 601.2840084213173 not in (0.01, 0.12)
# turn_rate out of range: 405.9833522736727 not in (0.01, 0.12)
# turn_rate out of range: 478.60939775911805 not in (0.01, 0.12)
# turn_rate out of range: 521.6332545921002 not in (0.01, 0.12)
# turn_rate out of range: 698.774916241194 not in (0.01, 0.12)
# turn_rate out of range: 513.7480372772328 not in (0.01, 0.12)
# turn_rate out of range: 257.1802404967732 not in (0.01, 0.12)
# turn_rate out of range: 257.1802404967732 not in (0.01, 0.12)
# turn_rate out of range: 257.7004474217012 not in (0.01, 0.12)
# turn_rate out of range: 192.96014229431626 not in (0.01, 0.12)
# turn_rate out of range: 272.4585217443559 not in (0.01, 0.12)
# turn_rate out of range: 309.03363871833807 not in (0.01, 0.12)
# turn_rate out of range: 210.28599626999397 not in (0.01, 0.12)
# turn_rate out of range: 294.8857775055517 not in (0.01, 0.12)
# turn_rate out of range: 452.8776297638277 not in (0.01, 0.12)
# turn_rate out of range: 506.1006759460057 not in (0.01, 0.12)
# turn_rate out of range: 444.4727773249926 not in (0.01, 0.12)
# turn_rate out of range: 463.94599225277824 not in (0.01, 0.12)
# turn_rate out of range: 332.97273698087525 not in (0.01, 0.12)
# turn_rate out of range: 240.51421264559545 not in (0.01, 0.12)
# turn_rate out of range: 270.8419311050657 not in (0.01, 0.12)
# turn_rate out of range: 474.3668851100433 not in (0.01, 0.12)
# turn_rate out of range: 67.81785573233753 not in (0.01, 0.12)
# turn_rate out of range: 93.91849099437098 not in (0.01, 0.12)
# turn_rate out of range: 136.5421225570402 not in (0.01, 0.12)
# turn_rate out of range: 176.28139915395997 not in (0.01, 0.12)
# turn_rate out of range: 186.96098221189368 not in (0.01, 0.12)
# turn_rate out of range: 154.29829324726455 not in (0.01, 0.12)
# turn_rate out of range: 120.9170925180695 not in (0.01, 0.12)
# turn_rate out of range: 422.200603659596 not in (0.01, 0.12)
# turn_rate out of range: 422.58128857369746 not in (0.01, 0.12)
# turn_rate out of range: 443.12583578114175 not in (0.01, 0.12)
# turn_rate out of range: 421.6159083881355 not in (0.01, 0.12)
# turn_rate out of range: 456.4874106500629 not in (0.01, 0.12)
# turn_rate out of range: 416.0800092386323 not in (0.01, 0.12)
# turn_rate out of range: 430.3929921041593 not in (0.01, 0.12)
# turn_rate out of range: 447.5954567906676 not in (0.01, 0.12)
# turn_rate out of range: 424.3539005828188 not in (0.01, 0.12)
# turn_rate out of range: 419.38420134108645 not in (0.01, 0.12)
# turn_rate out of range: 494.2067473812795 not in (0.01, 0.12)
# turn_rate out of range: 368.3216283380852 not in (0.01, 0.12)
# turn_rate out of range: 321.948063608941 not in (0.01, 0.12)
# turn_rate out of range: 457.1069800885893 not in (0.01, 0.12)
# turn_rate out of range: 358.8249395985867 not in (0.01, 0.12)
# turn_rate out of range: 318.64527158609695 not in (0.01, 0.12)
# turn_rate out of range: 411.28463312665207 not in (0.01, 0.12)
# turn_rate out of range: 275.97631499131154 not in (0.01, 0.12)
# turn_rate out of range: 275.97631499131154 not in (0.01, 0.12)
# turn_rate out of range: 466.0332226413954 not in (0.01, 0.12)
# turn_rate out of range: 98.66119071722245 not in (0.01, 0.12)
# turn_rate out of range: 220.6110268404263 not in (0.01, 0.12)
# turn_rate out of range: 345.86967279551595 not in (0.01, 0.12)
# turn_rate out of range: 308.25481424077384 not in (0.01, 0.12)
# turn_rate out of range: 260.9271466397789 not in (0.01, 0.12)
# turn_rate out of range: 385.9108347082697 not in (0.01, 0.12)
# turn_rate out of range: 175.47314764804634 not in (0.01, 0.12)
# turn_rate out of range: 109.31057133402088 not in (0.01, 0.12)
# turn_rate out of range: 300.5829330097779 not in (0.01, 0.12)
# turn_rate out of range: 175.47314764804634 not in (0.01, 0.12)
# turn_rate out of range: 175.47314764804634 not in (0.01, 0.12)
# turn_rate out of range: 348.4010234287172 not in (0.01, 0.12)
# turn_rate out of range: 1498.4252097007045 not in (0.01, 0.12)
# turn_rate out of range: 40.90363183482809 not in (0.01, 0.12)
# turn_rate out of range: 1498.4252097007045 not in (0.01, 0.12)
# turn_rate out of range: 1498.4252097007045 not in (0.01, 0.12)
# turn_rate out of range: 210.5137364476173 not in (0.01, 0.12)
# turn_rate out of range: 252.91531371710747 not in (0.01, 0.12)
# turn_rate out of range: 295.3168909865976 not in (0.01, 0.12)
# turn_rate out of range: 125.66553425836169 not in (0.01, 0.12)
# turn_rate out of range: 125.66553425836169 not in (0.01, 0.12)
# turn_rate out of range: 327.71349184522944 not in (0.01, 0.12)
# turn_rate out of range: 371.59464747771983 not in (0.01, 0.12)
# turn_rate out of range: 419.7688259251617 not in (0.01, 0.12)
# turn_rate out of range: 101.32478138873061 not in (0.01, 0.12)
# turn_rate out of range: 532.2148415934344 not in (0.01, 0.12)
# turn_rate out of range: 119.34061355889588 not in (0.01, 0.12)
# turn_rate out of range: 247.1774661775702 not in (0.01, 0.12)
# turn_rate out of range: 266.43955305245794 not in (0.01, 0.12)
# turn_rate out of range: 330.54572863409504 not in (0.01, 0.12)
# turn_rate out of range: 365.1219117418517 not in (0.01, 0.12)
# turn_rate out of range: 427.2576399146448 not in (0.01, 0.12)
# turn_rate out of range: 542.0280147862175 not in (0.01, 0.12)
# turn_rate out of range: 600.4936531969145 not in (0.01, 0.12)
# turn_rate out of range: 527.2751864509062 not in (0.01, 0.12)
# turn_rate out of range: 567.2878344320216 not in (0.01, 0.12)
# turn_rate out of range: 545.4729386197413 not in (0.01, 0.12)
# turn_rate out of range: 541.5847675470335 not in (0.01, 0.12)
# turn_rate out of range: 482.28592495880474 not in (0.01, 0.12)
# turn_rate out of range: 575.4971843344575 not in (0.01, 0.12)
# turn_rate out of range: 494.7797449271714 not in (0.01, 0.12)
# turn_rate out of range: 449.0242355883808 not in (0.01, 0.12)
# turn_rate out of range: 335.2135997036643 not in (0.01, 0.12)
# turn_rate out of range: 675.5362824368009 not in (0.01, 0.12)
# turn_rate out of range: 497.80306114377953 not in (0.01, 0.12)
# turn_rate out of range: 506.5516970640602 not in (0.01, 0.12)
# turn_rate out of range: 500.9035266223853 not in (0.01, 0.12)
# turn_rate out of range: 282.5579264013552 not in (0.01, 0.12)
# turn_rate out of range: 445.842946506085 not in (0.01, 0.12)
# turn_rate out of range: 497.07342482573165 not in (0.01, 0.12)
# turn_rate out of range: 415.0910137551012 not in (0.01, 0.12)
# turn_rate out of range: 422.45826075402255 not in (0.01, 0.12)
# turn_rate out of range: 311.5629068187833 not in (0.01, 0.12)
# turn_rate out of range: 293.4145808545225 not in (0.01, 0.12)
# turn_rate out of range: 254.15222968447614 not in (0.01, 0.12)
# turn_rate out of range: 238.8342547366353 not in (0.01, 0.12)
# turn_rate out of range: 247.57924683187957 not in (0.01, 0.12)
# turn_rate out of range: 221.6382941918671 not in (0.01, 0.12)
# turn_rate out of range: 278.18678275233293 not in (0.01, 0.12)
# turn_rate out of range: 444.4949959515974 not in (0.01, 0.12)
# turn_rate out of range: 473.11013793965776 not in (0.01, 0.12)
# turn_rate out of range: 407.46745632037994 not in (0.01, 0.12)
# turn_rate out of range: 227.98989450446325 not in (0.01, 0.12)
# turn_rate out of range: 84.71047703201008 not in (0.01, 0.12)
# turn_rate out of range: 215.11275697705534 not in (0.01, 0.12)
# turn_rate out of range: 233.3775029004502 not in (0.01, 0.12)
# turn_rate out of range: 84.51559476482265 not in (0.01, 0.12)
# turn_rate out of range: 63.76923673288927 not in (0.01, 0.12)
# turn_rate out of range: 63.76923673288927 not in (0.01, 0.12)
# turn_rate out of range: 201.86389799484755 not in (0.01, 0.12)
# turn_rate out of range: 201.86389799484755 not in (0.01, 0.12)
# turn_rate out of range: 27.041475806382987 not in (0.01, 0.12)
# turn_rate out of range: 98.55267353591361 not in (0.01, 0.12)
# turn_rate out of range: 329.53859795237094 not in (0.01, 0.12)
# turn_rate out of range: 359.7110940400477 not in (0.01, 0.12)
# turn_rate out of range: 360.79149019151214 not in (0.01, 0.12)
# turn_rate out of range: 121.62173138425142 not in (0.01, 0.12)
# turn_rate out of range: 340.0564010483683 not in (0.01, 0.12)
# turn_rate out of range: 284.7655965783018 not in (0.01, 0.12)
# turn_rate out of range: 214.23034474851025 not in (0.01, 0.12)
# turn_rate out of range: 83.2514408436653 not in (0.01, 0.12)
# turn_rate out of range: 219.08634449284415 not in (0.01, 0.12)
# turn_rate out of range: 592.0109121540698 not in (0.01, 0.12)
# turn_rate out of range: 549.9067614568444 not in (0.01, 0.12)
# turn_rate out of range: 489.90132307685525 not in (0.01, 0.12)
# turn_rate out of range: 443.3947202068799 not in (0.01, 0.12)
# turn_rate out of range: 391.0531512230752 not in (0.01, 0.12)
# turn_rate out of range: 412.9932462075194 not in (0.01, 0.12)
# turn_rate out of range: 418.0511606000874 not in (0.01, 0.12)
# turn_rate out of range: 446.00026390019474 not in (0.01, 0.12)
# turn_rate out of range: 508.6569546220826 not in (0.01, 0.12)
# turn_rate out of range: 457.0137787920985 not in (0.01, 0.12)
# turn_rate out of range: 568.8540486553786 not in (0.01, 0.12)
# turn_rate out of range: 557.8225073039174 not in (0.01, 0.12)
# turn_rate out of range: 597.4629385293713 not in (0.01, 0.12)
# turn_rate out of range: 572.0294133449211 not in (0.01, 0.12)
# turn_rate out of range: 429.9244833390696 not in (0.01, 0.12)
# turn_rate out of range: 325.3527379686425 not in (0.01, 0.12)
# turn_rate out of range: 265.4424825716359 not in (0.01, 0.12)
# turn_rate out of range: 173.77195216876018 not in (0.01, 0.12)
# turn_rate out of range: 245.80968841266986 not in (0.01, 0.12)
# turn_rate out of range: 241.08753381096835 not in (0.01, 0.12)
# turn_rate out of range: 300.9694963173253 not in (0.01, 0.12)
# turn_rate out of range: 193.49381939175925 not in (0.01, 0.12)
# turn_rate out of range: 332.87384823537093 not in (0.01, 0.12)
# turn_rate out of range: 216.1765448094135 not in (0.01, 0.12)
# turn_rate out of range: 239.1776060797369 not in (0.01, 0.12)
# turn_rate out of range: 247.0156453546796 not in (0.01, 0.12)
# turn_rate out of range: 181.3485553672543 not in (0.01, 0.12)
# turn_rate out of range: 689.2508408642448 not in (0.01, 0.12)
# turn_rate out of range: 767.6378322145586 not in (0.01, 0.12)
# turn_rate out of range: 779.5160258516804 not in (0.01, 0.12)
# turn_rate out of range: 705.2893554813147 not in (0.01, 0.12)
# turn_rate out of range: 634.573052844544 not in (0.01, 0.12)
# turn_rate out of range: 617.628634544573 not in (0.01, 0.12)
# turn_rate out of range: 617.628634544573 not in (0.01, 0.12)
# turn_rate out of range: 374.4105695869872 not in (0.01, 0.12)
# turn_rate out of range: 374.4105695869872 not in (0.01, 0.12)
# turn_rate out of range: 374.4105695869872 not in (0.01, 0.12)
# turn_rate out of range: 260.37294399223424 not in (0.01, 0.12)
# turn_rate out of range: 181.0934981932236 not in (0.01, 0.12)
# turn_rate out of range: 136.5052454110032 not in (0.01, 0.12)
# turn_rate out of range: 16.42787197602316 not in (0.01, 0.12)
# avg_height out of range: 1014.5666666666666 not in (100, 1000)
# avg_height out of range: 1027.1625 not in (100, 1000)
# avg_height out of range: 1025.7142857142856 not in (100, 1000)
# avg_height out of range: 1034.075 not in (100, 1000)
# turn_rate out of range: 524.0025124540383 not in (0.01, 0.12)
# turn_rate out of range: 298.8630318104465 not in (0.01, 0.12)
# turn_rate out of range: 270.14050884572976 not in (0.01, 0.12)
# turn_rate out of range: 322.6005685648165 not in (0.01, 0.12)
# turn_rate out of range: 340.89742288594766 not in (0.01, 0.12)
# turn_rate out of range: 396.0993076056292 not in (0.01, 0.12)
# turn_rate out of range: 265.55269728055316 not in (0.01, 0.12)
# turn_rate out of range: 233.38150722461947 not in (0.01, 0.12)
# turn_rate out of range: 588.1881405402231 not in (0.01, 0.12)
# turn_rate out of range: 352.61931737813666 not in (0.01, 0.12)
# turn_rate out of range: 456.5931123721466 not in (0.01, 0.12)
# turn_rate out of range: 490.67287217611283 not in (0.01, 0.12)
# turn_rate out of range: 517.7098495200046 not in (0.01, 0.12)
# turn_rate out of range: 446.3675926001047 not in (0.01, 0.12)
# turn_rate out of range: 365.52365108101856 not in (0.01, 0.12)
# turn_rate out of range: 326.9147690727463 not in (0.01, 0.12)
# turn_rate out of range: 366.83994553052145 not in (0.01, 0.12)
# turn_rate out of range: 500.30834324591126 not in (0.01, 0.12)
# turn_rate out of range: 548.2903869460914 not in (0.01, 0.12)
# turn_rate out of range: 504.60980848038906 not in (0.01, 0.12)
# turn_rate out of range: 682.9815972769385 not in (0.01, 0.12)
# turn_rate out of range: 409.97317856572255 not in (0.01, 0.12)
# turn_rate out of range: 465.0182774347566 not in (0.01, 0.12)
# turn_rate out of range: 480.75731844342226 not in (0.01, 0.12)
# turn_rate out of range: 410.10065716583534 not in (0.01, 0.12)
# turn_rate out of range: 299.48481667501466 not in (0.01, 0.12)
# turn_rate out of range: 860.8301063041113 not in (0.01, 0.12)
# turn_rate out of range: 926.7221822177137 not in (0.01, 0.12)
# turn_rate out of range: 337.37741822338194 not in (0.01, 0.12)
# turn_rate out of range: 278.03028906592635 not in (0.01, 0.12)
# turn_rate out of range: 288.1412357999827 not in (0.01, 0.12)
# turn_rate out of range: 416.13861952182754 not in (0.01, 0.12)
# turn_rate out of range: 444.98063013211885 not in (0.01, 0.12)
# turn_rate out of range: 436.2270605020153 not in (0.01, 0.12)
# turn_rate out of range: 409.20761459243306 not in (0.01, 0.12)
# turn_rate out of range: 234.2145465951794 not in (0.01, 0.12)
# turn_rate out of range: 164.88405613871768 not in (0.01, 0.12)
# turn_rate out of range: 288.75358551929924 not in (0.01, 0.12)
# turn_rate out of range: 346.6180233180507 not in (0.01, 0.12)
# turn_rate out of range: 273.89602590497145 not in (0.01, 0.12)
# turn_rate out of range: 133.0814016815686 not in (0.01, 0.12)
# turn_rate out of range: 142.1447836439204 not in (0.01, 0.12)
# turn_rate out of range: 117.06083448415671 not in (0.01, 0.12)
# turn_rate out of range: 128.2073624500024 not in (0.01, 0.12)
# turn_rate out of range: 246.37147183586507 not in (0.01, 0.12)
# turn_rate out of range: 526.2848294260016 not in (0.01, 0.12)
# turn_rate out of range: 558.4757916982616 not in (0.01, 0.12)
# turn_rate out of range: 558.4757916982616 not in (0.01, 0.12)
# turn_rate out of range: 157.0912095918207 not in (0.01, 0.12)
# turn_rate out of range: 127.90360137585655 not in (0.01, 0.12)
# turn_rate out of range: 177.07184905991258 not in (0.01, 0.12)
# turn_rate out of range: 256.1014864618133 not in (0.01, 0.12)
# turn_rate out of range: 156.51292379447773 not in (0.01, 0.12)
# turn_rate out of range: 51.5660760877102 not in (0.01, 0.12)
# turn_rate out of range: 319.44647305996483 not in (0.01, 0.12)
# turn_rate out of range: 433.5233847808046 not in (0.01, 0.12)
# turn_rate out of range: 613.3759244515545 not in (0.01, 0.12)
# turn_rate out of range: 506.619091056196 not in (0.01, 0.12)
# turn_rate out of range: 398.72980047037436 not in (0.01, 0.12)
# turn_rate out of range: 479.208500686962 not in (0.01, 0.12)
# turn_rate out of range: 392.92447473970253 not in (0.01, 0.12)
# turn_rate out of range: 416.53949984631174 not in (0.01, 0.12)
# turn_rate out of range: 346.6642694184772 not in (0.01, 0.12)
# turn_rate out of range: 437.6345347119086 not in (0.01, 0.12)
# turn_rate out of range: 441.27175295896325 not in (0.01, 0.12)
# turn_rate out of range: 425.7882530638855 not in (0.01, 0.12)
# turn_rate out of range: 407.5043488292845 not in (0.01, 0.12)
# turn_rate out of range: 298.7583616025666 not in (0.01, 0.12)
# turn_rate out of range: 569.439888327358 not in (0.01, 0.12)
# turn_rate out of range: 534.6878675582656 not in (0.01, 0.12)
# turn_rate out of range: 537.3753279166444 not in (0.01, 0.12)
# turn_rate out of range: 422.52166237869085 not in (0.01, 0.12)
# turn_rate out of range: 342.14836849999716 not in (0.01, 0.12)
# turn_rate out of range: 194.72620211466216 not in (0.01, 0.12)
# turn_rate out of range: 183.44949786583624 not in (0.01, 0.12)
# turn_rate out of range: 243.7057927757006 not in (0.01, 0.12)
# turn_rate out of range: 187.61290371715546 not in (0.01, 0.12)
# turn_rate out of range: 308.9460109925017 not in (0.01, 0.12)
# turn_rate out of range: 371.75739062706515 not in (0.01, 0.12)
# turn_rate out of range: 347.49209440085485 not in (0.01, 0.12)
# turn_rate out of range: 317.26903334315017 not in (0.01, 0.12)
# turn_rate out of range: 376.6783892115536 not in (0.01, 0.12)
# turn_rate out of range: 185.41466042233424 not in (0.01, 0.12)
# turn_rate out of range: 122.16724035328077 not in (0.01, 0.12)
# turn_rate out of range: 241.08315612063262 not in (0.01, 0.12)
# turn_rate out of range: 298.3235670475165 not in (0.01, 0.12)
# turn_rate out of range: 341.694810478021 not in (0.01, 0.12)
# turn_rate out of range: 230.15105432629767 not in (0.01, 0.12)
# turn_rate out of range: 359.855397884656 not in (0.01, 0.12)
# turn_rate out of range: 314.84104095368144 not in (0.01, 0.12)
# turn_rate out of range: 243.3523053947156 not in (0.01, 0.12)
# turn_rate out of range: 201.40148372436477 not in (0.01, 0.12)
# turn_rate out of range: 239.9064927278705 not in (0.01, 0.12)
# turn_rate out of range: 128.23116177818883 not in (0.01, 0.12)
# turn_rate out of range: 585.9610145704894 not in (0.01, 0.12)
# turn_rate out of range: 400.9066251499339 not in (0.01, 0.12)
# turn_rate out of range: 312.1366705878882 not in (0.01, 0.12)
# turn_rate out of range: 370.3005842884885 not in (0.01, 0.12)
# turn_rate out of range: 402.0935035503305 not in (0.01, 0.12)
# turn_rate out of range: 502.5246557941494 not in (0.01, 0.12)
# turn_rate out of range: 353.3535528893453 not in (0.01, 0.12)
# turn_rate out of range: 207.75276985839835 not in (0.01, 0.12)
# turn_rate out of range: 79.97318459911311 not in (0.01, 0.12)
# turn_rate out of range: 217.75151209632295 not in (0.01, 0.12)
# turn_rate out of range: 231.4236077690445 not in (0.01, 0.12)
# turn_rate out of range: 253.337889914285 not in (0.01, 0.12)
# turn_rate out of range: 299.2276442545102 not in (0.01, 0.12)
# turn_rate out of range: 365.970452677664 not in (0.01, 0.12)
# turn_rate out of range: 427.44778927482855 not in (0.01, 0.12)
# turn_rate out of range: 339.64744240837786 not in (0.01, 0.12)
# turn_rate out of range: 529.7939548997767 not in (0.01, 0.12)
# turn_rate out of range: 418.9745028883694 not in (0.01, 0.12)
# turn_rate out of range: 452.6631554004638 not in (0.01, 0.12)
# turn_rate out of range: 524.5718144001028 not in (0.01, 0.12)
# turn_rate out of range: 467.9916876127104 not in (0.01, 0.12)
# turn_rate out of range: 362.72443412243535 not in (0.01, 0.12)
# turn_rate out of range: 437.52059573853813 not in (0.01, 0.12)
# turn_rate out of range: 567.4441171741174 not in (0.01, 0.12)
# turn_rate out of range: 516.7645118914749 not in (0.01, 0.12)
# turn_rate out of range: 396.6308769913133 not in (0.01, 0.12)
# turn_rate out of range: 431.1628661929576 not in (0.01, 0.12)
# turn_rate out of range: 393.2892029980249 not in (0.01, 0.12)
# turn_rate out of range: 423.83346760113164 not in (0.01, 0.12)
# turn_rate out of range: 460.7417694846299 not in (0.01, 0.12)
# turn_rate out of range: 498.67036236129536 not in (0.01, 0.12)
# turn_rate out of range: 457.283661735207 not in (0.01, 0.12)
# turn_rate out of range: 265.83858231978263 not in (0.01, 0.12)
# turn_rate out of range: 364.0770933836358 not in (0.01, 0.12)
# turn_rate out of range: 328.72299178049036 not in (0.01, 0.12)
# turn_rate out of range: 516.9730696329581 not in (0.01, 0.12)
# turn_rate out of range: 449.35960533847344 not in (0.01, 0.12)
# turn_rate out of range: 603.4826718956053 not in (0.01, 0.12)
# turn_rate out of range: 496.31274646971866 not in (0.01, 0.12)
# turn_rate out of range: 414.7979115785983 not in (0.01, 0.12)
# turn_rate out of range: 286.19729437375133 not in (0.01, 0.12)
# turn_rate out of range: 199.2572482664292 not in (0.01, 0.12)
# turn_rate out of range: 284.7794204225683 not in (0.01, 0.12)
# turn_rate out of range: 465.526162177061 not in (0.01, 0.12)
# turn_rate out of range: 449.2792225961002 not in (0.01, 0.12)
# turn_rate out of range: 252.86883179224182 not in (0.01, 0.12)
# turn_rate out of range: 197.18481697833528 not in (0.01, 0.12)
# turn_rate out of range: 283.42882399970455 not in (0.01, 0.12)
# turn_rate out of range: 248.08350575637536 not in (0.01, 0.12)
# turn_rate out of range: 320.2710483958565 not in (0.01, 0.12)
# turn_rate out of range: 126.79232187030526 not in (0.01, 0.12)
# turn_rate out of range: 411.0999037884838 not in (0.01, 0.12)
# turn_rate out of range: 316.2181224754549 not in (0.01, 0.12)
# turn_rate out of range: 293.28556881456296 not in (0.01, 0.12)
# turn_rate out of range: 291.89036657966744 not in (0.01, 0.12)
# turn_rate out of range: 401.7764477836643 not in (0.01, 0.12)
# turn_rate out of range: 72.10665926563603 not in (0.01, 0.12)
# turn_rate out of range: 80.38473471021051 not in (0.01, 0.12)
# turn_rate out of range: 301.1452200995915 not in (0.01, 0.12)
# turn_rate out of range: 533.7683536472022 not in (0.01, 0.12)
# turn_rate out of range: 431.24715472409764 not in (0.01, 0.12)
# turn_rate out of range: 378.5936540932802 not in (0.01, 0.12)
# turn_rate out of range: 342.30453015533203 not in (0.01, 0.12)
# turn_rate out of range: 325.93876165785144 not in (0.01, 0.12)
# turn_rate out of range: 121.42760669874225 not in (0.01, 0.12)
# turn_rate out of range: 26.145965274547205 not in (0.01, 0.12)
# turn_rate out of range: 5.591555293702926 not in (0.01, 0.12)
# turn_rate out of range: 163.21121692719467 not in (0.01, 0.12)
# turn_rate out of range: 110.40688708400546 not in (0.01, 0.12)
# turn_rate out of range: 184.86020758061133 not in (0.01, 0.12)
# turn_rate out of range: 62.936299638053036 not in (0.01, 0.12)
# turn_rate out of range: 135.6054952227585 not in (0.01, 0.12)
# turn_rate out of range: 75.54040615863624 not in (0.01, 0.12)
# turn_rate out of range: 211.43444412895505 not in (0.01, 0.12)
# turn_rate out of range: 174.74556648180646 not in (0.01, 0.12)
# turn_rate out of range: 152.0885140986007 not in (0.01, 0.12)
# turn_rate out of range: 118.13752529017106 not in (0.01, 0.12)
# turn_rate out of range: 32.915935543071356 not in (0.01, 0.12)
# turn_rate out of range: 187.48478617112931 not in (0.01, 0.12)
# turn_rate out of range: 111.56575418979398 not in (0.01, 0.12)
# turn_rate out of range: 67.55540074431855 not in (0.01, 0.12)
# turn_rate out of range: 68.33725378341703 not in (0.01, 0.12)
# turn_rate out of range: 153.37479089685502 not in (0.01, 0.12)
# turn_rate out of range: 143.88875499909756 not in (0.01, 0.12)
# turn_rate out of range: 11.752126585229249 not in (0.01, 0.12)
# turn_rate out of range: 219.41500271875455 not in (0.01, 0.12)
# turn_rate out of range: 248.38586617479314 not in (0.01, 0.12)
# turn_rate out of range: 294.6508488063726 not in (0.01, 0.12)
# turn_rate out of range: 208.37051622323844 not in (0.01, 0.12)
# turn_rate out of range: 339.6724572609282 not in (0.01, 0.12)
# turn_rate out of range: 439.3414791274032 not in (0.01, 0.12)
# turn_rate out of range: 239.05741009895902 not in (0.01, 0.12)
# turn_rate out of range: 216.49510514788548 not in (0.01, 0.12)
# turn_rate out of range: 146.48834994100534 not in (0.01, 0.12)
# turn_rate out of range: 279.46785517645674 not in (0.01, 0.12)
# turn_rate out of range: 261.58477768461967 not in (0.01, 0.12)
# turn_rate out of range: 252.24860793673537 not in (0.01, 0.12)
# turn_rate out of range: 184.06816630723375 not in (0.01, 0.12)
# turn_rate out of range: 508.6526283016131 not in (0.01, 0.12)
# turn_rate out of range: 127.53930635533968 not in (0.01, 0.12)
# turn_rate out of range: 521.1593953282484 not in (0.01, 0.12)
# turn_rate out of range: 480.6940597998226 not in (0.01, 0.12)
# turn_rate out of range: 545.4169519562515 not in (0.01, 0.12)
# turn_rate out of range: 626.9147213162246 not in (0.01, 0.12)
# turn_rate out of range: 612.8450107747391 not in (0.01, 0.12)
# turn_rate out of range: 583.8578832183689 not in (0.01, 0.12)
# turn_rate out of range: 547.2999815946303 not in (0.01, 0.12)
# turn_rate out of range: 493.44423615405924 not in (0.01, 0.12)
# turn_rate out of range: 444.51052027282293 not in (0.01, 0.12)
# turn_rate out of range: 403.11059972608155 not in (0.01, 0.12)
# turn_rate out of range: 483.46558786193873 not in (0.01, 0.12)
# turn_rate out of range: 459.89057550824407 not in (0.01, 0.12)
# turn_rate out of range: 459.69213236043873 not in (0.01, 0.12)
# turn_rate out of range: 497.51024888098874 not in (0.01, 0.12)
# turn_rate out of range: 343.4277879865705 not in (0.01, 0.12)
# turn_rate out of range: 267.2308105801582 not in (0.01, 0.12)
# turn_rate out of range: 403.21089179473563 not in (0.01, 0.12)
# turn_rate out of range: 481.86174677005573 not in (0.01, 0.12)
# turn_rate out of range: 389.1527301766135 not in (0.01, 0.12)
# turn_rate out of range: 416.61898643435006 not in (0.01, 0.12)
# turn_rate out of range: 421.8839086605038 not in (0.01, 0.12)
# turn_rate out of range: 339.85719390973037 not in (0.01, 0.12)
# turn_rate out of range: 266.54002621892346 not in (0.01, 0.12)
# turn_rate out of range: 293.22991661269566 not in (0.01, 0.12)
# turn_rate out of range: 248.43824088322933 not in (0.01, 0.12)
# turn_rate out of range: 105.64594722360467 not in (0.01, 0.12)
# turn_rate out of range: 94.12672614201898 not in (0.01, 0.12)
# turn_rate out of range: 583.7884682200279 not in (0.01, 0.12)
# turn_rate out of range: 248.4509029872341 not in (0.01, 0.12)
# turn_rate out of range: 383.14357059233186 not in (0.01, 0.12)
# turn_rate out of range: 373.08820047361706 not in (0.01, 0.12)
# turn_rate out of range: 475.06913035306917 not in (0.01, 0.12)
# turn_rate out of range: 638.7709921544948 not in (0.01, 0.12)
# turn_rate out of range: 978.8161107192919 not in (0.01, 0.12)
# turn_rate out of range: 638.9677473730422 not in (0.01, 0.12)
# turn_rate out of range: 575.0264497618746 not in (0.01, 0.12)
# turn_rate out of range: 502.80485356800665 not in (0.01, 0.12)
# turn_rate out of range: 446.66770949118455 not in (0.01, 0.12)
# turn_rate out of range: 331.11273088164097 not in (0.01, 0.12)
# turn_rate out of range: 304.87386654345005 not in (0.01, 0.12)
# turn_rate out of range: 468.45467807769063 not in (0.01, 0.12)
# turn_rate out of range: 521.5141467148794 not in (0.01, 0.12)
# turn_rate out of range: 465.0957446098002 not in (0.01, 0.12)
# turn_rate out of range: 422.95889270696097 not in (0.01, 0.12)
# turn_rate out of range: 638.0792556880166 not in (0.01, 0.12)
# turn_rate out of range: 755.0340072278422 not in (0.01, 0.12)
# turn_rate out of range: 614.5114256687765 not in (0.01, 0.12)
# turn_rate out of range: 569.8942979973028 not in (0.01, 0.12)
# turn_rate out of range: 488.59916406441596 not in (0.01, 0.12)
# turn_rate out of range: 322.77420156410744 not in (0.01, 0.12)
# turn_rate out of range: 587.8426647488236 not in (0.01, 0.12)
# turn_rate out of range: 587.8426647488236 not in (0.01, 0.12)
# turn_rate out of range: 138.39214769041527 not in (0.01, 0.12)
# turn_rate out of range: 587.8426647488236 not in (0.01, 0.12)
# turn_rate out of range: 133.7924788067649 not in (0.01, 0.12)
# turn_rate out of range: 133.7924788067649 not in (0.01, 0.12)
# turn_rate out of range: 32.198996815277255 not in (0.01, 0.12)
# turn_rate out of range: 80.61820126674218 not in (0.01, 0.12)
# turn_rate out of range: 122.67332649779613 not in (0.01, 0.12)
# turn_rate out of range: 179.34794537773368 not in (0.01, 0.12)
# turn_rate out of range: 164.45984999260708 not in (0.01, 0.12)
# turn_rate out of range: 156.76369506404166 not in (0.01, 0.12)
# turn_rate out of range: 31.731674327628912 not in (0.01, 0.12)
# turn_rate out of range: 538.5278111095793 not in (0.01, 0.12)
# turn_rate out of range: 446.20248496999085 not in (0.01, 0.12)
# turn_rate out of range: 471.96081751625195 not in (0.01, 0.12)
# turn_rate out of range: 374.15393994351825 not in (0.01, 0.12)
# turn_rate out of range: 410.48737652452087 not in (0.01, 0.12)
# turn_rate out of range: 457.72797680641315 not in (0.01, 0.12)
# turn_rate out of range: 465.76980930099717 not in (0.01, 0.12)
# turn_rate out of range: 470.92428204917627 not in (0.01, 0.12)
# turn_rate out of range: 559.5976830745058 not in (0.01, 0.12)
# turn_rate out of range: 464.86232430054645 not in (0.01, 0.12)
# turn_rate out of range: 466.2359272329204 not in (0.01, 0.12)
# turn_rate out of range: 506.9444986980954 not in (0.01, 0.12)
# turn_rate out of range: 432.952254088498 not in (0.01, 0.12)
# turn_rate out of range: 501.470956319016 not in (0.01, 0.12)
# turn_rate out of range: 518.8476701747693 not in (0.01, 0.12)
# turn_rate out of range: 600.607373155775 not in (0.01, 0.12)
# turn_rate out of range: 640.3150589956294 not in (0.01, 0.12)
# turn_rate out of range: 542.3165536484814 not in (0.01, 0.12)
# turn_rate out of range: 484.9514820677466 not in (0.01, 0.12)
# turn_rate out of range: 475.494698730306 not in (0.01, 0.12)
# turn_rate out of range: 454.794934237079 not in (0.01, 0.12)
# turn_rate out of range: 504.7745263271634 not in (0.01, 0.12)
# turn_rate out of range: 518.6031643882731 not in (0.01, 0.12)
# turn_rate out of range: 572.0190312497335 not in (0.01, 0.12)
# turn_rate out of range: 550.5652910654496 not in (0.01, 0.12)
# turn_rate out of range: 438.78635680973 not in (0.01, 0.12)
# turn_rate out of range: 482.4527250215725 not in (0.01, 0.12)
# turn_rate out of range: 527.4756461852277 not in (0.01, 0.12)
# turn_rate out of range: 463.80560163421825 not in (0.01, 0.12)
# turn_rate out of range: 447.0965835736471 not in (0.01, 0.12)
# turn_rate out of range: 494.5615418053061 not in (0.01, 0.12)
# turn_rate out of range: 507.96689323474027 not in (0.01, 0.12)
# turn_rate out of range: 562.9210541508228 not in (0.01, 0.12)
# turn_rate out of range: 357.30741412421344 not in (0.01, 0.12)
# turn_rate out of range: 456.47379897554515 not in (0.01, 0.12)
# turn_rate out of range: 514.632483625999 not in (0.01, 0.12)
# turn_rate out of range: 466.5023305323131 not in (0.01, 0.12)
# turn_rate out of range: 381.23107786883975 not in (0.01, 0.12)
# turn_rate out of range: 474.3785022048319 not in (0.01, 0.12)
# turn_rate out of range: 560.3811738047166 not in (0.01, 0.12)
# turn_rate out of range: 431.73164621633913 not in (0.01, 0.12)
# turn_rate out of range: 527.4234627587308 not in (0.01, 0.12)
# turn_rate out of range: 503.68517507518493 not in (0.01, 0.12)
# turn_rate out of range: 426.08889131228494 not in (0.01, 0.12)
# turn_rate out of range: 260.3271218896435 not in (0.01, 0.12)
# turn_rate out of range: 568.4902104280765 not in (0.01, 0.12)
# turn_rate out of range: 557.4154196466353 not in (0.01, 0.12)
# turn_rate out of range: 499.9949351726879 not in (0.01, 0.12)
# turn_rate out of range: 464.9313407639352 not in (0.01, 0.12)
# turn_rate out of range: 524.4857702916424 not in (0.01, 0.12)
# turn_rate out of range: 538.5081365156436 not in (0.01, 0.12)
# turn_rate out of range: 494.9287780922672 not in (0.01, 0.12)
# turn_rate out of range: 447.8606788950095 not in (0.01, 0.12)
# turn_rate out of range: 434.79891490648714 not in (0.01, 0.12)
# turn_rate out of range: 415.6933472440684 not in (0.01, 0.12)
# turn_rate out of range: 488.33707526611306 not in (0.01, 0.12)
# turn_rate out of range: 456.57497823429577 not in (0.01, 0.12)
# turn_rate out of range: 431.55229280013765 not in (0.01, 0.12)
# turn_rate out of range: 419.9115369501536 not in (0.01, 0.12)
# turn_rate out of range: 459.66810613418136 not in (0.01, 0.12)
# turn_rate out of range: 471.7365644951827 not in (0.01, 0.12)
# turn_rate out of range: 478.8575187684408 not in (0.01, 0.12)
# turn_rate out of range: 314.60648197682184 not in (0.01, 0.12)
# turn_rate out of range: 839.1917028604188 not in (0.01, 0.12)
# turn_rate out of range: 839.1917028604188 not in (0.01, 0.12)
# turn_rate out of range: 706.1474263050495 not in (0.01, 0.12)
# turn_rate out of range: 539.0235090689091 not in (0.01, 0.12)
# turn_rate out of range: 481.7767471569171 not in (0.01, 0.12)
# turn_rate out of range: 396.3088291963303 not in (0.01, 0.12)
# turn_rate out of range: 383.6745414975719 not in (0.01, 0.12)
# turn_rate out of range: 358.5608116980207 not in (0.01, 0.12)
# turn_rate out of range: 384.3680139857917 not in (0.01, 0.12)
# turn_rate out of range: 382.2706152342128 not in (0.01, 0.12)
# turn_rate out of range: 442.5722076759841 not in (0.01, 0.12)
# turn_rate out of range: 543.0804983877453 not in (0.01, 0.12)
# turn_rate out of range: 535.3964343491807 not in (0.01, 0.12)
# turn_rate out of range: 604.3227129989484 not in (0.01, 0.12)
# turn_rate out of range: 465.38920330833963 not in (0.01, 0.12)
# turn_rate out of range: 407.95777226258355 not in (0.01, 0.12)
# turn_rate out of range: 427.24738539440045 not in (0.01, 0.12)
# turn_rate out of range: 530.5674635763471 not in (0.01, 0.12)
# turn_rate out of range: 623.6509507279964 not in (0.01, 0.12)
# turn_rate out of range: 625.7510864023213 not in (0.01, 0.12)
# turn_rate out of range: 546.9788925728723 not in (0.01, 0.12)
# turn_rate out of range: 482.98946099889764 not in (0.01, 0.12)
# turn_rate out of range: 544.5767411437153 not in (0.01, 0.12)
# turn_rate out of range: 462.89507932791685 not in (0.01, 0.12)
# turn_rate out of range: 388.2266697915586 not in (0.01, 0.12)
# turn_rate out of range: 487.6693651865593 not in (0.01, 0.12)
# turn_rate out of range: 320.0919666353969 not in (0.01, 0.12)
# turn_rate out of range: 578.2841836615602 not in (0.01, 0.12)
# ...
# turn_rate out of range: 565.4064014292062 not in (0.01, 0.12)
# turn_rate out of range: 420.7869941811118 not in (0.01, 0.12)
# turn_rate out of range: 229.06809014241065 not in (0.01, 0.12)
# turn_rate out of range: 75.26573499614496 not in (0.01, 0.12)
# turn_rate out of range: 129.06315390481174 not in (0.01, 0.12)
# turn_rate out of range: 109.69192320589084 not in (0.01, 0.12)
# turn_rate out of range: 87.46594011903647 not in (0.01, 0.12)
# turn_rate out of range: 133.3126195503589 not in (0.01, 0.12)
# turn_rate out of range: 440.26859503984923 not in (0.01, 0.12)
# turn_rate out of range: 445.23848452170586 not in (0.01, 0.12)
# turn_rate out of range: 436.4803562643291 not in (0.01, 0.12)
# turn_rate out of range: 506.5581333201409 not in (0.01, 0.12)
# turn_rate out of range: 418.183099708756 not in (0.01, 0.12)
# turn_rate out of range: 396.5864733339698 not in (0.01, 0.12)
# turn_rate out of range: 449.38891287315175 not in (0.01, 0.12)
# turn_rate out of range: 500.1266804428209 not in (0.01, 0.12)
# turn_rate out of range: 484.27612568862213 not in (0.01, 0.12)
# turn_rate out of range: 611.5971697871942 not in (0.01, 0.12)
# turn_rate out of range: 556.7599964521986 not in (0.01, 0.12)
# turn_rate out of range: 503.2634294687074 not in (0.01, 0.12)
# turn_rate out of range: 516.9236144465805 not in (0.01, 0.12)
# turn_rate out of range: 623.7346049008779 not in (0.01, 0.12)
# turn_rate out of range: 667.8302790030599 not in (0.01, 0.12)
# turn_rate out of range: 584.2798548976267 not in (0.01, 0.12)
# turn_rate out of range: 437.1331466422459 not in (0.01, 0.12)
# turn_rate out of range: 232.68189046047314 not in (0.01, 0.12)
# turn_rate out of range: 194.9399202716626 not in (0.01, 0.12)
# turn_rate out of range: 177.7197887713734 not in (0.01, 0.12)
# turn_rate out of range: 342.21669043261466 not in (0.01, 0.12)
# turn_rate out of range: 378.8876004319415 not in (0.01, 0.12)
# turn_rate out of range: 274.0438329356063 not in (0.01, 0.12)
# turn_rate out of range: 259.4186566737451 not in (0.01, 0.12)
# turn_rate out of range: 135.75473529740583 not in (0.01, 0.12)
# turn_rate out of range: 64.32919426898493 not in (0.01, 0.12)
# turn_rate out of range: 106.92823319531882 not in (0.01, 0.12)
# turn_rate out of range: 133.45642764337526 not in (0.01, 0.12)
# turn_rate out of range: 323.282346560022 not in (0.01, 0.12)
# turn_rate out of range: 195.13605376170122 not in (0.01, 0.12)
# turn_rate out of range: 347.70969123250165 not in (0.01, 0.12)
# turn_rate out of range: 315.392058725617 not in (0.01, 0.12)
# turn_rate out of range: 437.2269345815842 not in (0.01, 0.12)
# turn_rate out of range: 476.04529530085875 not in (0.01, 0.12)
# turn_rate out of range: 461.90021512343867 not in (0.01, 0.12)
# turn_rate out of range: 410.93457362601487 not in (0.01, 0.12)
# turn_rate out of range: 237.89814819969698 not in (0.01, 0.12)
# turn_rate out of range: 358.06872619681525 not in (0.01, 0.12)
# turn_rate out of range: 562.640148383406 not in (0.01, 0.12)
# turn_rate out of range: 570.6755473754249 not in (0.01, 0.12)
# turn_rate out of range: 428.96574997766294 not in (0.01, 0.12)
# turn_rate out of range: 375.68477929494696 not in (0.01, 0.12)
# turn_rate out of range: 532.4938836108533 not in (0.01, 0.12)
# turn_rate out of range: 542.4833103594651 not in (0.01, 0.12)
# turn_rate out of range: 631.9902953964753 not in (0.01, 0.12)
# turn_rate out of range: 95.30523898422702 not in (0.01, 0.12)
# turn_rate out of range: 5.694761049876244 not in (0.01, 0.12)
# turn_rate out of range: 95.30523898422702 not in (0.01, 0.12)
# turn_rate out of range: 5.694761049876244 not in (0.01, 0.12)
# turn_rate out of range: 5.694761049876244 not in (0.01, 0.12)
# turn_rate out of range: 568.4487887248177 not in (0.01, 0.12)
# turn_rate out of range: 568.4487887248177 not in (0.01, 0.12)
# turn_rate out of range: 1169.3194277360708 not in (0.01, 0.12)
# turn_rate out of range: 568.4487887248177 not in (0.01, 0.12)
# turn_rate out of range: 847.1574906136482 not in (0.01, 0.12)
# turn_rate out of range: 702.4535502989883 not in (0.01, 0.12)
# turn_rate out of range: 466.55433180794387 not in (0.01, 0.12)
# turn_rate out of range: 484.3094050979239 not in (0.01, 0.12)
# turn_rate out of range: 195.4422347994945 not in (0.01, 0.12)
# turn_rate out of range: 424.74869928775706 not in (0.01, 0.12)
# turn_rate out of range: 195.4422347994945 not in (0.01, 0.12)
# turn_rate out of range: 516.5978648225337 not in (0.01, 0.12)
# turn_rate out of range: 195.4422347994945 not in (0.01, 0.12)
# turn_rate out of range: 511.8136124923589 not in (0.01, 0.12)
# turn_rate out of range: 434.8988439566357 not in (0.01, 0.12)
# turn_rate out of range: 354.9561873686223 not in (0.01, 0.12)
# turn_rate out of range: 607.1792718383585 not in (0.01, 0.12)
# turn_rate out of range: 663.3282891105149 not in (0.01, 0.12)
# turn_rate out of range: 576.5240722356772 not in (0.01, 0.12)
# turn_rate out of range: 442.1648801279578 not in (0.01, 0.12)
# turn_rate out of range: 787.1505183857116 not in (0.01, 0.12)
# turn_rate out of range: 567.266142722409 not in (0.01, 0.12)
# turn_rate out of range: 524.1995014639797 not in (0.01, 0.12)
# turn_rate out of range: 411.4233061208532 not in (0.01, 0.12)
# turn_rate out of range: 41.9369680643293 not in (0.01, 0.12)
# turn_rate out of range: 794.6682938423121 not in (0.01, 0.12)
# turn_rate out of range: 442.7908925395274 not in (0.01, 0.12)
# turn_rate out of range: 375.1778446130855 not in (0.01, 0.12)
# turn_rate out of range: 394.818168209065 not in (0.01, 0.12)
# turn_rate out of range: 457.98785205042884 not in (0.01, 0.12)
# turn_rate out of range: 516.6728572779522 not in (0.01, 0.12)
# turn_rate out of range: 442.62591073048696 not in (0.01, 0.12)
# turn_rate out of range: 373.8609530936503 not in (0.01, 0.12)
# turn_rate out of range: 274.5995234095602 not in (0.01, 0.12)
# turn_rate out of range: 255.44127441031236 not in (0.01, 0.12)
# turn_rate out of range: 379.0099564880286 not in (0.01, 0.12)
# turn_rate out of range: 372.70741516073383 not in (0.01, 0.12)
# turn_rate out of range: 379.0099564880286 not in (0.01, 0.12)
# turn_rate out of range: 427.77742673716773 not in (0.01, 0.12)
# turn_rate out of range: 427.77742673716773 not in (0.01, 0.12)
# turn_rate out of range: 410.24758788603754 not in (0.01, 0.12)
# turn_rate out of range: 471.4919082968804 not in (0.01, 0.12)
# turn_rate out of range: 546.8469752105548 not in (0.01, 0.12)
# turn_rate out of range: 600.7767680905413 not in (0.01, 0.12)
# turn_rate out of range: 513.1911030343629 not in (0.01, 0.12)
# turn_rate out of range: 438.54879018639485 not in (0.01, 0.12)
# turn_rate out of range: 514.6661797207191 not in (0.01, 0.12)
# turn_rate out of range: 500.3142623683601 not in (0.01, 0.12)
# turn_rate out of range: 390.76118313562847 not in (0.01, 0.12)
# turn_rate out of range: 429.0754192530976 not in (0.01, 0.12)
# turn_rate out of range: 472.8363474658245 not in (0.01, 0.12)
# turn_rate out of range: 480.1142113678555 not in (0.01, 0.12)
# turn_rate out of range: 467.2778859798517 not in (0.01, 0.12)
# turn_rate out of range: 396.0203845884462 not in (0.01, 0.12)
# turn_rate out of range: 625.3884852361293 not in (0.01, 0.12)
# turn_rate out of range: 415.38952513628027 not in (0.01, 0.12)
# turn_rate out of range: 380.9517126665576 not in (0.01, 0.12)
# turn_rate out of range: 583.6270706475518 not in (0.01, 0.12)
# turn_rate out of range: 457.2974740232231 not in (0.01, 0.12)
# turn_rate out of range: 517.053133999636 not in (0.01, 0.12)
# turn_rate out of range: 105.61361218356126 not in (0.01, 0.12)
# turn_rate out of range: 517.053133999636 not in (0.01, 0.12)
# turn_rate out of range: 326.47082822092443 not in (0.01, 0.12)
# turn_rate out of range: 381.8809801088366 not in (0.01, 0.12)
# turn_rate out of range: 395.2408363934119 not in (0.01, 0.12)
# turn_rate out of range: 393.94147536839336 not in (0.01, 0.12)
# turn_rate out of range: 388.293162923998 not in (0.01, 0.12)
# turn_rate out of range: 369.6407369141938 not in (0.01, 0.12)
# turn_rate out of range: 510.59237832744526 not in (0.01, 0.12)
# turn_rate out of range: 502.0612375064167 not in (0.01, 0.12)
# turn_rate out of range: 472.7439081267233 not in (0.01, 0.12)
# turn_rate out of range: 473.01468479982816 not in (0.01, 0.12)
# turn_rate out of range: 436.11971453857615 not in (0.01, 0.12)
# turn_rate out of range: 196.15304027511542 not in (0.01, 0.12)
# turn_rate out of range: 607.1267253554746 not in (0.01, 0.12)
# turn_rate out of range: 582.1895270597967 not in (0.01, 0.12)
# turn_rate out of range: 576.3925024057476 not in (0.01, 0.12)
# turn_rate out of range: 598.6751143584545 not in (0.01, 0.12)
# turn_rate out of range: 516.4408026480928 not in (0.01, 0.12)
# turn_rate out of range: 495.64795361333546 not in (0.01, 0.12)
# turn_rate out of range: 553.1415664446941 not in (0.01, 0.12)
# turn_rate out of range: 449.41658122680485 not in (0.01, 0.12)
# turn_rate out of range: 472.9205262513668 not in (0.01, 0.12)
# turn_rate out of range: 400.25842571267015 not in (0.01, 0.12)
# turn_rate out of range: 401.3708171105271 not in (0.01, 0.12)
# turn_rate out of range: 443.0510690995409 not in (0.01, 0.12)
# turn_rate out of range: 453.8306448964006 not in (0.01, 0.12)
# turn_rate out of range: 509.84202441866285 not in (0.01, 0.12)
# turn_rate out of range: 535.0830066482548 not in (0.01, 0.12)
# turn_rate out of range: 645.2343627842599 not in (0.01, 0.12)
# turn_rate out of range: 358.25935324933357 not in (0.01, 0.12)
# turn_rate out of range: 397.2203093396049 not in (0.01, 0.12)
# turn_rate out of range: 427.7552375689834 not in (0.01, 0.12)
# turn_rate out of range: 477.4271972024724 not in (0.01, 0.12)
# turn_rate out of range: 513.3423220503138 not in (0.01, 0.12)
# turn_rate out of range: 562.2756985838839 not in (0.01, 0.12)
# turn_rate out of range: 579.3362188824871 not in (0.01, 0.12)
# turn_rate out of range: 584.5657933607142 not in (0.01, 0.12)
# turn_rate out of range: 524.1114686464441 not in (0.01, 0.12)
# turn_rate out of range: 555.8208313095544 not in (0.01, 0.12)
# turn_rate out of range: 438.7172734022649 not in (0.01, 0.12)
# turn_rate out of range: 524.8114822387631 not in (0.01, 0.12)
# turn_rate out of range: 275.15440694438945 not in (0.01, 0.12)
# turn_rate out of range: 665.8409405972977 not in (0.01, 0.12)
# turn_rate out of range: 623.295635274542 not in (0.01, 0.12)
# turn_rate out of range: 599.1556772416419 not in (0.01, 0.12)
# turn_rate out of range: 548.965227274662 not in (0.01, 0.12)
# turn_rate out of range: 452.2575228525825 not in (0.01, 0.12)
# turn_rate out of range: 373.893246875228 not in (0.01, 0.12)
# turn_rate out of range: 486.8380493536648 not in (0.01, 0.12)
# turn_rate out of range: 495.0970415750321 not in (0.01, 0.12)
# turn_rate out of range: 408.21287279229034 not in (0.01, 0.12)
# turn_rate out of range: 380.5148607144557 not in (0.01, 0.12)
# turn_rate out of range: 483.1124569407407 not in (0.01, 0.12)
# turn_rate out of range: 507.92632962662236 not in (0.01, 0.12)
# turn_rate out of range: 370.28753092648003 not in (0.01, 0.12)
# turn_rate out of range: 238.19670285739335 not in (0.01, 0.12)
# turn_rate out of range: 421.67309393001625 not in (0.01, 0.12)
# turn_rate out of range: 380.40770365856963 not in (0.01, 0.12)
# turn_rate out of range: 487.156244783345 not in (0.01, 0.12)
# turn_rate out of range: 453.91137297027024 not in (0.01, 0.12)
# turn_rate out of range: 478.64035943188134 not in (0.01, 0.12)
# turn_rate out of range: 502.2016746434007 not in (0.01, 0.12)
# turn_rate out of range: 258.0593896587891 not in (0.01, 0.12)
# turn_rate out of range: 314.52503239613293 not in (0.01, 0.12)
# turn_rate out of range: 381.2349735642781 not in (0.01, 0.12)
# turn_rate out of range: 426.16559670345725 not in (0.01, 0.12)
# turn_rate out of range: 478.1201196293414 not in (0.01, 0.12)
# turn_rate out of range: 562.610876202016 not in (0.01, 0.12)
# turn_rate out of range: 598.1045204661374 not in (0.01, 0.12)
# turn_rate out of range: 438.0884745815786 not in (0.01, 0.12)
# turn_rate out of range: 435.82274787514257 not in (0.01, 0.12)
# turn_rate out of range: 385.12138301819186 not in (0.01, 0.12)
# turn_rate out of range: 168.53835679124566 not in (0.01, 0.12)
# turn_rate out of range: 317.3892009995705 not in (0.01, 0.12)
# turn_rate out of range: 347.50632990116924 not in (0.01, 0.12)
# turn_rate out of range: 405.96041977725537 not in (0.01, 0.12)
# turn_rate out of range: 348.54456369182776 not in (0.01, 0.12)
# turn_rate out of range: 344.98121478727955 not in (0.01, 0.12)
# turn_rate out of range: 398.2291067391475 not in (0.01, 0.12)
# turn_rate out of range: 416.14618539160875 not in (0.01, 0.12)
# turn_rate out of range: 423.2513753795873 not in (0.01, 0.12)
# turn_rate out of range: 410.1522793834959 not in (0.01, 0.12)
# turn_rate out of range: 531.182236700029 not in (0.01, 0.12)
# turn_rate out of range: 572.114663334293 not in (0.01, 0.12)
# turn_rate out of range: 354.52868695552297 not in (0.01, 0.12)
# turn_rate out of range: 254.42277710095883 not in (0.01, 0.12)
# turn_rate out of range: 372.9141415811261 not in (0.01, 0.12)
# turn_rate out of range: 205.19452013083935 not in (0.01, 0.12)
# turn_rate out of range: 420.9139231980895 not in (0.01, 0.12)
# turn_rate out of range: 307.90566934585325 not in (0.01, 0.12)
# turn_rate out of range: 382.14787370080074 not in (0.01, 0.12)
# turn_rate out of range: 325.7282089976501 not in (0.01, 0.12)
# turn_rate out of range: 325.7282089976501 not in (0.01, 0.12)
# turn_rate out of range: 585.8803438835163 not in (0.01, 0.12)
# turn_rate out of range: 417.27661071272735 not in (0.01, 0.12)
# turn_rate out of range: 393.0052018012804 not in (0.01, 0.12)
# turn_rate out of range: 361.4407330264101 not in (0.01, 0.12)
# turn_rate out of range: 408.43975986146995 not in (0.01, 0.12)
# turn_rate out of range: 501.20010988416107 not in (0.01, 0.12)
# turn_rate out of range: 522.0557306400958 not in (0.01, 0.12)
# turn_rate out of range: 532.688892862729 not in (0.01, 0.12)
# turn_rate out of range: 491.6858762308435 not in (0.01, 0.12)
# turn_rate out of range: 519.0340902862641 not in (0.01, 0.12)
# turn_rate out of range: 562.296858951978 not in (0.01, 0.12)
# turn_rate out of range: 498.1553927781618 not in (0.01, 0.12)
# turn_rate out of range: 423.1883881380388 not in (0.01, 0.12)
# turn_rate out of range: 394.70639703262367 not in (0.01, 0.12)
# turn_rate out of range: 397.67995252249625 not in (0.01, 0.12)
# turn_rate out of range: 457.49682887943266 not in (0.01, 0.12)
# turn_rate out of range: 430.1889477913246 not in (0.01, 0.12)
# turn_rate out of range: 542.5735103810905 not in (0.01, 0.12)
# turn_rate out of range: 501.38128275317905 not in (0.01, 0.12)
# turn_rate out of range: 572.0282534958633 not in (0.01, 0.12)
# turn_rate out of range: 435.22001720781407 not in (0.01, 0.12)
# turn_rate out of range: 383.82488060651565 not in (0.01, 0.12)
# turn_rate out of range: 392.77161765642785 not in (0.01, 0.12)
# turn_rate out of range: 409.1949355463151 not in (0.01, 0.12)
# turn_rate out of range: 457.77669841623094 not in (0.01, 0.12)
# turn_rate out of range: 428.504596907121 not in (0.01, 0.12)
# turn_rate out of range: 438.2204617269863 not in (0.01, 0.12)
# turn_rate out of range: 391.648061120767 not in (0.01, 0.12)
# turn_rate out of range: 519.1204161350664 not in (0.01, 0.12)
# turn_rate out of range: 421.83711557849483 not in (0.01, 0.12)
# turn_rate out of range: 483.21782806022657 not in (0.01, 0.12)
# turn_rate out of range: 457.56983611619125 not in (0.01, 0.12)
# turn_rate out of range: 544.9651667973565 not in (0.01, 0.12)
# turn_rate out of range: 496.77768064519137 not in (0.01, 0.12)
# turn_rate out of range: 381.7009356043184 not in (0.01, 0.12)
# turn_rate out of range: 537.4532793289491 not in (0.01, 0.12)
# turn_rate out of range: 496.39885065681693 not in (0.01, 0.12)
# turn_rate out of range: 424.6156358084562 not in (0.01, 0.12)
# turn_rate out of range: 509.5778217424273 not in (0.01, 0.12)
# Empty DataFrame
# Columns: [avg_height, turn_rate, bearing, trajectory_curvature, angular_acceleration, angular_velocity, distance_traveled, displacement, jerk, vertical_acceleration, up_down_direction, angle_to_horizon, average_speed, average_velocity_magnitude, average_velocity_direction, new_cluster_label, matches_white_storks]
# Index: []

# %%
#clusters_with_features_df[clusters_with_features_df['matches_common_kestrel']]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Select a subset of features to plot (e.g., first 12)
selected_features = list(white_stork_ranges.items())[:12]

# Plot box plots for each feature against the range
plt.figure(figsize=(14, 18))

# Keep the grid size at 7 rows by 2 columns
for i, (feature, (min_val, max_val)) in enumerate(selected_features):
    plt.subplot(7, 2, i+1)  # Adjust the layout accordingly
    sns.boxplot(data=clusters_with_features_df, y=feature,color='coral')
    plt.axhline(y=min_val, color='red', linestyle='--', label='Min Range')
    plt.axhline(y=max_val, color='green', linestyle='--', label='Max Range')
    plt.title(f'{feature} Distribution')
    plt.legend()

plt.tight_layout()
plt.show()

# %%
# Initialize the plot
plt.figure(figsize=(20, 30))

# Plot box plots and violin plots for each feature
for i, (feature, (min_val, max_val)) in enumerate(white_stork_ranges.items()):
    plt.subplot(8, 2, i+1)
    
    # Box plot
    sns.boxplot(data=clusters_with_features_df, y=feature, color='red')
    
    # Violin plot (overlayed for better visualization)
    sns.violinplot(data=clusters_with_features_df, y=feature, color='lightcoral', alpha=0.3)
    
    # Add lines for min and max range
    plt.axhline(y=min_val, color='red', linestyle='--', label='Min Range')
    plt.axhline(y=max_val, color='green', linestyle='--', label='Max Range')
    
    # Title and labels
    plt.title(f'{feature} Distribution for white stork')
    plt.legend()

# Adjust layout
plt.tight_layout()

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
file_path = 'clusters3_with_kinematic_features.csv'  # Adjust the file path as needed
df = pd.read_csv(file_path)

# Ensure that the timestamp is in datetime format
df['timestamp'] = pd.to_datetime(df['first_timestamp'], format='%Y-%m-%d %H:%M:%S')

# Define the kinematic parameters you want to visualize
kinematic_parameters = [
    'avg_height', 'turn_rate', 'bearing', 'trajectory_curvature',
    'angular_acceleration', 'angular_velocity', 'distance_traveled',
    'displacement', 'jerk', 'vertical_acceleration', 'up_down_direction',
    'angle_to_horizon', 'average_speed', 'average_velocity_magnitude',
    'average_velocity_direction'
]

# Create subplots with a specific layout for compactness
num_params = len(kinematic_parameters)
cols = 3  # Number of columns in the subplot grid
rows = (num_params + cols - 1) // cols  # Number of rows needed

plt.figure(figsize=(18, 15))
sns.set_palette("Set2")

for i, param in enumerate(kinematic_parameters):
    plt.subplot(rows, cols, i + 1)
    sns.lineplot(x=df['timestamp'], y=df[param], color='red',label=param, marker="o")
    
    # Adding labels and title for each parameter
    plt.xlabel('Time')
    plt.ylabel(param)
    plt.title(f'{param}')
    plt.grid(True)

# Adjust layout to avoid overlapping
plt.tight_layout()

# Show the combined plot
plt.show()

# %% [markdown]
# # Poisson Regression Model
#
# Estimate objects count in clusters using PR model

# %%
import pandas as pd
import statsmodels.api as sm

clusters_with_features_df = pd.read_csv('clusters3_with_kinematic_features.csv')

# Assuming clusters_with_features_df contains your data
# The number of points in each cluster is the response variable
clusters_with_features_df['number_of_points'] = clusters_with_features_df['points'].apply(len)

# Define the response variable (number of points)
y = clusters_with_features_df['number_of_points']

# Define the explanatory variables (e.g., average speed, distance traveled)
# You can select the features you want to include in the model
X = clusters_with_features_df[['average_speed', 'distance_traveled', 'avg_height']]

# Add a constant term for the intercept
X = sm.add_constant(X)

# Fit the Poisson regression model
poisson_model = sm.GLM(y, X, family=sm.families.Poisson()).fit()

# Print the summary of the model
print(poisson_model.summary())
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:       number_of_points   No. Observations:                  537
# Model:                            GLM   Df Residuals:                      533
# Model Family:                 Poisson   Df Model:                            3
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -2545.8
# Date:                Fri, 23 Aug 2024   Deviance:                       747.04
# Time:                        17:14:43   Pearson chi2:                     725.
# No. Iterations:                     4   Pseudo R-squ. (CS):             0.5275
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                 6.2663      0.006   1087.330      0.000       6.255       6.278
# average_speed        -0.0045      0.000    -19.394      0.000      -0.005      -0.004
# distance_traveled     0.0014   7.18e-05     18.990      0.000       0.001       0.002
# avg_height         1.221e-06   1.07e-05      0.114      0.909   -1.97e-05    2.21e-05
# =====================================================================================

# %%
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt

# Assuming clusters_with_features_df contains your data
# The number of points in each cluster is the response variable
clusters_with_features_df['number_of_points'] = clusters_with_features_df['points'].apply(len)

# Define the response variable (number of points)
y = clusters_with_features_df['number_of_points']

# Define the explanatory variables (e.g., average speed, distance traveled)
# Select features to include in the model
X = clusters_with_features_df[['average_speed', 'distance_traveled', 'avg_height']]

# Add a constant term for the intercept
X = sm.add_constant(X)

# Fit the Poisson regression model
poisson_model = sm.GLM(y, X, family=sm.families.Poisson()).fit()

# Predict the lambda (expected number of points) for each cluster
clusters_with_features_df['predicted_lambda'] = poisson_model.predict(X)

# Plot the predicted lambda and actual number of points for each cluster
plt.figure(figsize=(10, 6))

plt.plot(clusters_with_features_df.index, clusters_with_features_df['predicted_lambda'], marker='o', linestyle='-', color='b', label='Predicted Lambda')
plt.plot(clusters_with_features_df.index, clusters_with_features_df['number_of_points'], marker='s', linestyle='-', color='r', label='Actual Number of Points')

plt.title('Predicted Lambda and Actual Number of Points for Each Cluster')
plt.xlabel('Cluster Index')
plt.ylabel('Count')
plt.legend()
plt.grid(True)
plt.show()

# %%
import pandas as pd
import numpy as np
from scipy.stats import poisson

# Load the dataset
file_path = 'white_storks_sample.csv'  # Adjust the file path as needed
df = pd.read_csv(file_path)

# Convert epoch time in milliseconds to datetime
df['timestamp'] = pd.to_datetime(df['epoch']*1000, unit='ms')

# Define the sliding window in seconds (e.g., 10 minutes)
window_size = 60 * 60  # 10 minutes in seconds

# Define the step size for moving the window
step_size = 20 * 60  # 2 minutes in seconds

# Initialize lists to store window start times and event counts
window_start_times = []
event_counts = []

# Iterate through the data in sliding windows
start_time = df['timestamp'].min()
end_time = df['timestamp'].max()

while start_time <= end_time:
    window_end_time = start_time + pd.Timedelta(seconds=window_size)
    
    # Count the number of events (points) in the current window
    count_in_window = df[(df['timestamp'] >= start_time) & (df['timestamp'] < window_end_time)].shape[0]
    
    # Store the window start time and event count
    window_start_times.append(start_time)
    event_counts.append(count_in_window)
    
    # Move to the next window
    start_time = start_time + pd.Timedelta(seconds=step_size)

# Convert the lists to a DataFrame
window_df = pd.DataFrame({'window_start_time': window_start_times, 'event_count': event_counts})

# Calculate the mean event count (λ) across all windows
lambda_estimated = np.mean(event_counts)

# Validate Poisson distribution using MLE for λ
window_df['lambda_mle'] = lambda_estimated

# Calculate the predicted number of events using the Poisson distribution
window_df['predicted_count'] = poisson.pmf(window_df['event_count'], window_df['lambda_mle'])

# Identify potential anomalies where the actual count deviates significantly from the predicted count
window_df['anomaly'] = window_df.apply(lambda row: np.abs(row['event_count'] - row['lambda_mle']) > 2*np.sqrt(row['lambda_mle']), axis=1)

# Print the windows identified as anomalies
anomalies = window_df[window_df['anomaly']]
print(anomalies)

# Plot the actual event counts and the estimated λ
import matplotlib.pyplot as plt

plt.figure(figsize=(14, 7))
plt.plot(window_df['window_start_time'], window_df['event_count'], label='Actual Event Count', marker='o',color='pink')
plt.plot(window_df['window_start_time'], window_df['lambda_mle'], label='Estimated λ', linestyle='--', color='r')
plt.title('Poisson Model: Actual Event Counts vs. Estimated λ')
plt.xlabel('Window Start Time')
plt.ylabel('Event Count / λ')
plt.legend()
plt.grid(True)
plt.show()
# Out:
#        window_start_time  event_count  lambda_mle  predicted_count  anomaly
# 51   2012-02-14 19:00:44            0    8.131308         0.000294     True
# 52   2012-02-14 19:20:44            0    8.131308         0.000294     True
# 53   2012-02-14 19:40:44            0    8.131308         0.000294     True
# 54   2012-02-14 20:00:44            0    8.131308         0.000294     True
# 55   2012-02-14 20:20:44            0    8.131308         0.000294     True
# ...                  ...          ...         ...              ...      ...
# 1793 2012-03-09 23:40:44            0    8.131308         0.000294     True
# 1794 2012-03-10 00:00:44            0    8.131308         0.000294     True
# 1795 2012-03-10 00:20:44            0    8.131308         0.000294     True
# 1796 2012-03-10 00:40:44            0    8.131308         0.000294     True
# 1797 2012-03-10 01:00:44            0    8.131308         0.000294     True
#
# [480 rows x 5 columns]

# %% [markdown]
# The analysis identified anomalies in time intervals where the actual event count significantly deviated from the expected number based on the Poisson distribution. In this context, an anomaly was defined as a time window where the event count was more than two standard deviations away from the mean count (λ). The plot visually highlights these anomalies as red 'x' marks.
#
# A total of 3,596 time intervals were flagged as anomalies, indicating periods where the bird movements deviated from what the model expected. This suggests that during these periods, either more or fewer birds were detected than anticipated, which could be due to various factors such as unusual bird behavior, environmental changes, or errors in data collection.
#
# The time intervals with detected anomalies can be further investigated to understand the underlying causes and assess whether these deviations indicate significant events or patterns

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load the dataset
file_path = 'white_storks_sample.csv'  # Adjust the file path as needed
df = pd.read_csv(file_path)

# Convert timestamp column to datetime and sort the dataframe
df['timestamp'] = pd.to_datetime(df['timestamp'], errors='coerce')
df_sorted = df.sort_values(by='timestamp').reset_index(drop=True)

# Define the sliding window size and step size in seconds
window_size = 60 * 60  # 60 minutes
step_size = 20 * 60  # 20 minutes

# Function to calculate lambda (average rate of events)
def calculate_lambda(event_counts):
    return np.mean(event_counts)

# Initialize lists to store results
window_starts = []
actual_counts = []
expected_counts = []
anomalies = []

# Iterate through the data in sliding windows
start_time = df_sorted['timestamp'].min()
end_time = df_sorted['timestamp'].max()

while start_time <= end_time:
    window_end_time = start_time + pd.Timedelta(seconds=window_size)
    window_df = df_sorted[(df_sorted['timestamp'] >= start_time) & (df_sorted['timestamp'] < window_end_time)]
    
    # Calculate the number of events (points) in the current window
    event_count = len(window_df)
    actual_counts.append(event_count)
    
    # Calculate the expected number of events (λ) for this window
    lambda_value = calculate_lambda(actual_counts)
    expected_counts.append(lambda_value)
    
    # Calculate standard deviation for anomaly detection
    std_dev = np.std(actual_counts)
    
    # Identify anomalies where the actual count deviates significantly from the expected count
    if abs(event_count - lambda_value) > 2 * std_dev:
        anomalies.append(True)
    else:
        anomalies.append(False)
    
    window_starts.append(start_time)
    
    # Move to the next window start time
    start_time = start_time + pd.Timedelta(seconds=step_size)

# Create a DataFrame to hold the results
results_df = pd.DataFrame({
    'window_start': window_starts,
    'actual_count': actual_counts,
    'expected_count': expected_counts,
    'anomaly': anomalies
})

# Plot the actual vs expected counts with anomalies highlighted
plt.figure(figsize=(14, 7))
plt.plot(results_df['window_start'], results_df['actual_count'], marker='o', linestyle='-', color='pink', label='Actual Count')
plt.plot(results_df['window_start'], results_df['expected_count'], linestyle='--', color='orange', label='Expected Count (λ)')
plt.scatter(results_df[results_df['anomaly']]['window_start'], results_df[results_df['anomaly']]['actual_count'], color='red', label='Anomaly', marker='x')
plt.xlabel('Time')
plt.ylabel('Event Count')
plt.title('Actual vs Expected Event Count with Anomalies Highlighted')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# Print the DataFrame showing where anomalies occurred
print("Anomalous time intervals:")
print(results_df[results_df['anomaly']])
# Out:
# Anomalous time intervals:
#            window_start  actual_count  expected_count  anomaly
# 21  2012-02-14 09:00:44            10       11.954545     True
# 22  2012-02-14 09:20:44            10       11.869565     True
# 23  2012-02-14 09:40:44            10       11.791667     True
# 25  2012-02-14 10:20:44            10       11.692308     True
# 27  2012-02-14 11:00:44             9       11.535714     True
# 33  2012-02-14 13:00:44             9       11.411765     True
# 34  2012-02-14 13:20:44             8       11.314286     True
# 35  2012-02-14 13:40:44             6       11.166667     True
# 36  2012-02-14 14:00:44             7       11.054054     True
# 37  2012-02-14 14:20:44             7       10.947368     True
# 38  2012-02-14 14:40:44             7       10.846154     True
# 50  2012-02-14 18:40:44             4       10.784314     True
# 51  2012-02-14 19:00:44             0       10.576923     True
# 52  2012-02-14 19:20:44             0       10.377358     True
# 53  2012-02-14 19:40:44             0       10.185185     True
# 54  2012-02-14 20:00:44             0       10.000000     True
# 55  2012-02-14 20:20:44             0        9.821429     True
# 56  2012-02-14 20:40:44             0        9.649123     True
# 57  2012-02-14 21:00:44             0        9.482759     True
# 58  2012-02-14 21:20:44             0        9.322034     True
# 59  2012-02-14 21:40:44             0        9.166667     True
# 60  2012-02-14 22:00:44             0        9.016393     True
# 123 2012-02-15 19:00:44             0        9.056452     True
# 124 2012-02-15 19:20:44             0        8.984000     True
# 125 2012-02-15 19:40:44             0        8.912698     True
